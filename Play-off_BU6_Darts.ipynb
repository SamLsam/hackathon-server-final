# %% [raw]
# Привет!
# В преддверии финала хотели бы поделиться обратной связью от экспертов:
#
# Всем спасибо за проделанную работу и предоставленные решения.
#
# Мы решили выдать данные за 1 квартал 21 года, чтобы у вас была возможность
# самим оценить работу моделей и скорректировать некоторые моменты.
# По окончании данного этапа мы ожидаем от вас реализацию ваших идей,
# прогноз на 2 квартал 21 года, а также твердый и четкий ответ, на вопрос о том,
# могут ли предоставленные дополнительные данные о БЕ номер 3 и 5 помочь улучшить точность моделей.
#
# Пожалуйста, по итогам своей работы предоставьте файл с прогнозами в виде кумулятивных сумм,
# аналогично тому, как это представлено в файле с объяснением подсчета метрики.

# %% [raw]
# Фидбэк по вашему решению:
# Советуем углубить анализ в контексте определения дней транзакции,
# поискать закономерности, создать дополнительные признаки и усложнить модели.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import holidays
import calendar
import datetime

# %%
from sklearn.metrics import mean_absolute_error

# %%
import optuna
from darts import TimeSeries
from darts.models import AutoARIMA, LightGBMModel

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.set(font_scale=1.25)

# %%
data = pd.read_csv("train.csv")

# %%
train = pd.DataFrame()
train["Unit"] = data["БЕ"]
train["Date"] = data["Дата транзакции"]
train["RUB"] = data["Сумма в RUB"]

# %%
train_0 = train[train["Unit"]==0][["Date", "RUB"]]
train_0.set_index(pd.to_datetime(train_0["Date"]), inplace=True)
train_0.drop(["Date"], inplace=True, axis=1)

train_1 = train[train["Unit"]==1][["Date", "RUB"]]
train_1.set_index(pd.to_datetime(train_1["Date"]), inplace=True)
train_1.drop(["Date"], inplace=True, axis=1)

train_2 = train[train["Unit"]==2][["Date", "RUB"]]
train_2.set_index(pd.to_datetime(train_2["Date"]), inplace=True)
train_2.drop(["Date"], inplace=True, axis=1)

train_3 = train[train["Unit"]==3][["Date", "RUB"]]
train_3.set_index(pd.to_datetime(train_3["Date"]), inplace=True)
train_3.drop(["Date"], inplace=True, axis=1)

train_4 = train[train["Unit"]==4][["Date", "RUB"]]
train_4.set_index(pd.to_datetime(train_4["Date"]), inplace=True)
train_4.drop(["Date"], inplace=True, axis=1)

train_5 = train[train["Unit"]==5][["Date", "RUB"]]
train_5.set_index(pd.to_datetime(train_5["Date"]), inplace=True)
train_5.drop(["Date"], inplace=True, axis=1)

train_6 = train[train["Unit"]==6][["Date", "RUB"]]
train_6.set_index(pd.to_datetime(train_6["Date"]), inplace=True)
train_6.drop(["Date"], inplace=True, axis=1)

# %%
train_6.tail()
# Out:
#                      RUB
# Date
# 2020-12-02 -1.783439e+03
# 2020-12-09 -2.029097e+05
# 2020-12-16 -8.341146e+03
# 2020-12-23 -2.872760e+07
# 2020-12-30 -3.441478e+05

# %%
train_6_1d = train_6.resample('1D').sum()

train_6_1d = pd.concat([train_6_1d, pd.DataFrame([0], columns=["RUB"], index=[pd.to_datetime("2020-12-31")])])
train_6_1d.index.name = "Date"

# %%
train_6_1d.tail()
# Out:
#                       RUB
# Date
# 2020-12-27       0.000000
# 2020-12-28       0.000000
# 2020-12-29       0.000000
# 2020-12-30 -344147.757962
# 2020-12-31       0.000000

# %%
# Этот выброс ...
sns.lineplot(data=train_6_1d)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##############################################################################################################################################################################################

# %%
### Generalized valid data ###
# Данные, выданные к финалу - первый квартал 2021 года
data = pd.read_excel("1кв2021_1.xlsx")

# %%
val = pd.DataFrame()
val["Unit"] = data["БЕ"]
val["Date"] = data["Расчет ликвидности - дата"]
val["RUB"] = data["Сумма в валюте транзакции"]

# %%
val_0 = val[val["Unit"]==0][["Date", "RUB"]]
val_0.set_index(pd.to_datetime(val_0["Date"], dayfirst=True), inplace=True)
val_0.drop("Date", inplace=True, axis=1)

val_1 = val[val["Unit"]==1][["Date", "RUB"]]
val_1.set_index(pd.to_datetime(val_1["Date"], dayfirst=True), inplace=True)
val_1.drop("Date", inplace=True, axis=1)

val_2 = val[val["Unit"]==2][["Date", "RUB"]]
val_2.set_index(pd.to_datetime(val_2["Date"], dayfirst=True), inplace=True)
val_2.drop("Date", inplace=True, axis=1)

val_3 = val[val["Unit"]==3][["Date", "RUB"]]
val_3.set_index(pd.to_datetime(val_3["Date"], dayfirst=True), inplace=True)
val_3.drop("Date", inplace=True, axis=1)

val_4 = val[val["Unit"]==4][["Date", "RUB"]]
val_4.set_index(pd.to_datetime(val_4["Date"], dayfirst=True), inplace=True)
val_4.drop("Date", inplace=True, axis=1)

val_5 = val[val["Unit"]==5][["Date", "RUB"]]
val_5.set_index(pd.to_datetime(val_5["Date"], dayfirst=True), inplace=True)
val_5.drop("Date", inplace=True, axis=1)

val_6 = val[val["Unit"]==6][["Date", "RUB"]]
val_6.set_index(pd.to_datetime(val_6["Date"], dayfirst=True), inplace=True)
val_6.drop("Date", inplace=True, axis=1)

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*B1oKvhOuYoTdFEnwl8SEpg.png">

# %% [raw]
# Рисунок 1 - Схематичное изображение future covariates на временном интревале.
# Источник: https://medium.com/unit8-machine-learning-publication/time-series-forecasting-using-past-and-future-external-data-with-darts-1f0539585993

# %%
first_quarter = pd.DataFrame()
first_quarter.index = pd.date_range(start='1/1/2021', end='31/08/2021')
first_quarter["RUB"] = 0

val_0_1d = pd.DataFrame()
val_0_1d.index = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_0_1d.index.name = "Date"
val_0_1d["RUB"] = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_1_1d = pd.DataFrame()
val_1_1d.index = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_1_1d.index.name = "Date"
val_1_1d["RUB"] = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_2_1d = pd.DataFrame()
val_2_1d.index = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_2_1d.index.name = "Date"
val_2_1d["RUB"] = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_3_1d = pd.DataFrame()
val_3_1d.index = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_3_1d.index.name = "Date"
val_3_1d["RUB"] = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_4_1d = pd.DataFrame()
val_4_1d.index = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_4_1d.index.name = "Date"
val_4_1d["RUB"] = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_5_1d = pd.DataFrame()
val_5_1d.index = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_5_1d.index.name = "Date"
val_5_1d["RUB"] = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_6_1d = pd.DataFrame()
val_6_1d.index = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_6_1d.index.name = "Date"
val_6_1d["RUB"] = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

# %%
##############################################################################################################################################################################################

# %%
# Feature engineering
# Добавляем регрессоры

# %%
def dayofweek(df):
    df["Dayofweek"] = df.index.dayofweek
    return df

# %%
def get_holidays(df):
    df["Holidays"] = pd.Series(df.index).apply(lambda x: holidays.CountryHoliday('RUS').get(x)).values
    df["Holidays"] = df["Holidays"].astype('bool').astype('int')
    return df

# %%
def number_of_week_in_year(df):
    df["Number_of_week_in_year"] = df.index.isocalendar().week
    df["Number_of_week_in_year"] = df["Number_of_week_in_year"].astype(int)
    return df

# %%
def number_of_week_in_month(df):
    def week_of_month(tgtdate):
        days_this_month = calendar.mdays[tgtdate.month]
        for i in range(1, days_this_month):
            d = datetime.datetime(tgtdate.year, tgtdate.month, i)
            if d.day - d.weekday() > 0:
                startdate = d
                break
        return (tgtdate - startdate).days //7 + 1

    df["Number_of_week_in_month"] = df.index.to_series().apply(week_of_month)
    return df

# %%
def number_of_day_in_month(df):
    df["Number_of_day_in_month"] = df.index.day
    return df

# %%
def number_of_day_in_year(df):
    df["Number_of_day_in_year"] = df.index.dayofyear
    return df

# %%
def get_month(df):
    df["Month"] = df.index.month
    return df

# %%
def get_season(df):
    df["Season"] = df.index.month%12 // 3 + 1
    return df

# %%
def changepoint(df, date):
    df["Changepoint"] = 0 
    df.loc[date:, "Changepoint"] = 1
    return df

# %%
def payday(df, payday):
    df["Payday"] = 0 
    df.loc[df.index.day_name() == payday, "Payday"] = 1
    return df

# %%
(
    train_6_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)
    .pipe(changepoint, date="2019-07-30")
    .pipe(payday, payday="Wednesday")
)
# Out:
#                       RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2017-01-11 -721219.987261          2         0                       2
# 2017-01-12       0.000000          3         0                       2
# 2017-01-13       0.000000          4         0                       2
# 2017-01-14       0.000000          5         0                       2
# 2017-01-15       0.000000          6         0                       2
# ...                   ...        ...       ...                     ...
# 2020-12-27       0.000000          6         0                      52
# 2020-12-28       0.000000          0         0                      53
# 2020-12-29       0.000000          1         0                      53
# 2020-12-30 -344147.757962          2         0                      53
# 2020-12-31       0.000000          3         1                      53
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2017-01-11                        2                      11
# 2017-01-12                        2                      12
# 2017-01-13                        2                      13
# 2017-01-14                        2                      14
# 2017-01-15                        2                      15
# ...                             ...                     ...
# 2020-12-27                        3                      27
# 2020-12-28                        4                      28
# 2020-12-29                        4                      29
# 2020-12-30                        4                      30
# 2020-12-31                        4                      31
#
#             Number_of_day_in_year  Month  Season  Changepoint  Payday
# Date
# 2017-01-11                     11      1       1            0       1
# 2017-01-12                     12      1       1            0       0
# 2017-01-13                     13      1       1            0       0
# 2017-01-14                     14      1       1            0       0
# 2017-01-15                     15      1       1            0       0
# ...                           ...    ...     ...          ...     ...
# 2020-12-27                    362     12       1            1       0
# 2020-12-28                    363     12       1            1       0
# 2020-12-29                    364     12       1            1       0
# 2020-12-30                    365     12       1            1       1
# 2020-12-31                    366     12       1            1       0
#
# [1451 rows x 11 columns]

# %%
(
    val_6_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)
    .pipe(changepoint, date="2019-07-30")
    .pipe(payday, payday="Wednesday")
)
# Out:
#             RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2021-01-01  0.0          4         1                      53
# 2021-01-02  0.0          5         1                      53
# 2021-01-03  0.0          6         1                      53
# 2021-01-04  0.0          0         1                       1
# 2021-01-05  0.0          1         1                       1
# ...         ...        ...       ...                     ...
# 2021-08-27  0.0          4         0                      34
# 2021-08-28  0.0          5         0                      34
# 2021-08-29  0.0          6         0                      34
# 2021-08-30  0.0          0         0                      35
# 2021-08-31  0.0          1         0                      35
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2021-01-01                        0                       1
# 2021-01-02                        0                       2
# 2021-01-03                        0                       3
# 2021-01-04                        1                       4
# 2021-01-05                        1                       5
# ...                             ...                     ...
# 2021-08-27                        4                      27
# 2021-08-28                        4                      28
# 2021-08-29                        4                      29
# 2021-08-30                        5                      30
# 2021-08-31                        5                      31
#
#             Number_of_day_in_year  Month  Season  Changepoint  Payday
# Date
# 2021-01-01                      1      1       1            1       0
# 2021-01-02                      2      1       1            1       0
# 2021-01-03                      3      1       1            1       0
# 2021-01-04                      4      1       1            1       0
# 2021-01-05                      5      1       1            1       0
# ...                           ...    ...     ...          ...     ...
# 2021-08-27                    239      8       3            1       0
# 2021-08-28                    240      8       3            1       0
# 2021-08-29                    241      8       3            1       0
# 2021-08-30                    242      8       3            1       0
# 2021-08-31                    243      8       3            1       0
#
# [243 rows x 11 columns]

# %%
list(train_6_1d.columns.values)
# Out:
# ['RUB',
#  'Dayofweek',
#  'Holidays',
#  'Number_of_week_in_year',
#  'Number_of_week_in_month',
#  'Number_of_day_in_month',
#  'Number_of_day_in_year',
#  'Month',
#  'Season',
#  'Changepoint',
#  'Payday']

# %%
##############################################################################################################################################################################################

# %%
# Darts модели

# %%
train_6_1d_reindex = train_6_1d["RUB"].reset_index(inplace=False)
train_6_1d_covariates = train_6_1d.drop("RUB", inplace=False, axis=1).reset_index()

val_6_1d_reindex = val_6_1d.loc["2021-01-01":"2021-03-31","RUB"].reset_index(inplace=False)
val_6_1d_covariates = val_6_1d.drop("RUB", inplace=False, axis=1).reset_index()

# %%
total_6_1d = pd.concat([train_6_1d, val_6_1d.loc["2021-01-01":"2021-03-31"]])
total_6_1d_reindex = total_6_1d["RUB"].reset_index(inplace=False)

# %%
series_1d_total = TimeSeries.from_dataframe(total_6_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
covariates = pd.concat([train_6_1d_covariates, val_6_1d_covariates])

# %%
series_1d_train = TimeSeries.from_dataframe(train_6_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)
series_1d_val = TimeSeries.from_dataframe(val_6_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
series_1d_future_covariates = TimeSeries.from_dataframe(
    covariates,
    time_col="Date",
    value_cols=[
        "Dayofweek",
        "Holidays",
        "Number_of_week_in_year",
        "Number_of_week_in_month",
        "Number_of_day_in_month",
        "Number_of_day_in_year",
        "Month",
        "Season",
        "Changepoint",
        "Payday",
    ],
    freq="1d",
    fill_missing_dates=True,
)

# %%
train_1d_split, local_val_1d_split = series_1d_train.split_before(0.80)
val_1d_split = series_1d_val

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
def objective_LGB(trial):

    model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=trial.suggest_float("learning_rate", 1e-3, 1.0, log=True),
        lambda_l1=trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
        lambda_l2=trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
        min_gain_to_split=trial.suggest_float("min_gain_to_split", 0, 10.0),
        num_leaves=trial.suggest_int("num_leaves", 8, 256),
        feature_fraction=trial.suggest_uniform("feature_fraction", 0.0001, 1.0),
        bagging_fraction=trial.suggest_uniform("bagging_fraction", 0.0001, 1.0),
        bagging_freq=trial.suggest_int("bagging_freq", 0, 30),
        min_child_samples=trial.suggest_int("min_child_samples", 1, 100),
        min_data_in_leaf=trial.suggest_int("min_data_in_leaf", 3, 100),
        feature_pre_filter=False
    )  

    model1d.fit(train_1d_split, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(local_val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    local_val = mean_absolute_error(local_val_1d_split.pd_dataframe(), fixed_prediction1d)
    

    model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    global_val = mean_absolute_error(val_1d_split.pd_dataframe(), fixed_prediction1d)
    
    val = np.mean([local_val, global_val])

    trial.set_user_attr("Valid_score", val)

    print(f"MAE: {val}\n")

    return val

# %%
study_LGB = optuna.create_study(direction="minimize")
study_LGB.optimize(objective_LGB, n_trials=300, gc_after_trial=True)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9735177131561992, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9735177131561992
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=58 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=8.50365882839197, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.50365882839197
# [LightGBM] [Warning] lambda_l1 is set=2.086547470203393e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.086547470203393e-07
# [LightGBM] [Warning] bagging_fraction is set=0.13026320035429484, subsample=1.0 will be ignored. Current value: bagging_fraction=0.13026320035429484
# [LightGBM] [Warning] lambda_l2 is set=2.844481604879119e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.844481604879119e-05
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# [LightGBM] [Warning] feature_fraction is set=0.9735177131561992, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9735177131561992
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=58 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=8.50365882839197, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.50365882839197
# [LightGBM] [Warning] lambda_l1 is set=2.086547470203393e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.086547470203393e-07
# [LightGBM] [Warning] bagging_fraction is set=0.13026320035429484, subsample=1.0 will be ignored. Current value: bagging_fraction=0.13026320035429484
# [LightGBM] [Warning] lambda_l2 is set=2.844481604879119e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.844481604879119e-05
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# MAE: 347964.7440727623
#
# [LightGBM] [Warning] feature_fraction is set=0.4500786194326903, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4500786194326903
# [LightGBM] [Warning] min_data_in_leaf is set=71, min_child_samples=44 will be ignored. Current value: min_data_in_leaf=71
# [LightGBM] [Warning] min_gain_to_split is set=5.009970972617658, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.009970972617658
# [LightGBM] [Warning] lambda_l1 is set=6.591824657183654, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.591824657183654
# [LightGBM] [Warning] bagging_fraction is set=0.004225878699491437, subsample=1.0 will be ignored. Current value: bagging_fraction=0.004225878699491437
# [LightGBM] [Warning] lambda_l2 is set=1.8030943196819938e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8030943196819938e-05
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# [LightGBM] [Warning] feature_fraction is set=0.4500786194326903, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4500786194326903
# [LightGBM] [Warning] min_data_in_leaf is set=71, min_child_samples=44 will be ignored. Current value: min_data_in_leaf=71
# [LightGBM] [Warning] min_gain_to_split is set=5.009970972617658, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.009970972617658
# [LightGBM] [Warning] lambda_l1 is set=6.591824657183654, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.591824657183654
# [LightGBM] [Warning] bagging_fraction is set=0.004225878699491437, subsample=1.0 will be ignored. Current value: bagging_fraction=0.004225878699491437
# [LightGBM] [Warning] lambda_l2 is set=1.8030943196819938e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8030943196819938e-05
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 449519.23745372304
#
# [LightGBM] [Warning] feature_fraction is set=0.7987091070294101, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7987091070294101
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.485516802633467, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.485516802633467
# [LightGBM] [Warning] lambda_l1 is set=0.4179269529474146, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4179269529474146
# [LightGBM] [Warning] bagging_fraction is set=0.23646439477493458, subsample=1.0 will be ignored. Current value: bagging_fraction=0.23646439477493458
# [LightGBM] [Warning] lambda_l2 is set=0.294562384475653, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.294562384475653
# [LightGBM] [Warning] bagging_freq is set=24, subsample_freq=0 will be ignored. Current value: bagging_freq=24
# [LightGBM] [Warning] feature_fraction is set=0.7987091070294101, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7987091070294101
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.485516802633467, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.485516802633467
# [LightGBM] [Warning] lambda_l1 is set=0.4179269529474146, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4179269529474146
# [LightGBM] [Warning] bagging_fraction is set=0.23646439477493458, subsample=1.0 will be ignored. Current value: bagging_fraction=0.23646439477493458
# [LightGBM] [Warning] lambda_l2 is set=0.294562384475653, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.294562384475653
# [LightGBM] [Warning] bagging_freq is set=24, subsample_freq=0 will be ignored. Current value: bagging_freq=24
# MAE: 391453.9372840874
#
# [LightGBM] [Warning] feature_fraction is set=0.8182752835561092, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8182752835561092
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=5.241778814742899, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.241778814742899
# [LightGBM] [Warning] lambda_l1 is set=1.75092745129459e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.75092745129459e-08
# [LightGBM] [Warning] bagging_fraction is set=0.8313394749946965, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8313394749946965
# [LightGBM] [Warning] lambda_l2 is set=1.120417095265225e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.120417095265225e-06
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# [LightGBM] [Warning] feature_fraction is set=0.8182752835561092, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8182752835561092
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=5.241778814742899, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.241778814742899
# [LightGBM] [Warning] lambda_l1 is set=1.75092745129459e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.75092745129459e-08
# [LightGBM] [Warning] bagging_fraction is set=0.8313394749946965, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8313394749946965
# [LightGBM] [Warning] lambda_l2 is set=1.120417095265225e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.120417095265225e-06
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# MAE: 288190.45495162497
#
# [LightGBM] [Warning] feature_fraction is set=0.027965441947930554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.027965441947930554
# [LightGBM] [Warning] min_data_in_leaf is set=82, min_child_samples=4 will be ignored. Current value: min_data_in_leaf=82
# [LightGBM] [Warning] min_gain_to_split is set=9.714433932042883, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.714433932042883
# [LightGBM] [Warning] lambda_l1 is set=1.70856823132153e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.70856823132153e-06
# [LightGBM] [Warning] bagging_fraction is set=0.21066092905483266, subsample=1.0 will be ignored. Current value: bagging_fraction=0.21066092905483266
# [LightGBM] [Warning] lambda_l2 is set=0.0024948349290983937, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0024948349290983937
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.027965441947930554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.027965441947930554
# [LightGBM] [Warning] min_data_in_leaf is set=82, min_child_samples=4 will be ignored. Current value: min_data_in_leaf=82
# [LightGBM] [Warning] min_gain_to_split is set=9.714433932042883, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.714433932042883
# [LightGBM] [Warning] lambda_l1 is set=1.70856823132153e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.70856823132153e-06
# [LightGBM] [Warning] bagging_fraction is set=0.21066092905483266, subsample=1.0 will be ignored. Current value: bagging_fraction=0.21066092905483266
# [LightGBM] [Warning] lambda_l2 is set=0.0024948349290983937, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0024948349290983937
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# MAE: 380065.0092030704
#
# [LightGBM] [Warning] feature_fraction is set=0.2251936956912498, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2251936956912498
# [LightGBM] [Warning] min_data_in_leaf is set=79, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=79
# [LightGBM] [Warning] min_gain_to_split is set=6.4265952442117005, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.4265952442117005
# [LightGBM] [Warning] lambda_l1 is set=0.002163699881695087, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.002163699881695087
# [LightGBM] [Warning] bagging_fraction is set=0.5279458115181104, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5279458115181104
# [LightGBM] [Warning] lambda_l2 is set=0.0006506125660773607, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006506125660773607
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# [LightGBM] [Warning] feature_fraction is set=0.2251936956912498, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2251936956912498
# [LightGBM] [Warning] min_data_in_leaf is set=79, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=79
# [LightGBM] [Warning] min_gain_to_split is set=6.4265952442117005, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.4265952442117005
# [LightGBM] [Warning] lambda_l1 is set=0.002163699881695087, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.002163699881695087
# [LightGBM] [Warning] bagging_fraction is set=0.5279458115181104, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5279458115181104
# [LightGBM] [Warning] lambda_l2 is set=0.0006506125660773607, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006506125660773607
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# MAE: 309032.6612645626
#
# [LightGBM] [Warning] feature_fraction is set=0.7148398350237506, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7148398350237506
# [LightGBM] [Warning] min_data_in_leaf is set=60, min_child_samples=53 will be ignored. Current value: min_data_in_leaf=60
# [LightGBM] [Warning] min_gain_to_split is set=0.9208580529805899, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.9208580529805899
# [LightGBM] [Warning] lambda_l1 is set=1.536477779456901e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.536477779456901e-08
# [LightGBM] [Warning] bagging_fraction is set=0.9436049605328872, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9436049605328872
# [LightGBM] [Warning] lambda_l2 is set=7.745852388489166e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.745852388489166e-05
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.7148398350237506, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7148398350237506
# [LightGBM] [Warning] min_data_in_leaf is set=60, min_child_samples=53 will be ignored. Current value: min_data_in_leaf=60
# [LightGBM] [Warning] min_gain_to_split is set=0.9208580529805899, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.9208580529805899
# [LightGBM] [Warning] lambda_l1 is set=1.536477779456901e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.536477779456901e-08
# [LightGBM] [Warning] bagging_fraction is set=0.9436049605328872, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9436049605328872
# [LightGBM] [Warning] lambda_l2 is set=7.745852388489166e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.745852388489166e-05
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# MAE: 288951.4710972763
#
# [LightGBM] [Warning] feature_fraction is set=0.5392095032239788, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5392095032239788
# [LightGBM] [Warning] min_data_in_leaf is set=66, min_child_samples=52 will be ignored. Current value: min_data_in_leaf=66
# [LightGBM] [Warning] min_gain_to_split is set=6.269216727497452, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.269216727497452
# [LightGBM] [Warning] lambda_l1 is set=0.030843057830682037, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.030843057830682037
# [LightGBM] [Warning] bagging_fraction is set=0.9158691579115791, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9158691579115791
# [LightGBM] [Warning] lambda_l2 is set=7.761947141036448e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.761947141036448e-07
# [LightGBM] [Warning] bagging_freq is set=21, subsample_freq=0 will be ignored. Current value: bagging_freq=21
# [LightGBM] [Warning] feature_fraction is set=0.5392095032239788, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5392095032239788
# [LightGBM] [Warning] min_data_in_leaf is set=66, min_child_samples=52 will be ignored. Current value: min_data_in_leaf=66
# [LightGBM] [Warning] min_gain_to_split is set=6.269216727497452, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.269216727497452
# [LightGBM] [Warning] lambda_l1 is set=0.030843057830682037, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.030843057830682037
# [LightGBM] [Warning] bagging_fraction is set=0.9158691579115791, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9158691579115791
# [LightGBM] [Warning] lambda_l2 is set=7.761947141036448e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.761947141036448e-07
# [LightGBM] [Warning] bagging_freq is set=21, subsample_freq=0 will be ignored. Current value: bagging_freq=21
# MAE: 295864.2303839446
#
# [LightGBM] [Warning] feature_fraction is set=0.7541747897071299, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7541747897071299
# [LightGBM] [Warning] min_data_in_leaf is set=68, min_child_samples=1 will be ignored. Current value: min_data_in_leaf=68
# [LightGBM] [Warning] min_gain_to_split is set=8.878776104343654, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.878776104343654
# [LightGBM] [Warning] lambda_l1 is set=0.34955996823928925, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.34955996823928925
# [LightGBM] [Warning] bagging_fraction is set=0.13414503321129978, subsample=1.0 will be ignored. Current value: bagging_fraction=0.13414503321129978
# [LightGBM] [Warning] lambda_l2 is set=1.407245714491989e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.407245714491989e-08
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# [LightGBM] [Warning] feature_fraction is set=0.7541747897071299, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7541747897071299
# [LightGBM] [Warning] min_data_in_leaf is set=68, min_child_samples=1 will be ignored. Current value: min_data_in_leaf=68
# [LightGBM] [Warning] min_gain_to_split is set=8.878776104343654, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.878776104343654
# [LightGBM] [Warning] lambda_l1 is set=0.34955996823928925, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.34955996823928925
# [LightGBM] [Warning] bagging_fraction is set=0.13414503321129978, subsample=1.0 will be ignored. Current value: bagging_fraction=0.13414503321129978
# [LightGBM] [Warning] lambda_l2 is set=1.407245714491989e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.407245714491989e-08
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# MAE: 412496.0806240014
#
# [LightGBM] [Warning] feature_fraction is set=0.9845917427790166, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9845917427790166
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=68 will be ignored. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_gain_to_split is set=0.0885889357947156, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.0885889357947156
# [LightGBM] [Warning] lambda_l1 is set=2.4026988365459374, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4026988365459374
# [LightGBM] [Warning] bagging_fraction is set=0.3751828838529162, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3751828838529162
# [LightGBM] [Warning] lambda_l2 is set=6.688543536171673, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.688543536171673
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# [LightGBM] [Warning] feature_fraction is set=0.9845917427790166, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9845917427790166
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=68 will be ignored. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] min_gain_to_split is set=0.0885889357947156, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.0885889357947156
# [LightGBM] [Warning] lambda_l1 is set=2.4026988365459374, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4026988365459374
# [LightGBM] [Warning] bagging_fraction is set=0.3751828838529162, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3751828838529162
# [LightGBM] [Warning] lambda_l2 is set=6.688543536171673, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.688543536171673
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# MAE: 340063.92303571856
#
# [LightGBM] [Warning] feature_fraction is set=0.49326895456912156, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.49326895456912156
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_gain_to_split is set=3.042553098250963, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.042553098250963
# [LightGBM] [Warning] lambda_l1 is set=2.5417375229464573e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.5417375229464573e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6961915775693548, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6961915775693548
# [LightGBM] [Warning] lambda_l2 is set=1.5590975421373962e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5590975421373962e-08
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.49326895456912156, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.49326895456912156
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_gain_to_split is set=3.042553098250963, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.042553098250963
# [LightGBM] [Warning] lambda_l1 is set=2.5417375229464573e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.5417375229464573e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6961915775693548, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6961915775693548
# [LightGBM] [Warning] lambda_l2 is set=1.5590975421373962e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5590975421373962e-08
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# MAE: 243108.1606570826
#
# [LightGBM] [Warning] feature_fraction is set=0.45172303889401577, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.45172303889401577
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=98 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=2.8071571908934296, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.8071571908934296
# [LightGBM] [Warning] lambda_l1 is set=2.332482714576804e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.332482714576804e-05
# [LightGBM] [Warning] bagging_fraction is set=0.747075953494141, subsample=1.0 will be ignored. Current value: bagging_fraction=0.747075953494141
# [LightGBM] [Warning] lambda_l2 is set=1.0548542619118145e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0548542619118145e-08
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.45172303889401577, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.45172303889401577
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=98 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=2.8071571908934296, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.8071571908934296
# [LightGBM] [Warning] lambda_l1 is set=2.332482714576804e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.332482714576804e-05
# [LightGBM] [Warning] bagging_fraction is set=0.747075953494141, subsample=1.0 will be ignored. Current value: bagging_fraction=0.747075953494141
# [LightGBM] [Warning] lambda_l2 is set=1.0548542619118145e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0548542619118145e-08
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# MAE: 239741.13379942987
#
# [LightGBM] [Warning] feature_fraction is set=0.4333851882476698, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4333851882476698
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=2.4843225808243887, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.4843225808243887
# [LightGBM] [Warning] lambda_l1 is set=2.7741486223740724e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.7741486223740724e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6925630210932094, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6925630210932094
# [LightGBM] [Warning] lambda_l2 is set=3.077836055334059e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.077836055334059e-08
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.4333851882476698, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4333851882476698
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=2.4843225808243887, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.4843225808243887
# [LightGBM] [Warning] lambda_l1 is set=2.7741486223740724e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.7741486223740724e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6925630210932094, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6925630210932094
# [LightGBM] [Warning] lambda_l2 is set=3.077836055334059e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.077836055334059e-08
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 218775.80417617518
#
# [LightGBM] [Warning] feature_fraction is set=0.34161808560295737, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.34161808560295737
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=2.212222857856079, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.212222857856079
# [LightGBM] [Warning] lambda_l1 is set=0.0001439259866685691, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0001439259866685691
# [LightGBM] [Warning] bagging_fraction is set=0.6363183875169558, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6363183875169558
# [LightGBM] [Warning] lambda_l2 is set=2.91513691670281e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.91513691670281e-07
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.34161808560295737, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.34161808560295737
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=2.212222857856079, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.212222857856079
# [LightGBM] [Warning] lambda_l1 is set=0.0001439259866685691, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0001439259866685691
# [LightGBM] [Warning] bagging_fraction is set=0.6363183875169558, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6363183875169558
# [LightGBM] [Warning] lambda_l2 is set=2.91513691670281e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.91513691670281e-07
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 220752.85997993476
#
# [LightGBM] [Warning] feature_fraction is set=0.2892730911770078, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2892730911770078
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=83 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_gain_to_split is set=2.696973199086923, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.696973199086923
# [LightGBM] [Warning] lambda_l1 is set=0.0009157287664940116, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009157287664940116
# [LightGBM] [Warning] bagging_fraction is set=0.552653463590049, subsample=1.0 will be ignored. Current value: bagging_fraction=0.552653463590049
# [LightGBM] [Warning] lambda_l2 is set=4.83732469673645e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.83732469673645e-07
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2892730911770078, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2892730911770078
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=83 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_gain_to_split is set=2.696973199086923, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.696973199086923
# [LightGBM] [Warning] lambda_l1 is set=0.0009157287664940116, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009157287664940116
# [LightGBM] [Warning] bagging_fraction is set=0.552653463590049, subsample=1.0 will be ignored. Current value: bagging_fraction=0.552653463590049
# [LightGBM] [Warning] lambda_l2 is set=4.83732469673645e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.83732469673645e-07
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# MAE: 327803.4461304407
#
# [LightGBM] [Warning] feature_fraction is set=0.290045552878886, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.290045552878886
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=88 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] min_gain_to_split is set=1.6533942095953913, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.6533942095953913
# [LightGBM] [Warning] lambda_l1 is set=1.2170896495417436e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.2170896495417436e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6440144872724914, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6440144872724914
# [LightGBM] [Warning] lambda_l2 is set=2.197328989170089e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.197328989170089e-07
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.290045552878886, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.290045552878886
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=88 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] min_gain_to_split is set=1.6533942095953913, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.6533942095953913
# [LightGBM] [Warning] lambda_l1 is set=1.2170896495417436e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.2170896495417436e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6440144872724914, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6440144872724914
# [LightGBM] [Warning] lambda_l2 is set=2.197328989170089e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.197328989170089e-07
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# MAE: 277324.851222695
#
# [LightGBM] [Warning] feature_fraction is set=0.11521931815731279, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11521931815731279
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=71 will be ignored. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] min_gain_to_split is set=3.7514207041983827, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.7514207041983827
# [LightGBM] [Warning] lambda_l1 is set=0.000280373427352847, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.000280373427352847
# [LightGBM] [Warning] bagging_fraction is set=0.38676128335792825, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38676128335792825
# [LightGBM] [Warning] lambda_l2 is set=4.532083911358367e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.532083911358367e-06
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.11521931815731279, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11521931815731279
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=71 will be ignored. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] min_gain_to_split is set=3.7514207041983827, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.7514207041983827
# [LightGBM] [Warning] lambda_l1 is set=0.000280373427352847, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.000280373427352847
# [LightGBM] [Warning] bagging_fraction is set=0.38676128335792825, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38676128335792825
# [LightGBM] [Warning] lambda_l2 is set=4.532083911358367e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.532083911358367e-06
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 256241.14111970918
#
# [LightGBM] [Warning] feature_fraction is set=0.631856378843062, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.631856378843062
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=90 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] min_gain_to_split is set=1.6636689270382228, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.6636689270382228
# [LightGBM] [Warning] lambda_l1 is set=0.00825194194136597, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00825194194136597
# [LightGBM] [Warning] bagging_fraction is set=0.42484691788061413, subsample=1.0 will be ignored. Current value: bagging_fraction=0.42484691788061413
# [LightGBM] [Warning] lambda_l2 is set=0.005054392676693329, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.005054392676693329
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.631856378843062, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.631856378843062
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=90 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] min_gain_to_split is set=1.6636689270382228, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.6636689270382228
# [LightGBM] [Warning] lambda_l1 is set=0.00825194194136597, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00825194194136597
# [LightGBM] [Warning] bagging_fraction is set=0.42484691788061413, subsample=1.0 will be ignored. Current value: bagging_fraction=0.42484691788061413
# [LightGBM] [Warning] lambda_l2 is set=0.005054392676693329, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.005054392676693329
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# MAE: 307413.94708049414
#
# [LightGBM] [Warning] feature_fraction is set=0.3693579945497819, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3693579945497819
# [LightGBM] [Warning] min_data_in_leaf is set=95, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=95
# [LightGBM] [Warning] min_gain_to_split is set=1.8396048562858207, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.8396048562858207
# [LightGBM] [Warning] lambda_l1 is set=0.00016865850665749682, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00016865850665749682
# [LightGBM] [Warning] bagging_fraction is set=0.6105516707952146, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6105516707952146
# [LightGBM] [Warning] lambda_l2 is set=9.192823721220923e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.192823721220923e-08
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] feature_fraction is set=0.3693579945497819, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3693579945497819
# [LightGBM] [Warning] min_data_in_leaf is set=95, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=95
# [LightGBM] [Warning] min_gain_to_split is set=1.8396048562858207, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.8396048562858207
# [LightGBM] [Warning] lambda_l1 is set=0.00016865850665749682, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00016865850665749682
# [LightGBM] [Warning] bagging_fraction is set=0.6105516707952146, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6105516707952146
# [LightGBM] [Warning] lambda_l2 is set=9.192823721220923e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.192823721220923e-08
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# MAE: 344124.35823393275
#
# [LightGBM] [Warning] feature_fraction is set=0.19184861004747733, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.19184861004747733
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=67 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=0.4261456733232749, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.4261456733232749
# [LightGBM] [Warning] lambda_l1 is set=1.97919561089783e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.97919561089783e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7984322061784977, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7984322061784977
# [LightGBM] [Warning] lambda_l2 is set=3.4494246184551922e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.4494246184551922e-06
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.19184861004747733, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.19184861004747733
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=67 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=0.4261456733232749, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.4261456733232749
# [LightGBM] [Warning] lambda_l1 is set=1.97919561089783e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.97919561089783e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7984322061784977, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7984322061784977
# [LightGBM] [Warning] lambda_l2 is set=3.4494246184551922e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.4494246184551922e-06
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# MAE: 245989.31357301143
#
# [LightGBM] [Warning] feature_fraction is set=0.5985346771751383, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5985346771751383
# [LightGBM] [Warning] min_data_in_leaf is set=51, min_child_samples=41 will be ignored. Current value: min_data_in_leaf=51
# [LightGBM] [Warning] min_gain_to_split is set=3.8727462985076424, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.8727462985076424
# [LightGBM] [Warning] lambda_l1 is set=2.817511977914908e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.817511977914908e-07
# [LightGBM] [Warning] bagging_fraction is set=0.865947982101452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.865947982101452
# [LightGBM] [Warning] lambda_l2 is set=8.370389140683967e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.370389140683967e-08
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5985346771751383, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5985346771751383
# [LightGBM] [Warning] min_data_in_leaf is set=51, min_child_samples=41 will be ignored. Current value: min_data_in_leaf=51
# [LightGBM] [Warning] min_gain_to_split is set=3.8727462985076424, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.8727462985076424
# [LightGBM] [Warning] lambda_l1 is set=2.817511977914908e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.817511977914908e-07
# [LightGBM] [Warning] bagging_fraction is set=0.865947982101452, subsample=1.0 will be ignored. Current value: bagging_fraction=0.865947982101452
# [LightGBM] [Warning] lambda_l2 is set=8.370389140683967e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.370389140683967e-08
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# MAE: 332473.28983043437
#
# [LightGBM] [Warning] feature_fraction is set=0.42362737517879523, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.42362737517879523
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] min_gain_to_split is set=2.5955720232613992, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.5955720232613992
# [LightGBM] [Warning] lambda_l1 is set=3.698938129524298e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.698938129524298e-05
# [LightGBM] [Warning] bagging_fraction is set=0.7365328566977376, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7365328566977376
# [LightGBM] [Warning] lambda_l2 is set=1.5444814636733133e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5444814636733133e-08
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.42362737517879523, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.42362737517879523
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] min_gain_to_split is set=2.5955720232613992, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.5955720232613992
# [LightGBM] [Warning] lambda_l1 is set=3.698938129524298e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.698938129524298e-05
# [LightGBM] [Warning] bagging_fraction is set=0.7365328566977376, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7365328566977376
# [LightGBM] [Warning] lambda_l2 is set=1.5444814636733133e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5444814636733133e-08
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 236246.26806326187
#
# [LightGBM] [Warning] feature_fraction is set=0.3804217528277717, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3804217528277717
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=90 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=2.406698090310088, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.406698090310088
# [LightGBM] [Warning] lambda_l1 is set=8.33580801110094e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.33580801110094e-05
# [LightGBM] [Warning] bagging_fraction is set=0.7141862843282645, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7141862843282645
# [LightGBM] [Warning] lambda_l2 is set=7.606238974843256e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.606238974843256e-08
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.3804217528277717, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3804217528277717
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=90 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=2.406698090310088, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.406698090310088
# [LightGBM] [Warning] lambda_l1 is set=8.33580801110094e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.33580801110094e-05
# [LightGBM] [Warning] bagging_fraction is set=0.7141862843282645, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7141862843282645
# [LightGBM] [Warning] lambda_l2 is set=7.606238974843256e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.606238974843256e-08
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 242436.29944664455
#
# [LightGBM] [Warning] feature_fraction is set=0.3635224857343301, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3635224857343301
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=1.1470222621471757, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.1470222621471757
# [LightGBM] [Warning] lambda_l1 is set=4.1354449670408494e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.1354449670408494e-06
# [LightGBM] [Warning] bagging_fraction is set=0.6176338097841447, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6176338097841447
# [LightGBM] [Warning] lambda_l2 is set=5.3793286150881e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.3793286150881e-08
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.3635224857343301, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3635224857343301
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=1.1470222621471757, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.1470222621471757
# [LightGBM] [Warning] lambda_l1 is set=4.1354449670408494e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.1354449670408494e-06
# [LightGBM] [Warning] bagging_fraction is set=0.6176338097841447, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6176338097841447
# [LightGBM] [Warning] lambda_l2 is set=5.3793286150881e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.3793286150881e-08
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# MAE: 237473.22462882055
#
# [LightGBM] [Warning] feature_fraction is set=0.28943003785027405, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.28943003785027405
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=90 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] min_gain_to_split is set=3.7948913513436455, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.7948913513436455
# [LightGBM] [Warning] lambda_l1 is set=0.0013822694837373466, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0013822694837373466
# [LightGBM] [Warning] bagging_fraction is set=0.9995240173221629, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9995240173221629
# [LightGBM] [Warning] lambda_l2 is set=7.456554148692889e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.456554148692889e-06
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.28943003785027405, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.28943003785027405
# ...
# [LightGBM] [Warning] bagging_fraction is set=0.9304185563468303, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9304185563468303
# [LightGBM] [Warning] lambda_l2 is set=1.3037099730776982e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.3037099730776982e-08
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# MAE: 214042.34903169668
#
# [LightGBM] [Warning] feature_fraction is set=0.26143111043115747, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.26143111043115747
# [LightGBM] [Warning] min_data_in_leaf is set=63, min_child_samples=90 will be ignored. Current value: min_data_in_leaf=63
# [LightGBM] [Warning] min_gain_to_split is set=7.967601745704216, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.967601745704216
# [LightGBM] [Warning] lambda_l1 is set=0.010242334614507388, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.010242334614507388
# [LightGBM] [Warning] bagging_fraction is set=0.9187872658941568, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9187872658941568
# [LightGBM] [Warning] lambda_l2 is set=3.9176179508542693e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.9176179508542693e-08
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# [LightGBM] [Warning] feature_fraction is set=0.26143111043115747, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.26143111043115747
# [LightGBM] [Warning] min_data_in_leaf is set=63, min_child_samples=90 will be ignored. Current value: min_data_in_leaf=63
# [LightGBM] [Warning] min_gain_to_split is set=7.967601745704216, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.967601745704216
# [LightGBM] [Warning] lambda_l1 is set=0.010242334614507388, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.010242334614507388
# [LightGBM] [Warning] bagging_fraction is set=0.9187872658941568, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9187872658941568
# [LightGBM] [Warning] lambda_l2 is set=3.9176179508542693e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.9176179508542693e-08
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# MAE: 277156.59527552174
#
# [LightGBM] [Warning] feature_fraction is set=0.3104126761695076, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3104126761695076
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=89 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=5.831871495485849, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.831871495485849
# [LightGBM] [Warning] lambda_l1 is set=0.027247873864547845, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.027247873864547845
# [LightGBM] [Warning] bagging_fraction is set=0.8966057480780016, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8966057480780016
# [LightGBM] [Warning] lambda_l2 is set=3.0161717145448734e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0161717145448734e-08
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.3104126761695076, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3104126761695076
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=89 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=5.831871495485849, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.831871495485849
# [LightGBM] [Warning] lambda_l1 is set=0.027247873864547845, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.027247873864547845
# [LightGBM] [Warning] bagging_fraction is set=0.8966057480780016, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8966057480780016
# [LightGBM] [Warning] lambda_l2 is set=3.0161717145448734e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0161717145448734e-08
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# MAE: 234375.2696377885
#
# [LightGBM] [Warning] feature_fraction is set=0.22802216277403206, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.22802216277403206
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.881688851784157, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.881688851784157
# [LightGBM] [Warning] lambda_l1 is set=0.007672534224935508, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.007672534224935508
# [LightGBM] [Warning] bagging_fraction is set=0.9369494833510302, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9369494833510302
# [LightGBM] [Warning] lambda_l2 is set=1.0509034313410225e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0509034313410225e-08
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.22802216277403206, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.22802216277403206
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.881688851784157, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.881688851784157
# [LightGBM] [Warning] lambda_l1 is set=0.007672534224935508, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.007672534224935508
# [LightGBM] [Warning] bagging_fraction is set=0.9369494833510302, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9369494833510302
# [LightGBM] [Warning] lambda_l2 is set=1.0509034313410225e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0509034313410225e-08
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# MAE: 229803.90838733246
#
# [LightGBM] [Warning] feature_fraction is set=0.24540890760779066, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.24540890760779066
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=65 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=7.268331170949522, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.268331170949522
# [LightGBM] [Warning] lambda_l1 is set=0.015224897699801846, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.015224897699801846
# [LightGBM] [Warning] bagging_fraction is set=0.9981406024215338, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9981406024215338
# [LightGBM] [Warning] lambda_l2 is set=2.465874095099305e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.465874095099305e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.24540890760779066, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.24540890760779066
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=65 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=7.268331170949522, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.268331170949522
# [LightGBM] [Warning] lambda_l1 is set=0.015224897699801846, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.015224897699801846
# [LightGBM] [Warning] bagging_fraction is set=0.9981406024215338, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9981406024215338
# [LightGBM] [Warning] lambda_l2 is set=2.465874095099305e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.465874095099305e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# MAE: 238985.3984551889
#
# [LightGBM] [Warning] feature_fraction is set=0.21687592088145605, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21687592088145605
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=89 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=9.280628618122572, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.280628618122572
# [LightGBM] [Warning] lambda_l1 is set=0.0249132001278729, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0249132001278729
# [LightGBM] [Warning] bagging_fraction is set=0.8860281837514439, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8860281837514439
# [LightGBM] [Warning] lambda_l2 is set=2.316629986601445e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.316629986601445e-08
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# [LightGBM] [Warning] feature_fraction is set=0.21687592088145605, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21687592088145605
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=89 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=9.280628618122572, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.280628618122572
# [LightGBM] [Warning] lambda_l1 is set=0.0249132001278729, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0249132001278729
# [LightGBM] [Warning] bagging_fraction is set=0.8860281837514439, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8860281837514439
# [LightGBM] [Warning] lambda_l2 is set=2.316629986601445e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.316629986601445e-08
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# MAE: 264756.90965537424
#
# [LightGBM] [Warning] feature_fraction is set=0.27126134668335733, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.27126134668335733
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.3003892741622, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.3003892741622
# [LightGBM] [Warning] lambda_l1 is set=1.1559279466613558e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1559279466613558e-05
# [LightGBM] [Warning] bagging_fraction is set=0.9179409262715671, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9179409262715671
# [LightGBM] [Warning] lambda_l2 is set=5.688277914371046e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.688277914371046e-08
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.27126134668335733, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.27126134668335733
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.3003892741622, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.3003892741622
# [LightGBM] [Warning] lambda_l1 is set=1.1559279466613558e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1559279466613558e-05
# [LightGBM] [Warning] bagging_fraction is set=0.9179409262715671, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9179409262715671
# [LightGBM] [Warning] lambda_l2 is set=5.688277914371046e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.688277914371046e-08
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# MAE: 233192.40712094767
#
# [LightGBM] [Warning] feature_fraction is set=0.33751310372237586, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.33751310372237586
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=92 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=8.45234143762848, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.45234143762848
# [LightGBM] [Warning] lambda_l1 is set=0.03143035477072983, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03143035477072983
# [LightGBM] [Warning] bagging_fraction is set=0.975231809340937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.975231809340937
# [LightGBM] [Warning] lambda_l2 is set=2.093078387213106e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.093078387213106e-05
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.33751310372237586, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.33751310372237586
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=92 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=8.45234143762848, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.45234143762848
# [LightGBM] [Warning] lambda_l1 is set=0.03143035477072983, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03143035477072983
# [LightGBM] [Warning] bagging_fraction is set=0.975231809340937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.975231809340937
# [LightGBM] [Warning] lambda_l2 is set=2.093078387213106e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.093078387213106e-05
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# MAE: 224412.78535719155
#
# [LightGBM] [Warning] feature_fraction is set=0.21370323398668717, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21370323398668717
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=7.537428935341812, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.537428935341812
# [LightGBM] [Warning] lambda_l1 is set=3.732945461077989e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.732945461077989e-06
# [LightGBM] [Warning] bagging_fraction is set=0.951702482962218, subsample=1.0 will be ignored. Current value: bagging_fraction=0.951702482962218
# [LightGBM] [Warning] lambda_l2 is set=4.471719655024769e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.471719655024769e-08
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.21370323398668717, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21370323398668717
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=7.537428935341812, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.537428935341812
# [LightGBM] [Warning] lambda_l1 is set=3.732945461077989e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.732945461077989e-06
# [LightGBM] [Warning] bagging_fraction is set=0.951702482962218, subsample=1.0 will be ignored. Current value: bagging_fraction=0.951702482962218
# [LightGBM] [Warning] lambda_l2 is set=4.471719655024769e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.471719655024769e-08
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# MAE: 213044.76674989593

# %%
# С выбросом
# {'learning_rate': 0.6557885350814743,
#  'lambda_l1': 0.037706634624958206,
#  'lambda_l2': 1.0400456820426082e-07,
#  'min_gain_to_split': 7.643743486585145,
#  'num_leaves': 84,
#  'feature_fraction': 0.08119108264276928,
#  'bagging_fraction': 0.9927172037242908,
#  'bagging_freq': 6,
#  'min_child_samples': 87,
#  'min_data_in_leaf': 5}
study_LGB.best_params
# Out:
# {'learning_rate': 0.6557885350814743,
#  'lambda_l1': 0.037706634624958206,
#  'lambda_l2': 1.0400456820426082e-07,
#  'min_gain_to_split': 7.643743486585145,
#  'num_leaves': 84,
#  'feature_fraction': 0.08119108264276928,
#  'bagging_fraction': 0.9927172037242908,
#  'bagging_freq': 6,
#  'min_child_samples': 87,
#  'min_data_in_leaf': 5}

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    )  
model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
prediction1d = model1d.predict(n=90, future_covariates=series_1d_future_covariates)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.08119108264276928, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08119108264276928
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=7.643743486585145, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.643743486585145
# [LightGBM] [Warning] lambda_l1 is set=0.037706634624958206, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.037706634624958206
# [LightGBM] [Warning] bagging_fraction is set=0.9927172037242908, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9927172037242908
# [LightGBM] [Warning] lambda_l2 is set=1.0400456820426082e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0400456820426082e-07
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
df_prediction1d = prediction1d.pd_dataframe()
df_prediction1d[df_prediction1d["RUB"]>0] = 0

# %%
series_1d_val.plot()
prediction1d.plot(label='forecast', low_quantile=0.05, high_quantile=0.95)
plt.legend()

# %%
# Настройка ARIMA модели на пиковые платежи.
# AUTOArima построена поверх библиотеки pmdarima для python
# Все шаги аналогичны

# %%
#Делаем шаг по времени 7 дней
train_6_7d = train_6.reset_index().groupby(pd.Grouper(key='Date', freq='7D', how='sum', closed='left')).sum()
train_6_7d = train_6_7d.loc["2019-07-30":]

# %%
sns.lineplot(data=train_6_7d)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(
    train_6_7d.pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(get_month)
    .pipe(get_season)
)
# Out:
#                      RUB  Holidays  Number_of_week_in_year  \
# Date
# 2019-07-31 -4.671491e+04         0                      31
# 2019-08-07 -1.809109e+05         0                      32
# 2019-08-14 -3.859053e+05         0                      33
# 2019-08-21 -1.288535e+06         0                      34
# 2019-08-28 -2.968270e+06         0                      35
# ...                  ...       ...                     ...
# 2020-12-02 -1.783439e+03         0                      49
# 2020-12-09 -2.029097e+05         0                      50
# 2020-12-16 -8.341146e+03         0                      51
# 2020-12-23 -2.872760e+07         0                      52
# 2020-12-30 -3.441478e+05         0                      53
#
#             Number_of_week_in_month  Month  Season
# Date
# 2019-07-31                        5      7       3
# 2019-08-07                        1      8       3
# 2019-08-14                        2      8       3
# 2019-08-21                        3      8       3
# 2019-08-28                        4      8       3
# ...                             ...    ...     ...
# 2020-12-02                        0     12       1
# 2020-12-09                        1     12       1
# 2020-12-16                        2     12       1
# 2020-12-23                        3     12       1
# 2020-12-30                        4     12       1
#
# [75 rows x 6 columns]

# %%
val_6_7d = val_6_1d["2021-01-06":]["RUB"].reset_index().groupby(pd.Grouper(key='Date', freq='7D', how='sum', closed='left')).sum()

# %%
(
    val_6_7d.pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(get_month)
    .pipe(get_season)
)
# Out:
#                      RUB  Holidays  Number_of_week_in_year  \
# Date
# 2021-01-06  0.000000e+00         1                       1
# 2021-01-13 -9.982070e+04         0                       2
# 2021-01-20 -2.145696e+06         0                       3
# 2021-01-27 -5.458383e+06         0                       4
# 2021-02-03 -1.089172e+05         0                       5
# 2021-02-10 -1.212536e+05         0                       6
# 2021-02-17 -4.482502e+05         0                       7
# 2021-02-24 -8.414086e+06         0                       8
# 2021-03-03 -5.020778e+05         0                       9
# 2021-03-10 -1.391880e+05         0                      10
# 2021-03-17 -4.347452e+05         0                      11
# 2021-03-24 -7.098109e+06         0                      12
# 2021-03-31 -1.327575e+06         0                      13
# 2021-04-07  0.000000e+00         0                      14
# 2021-04-14  0.000000e+00         0                      15
# 2021-04-21  0.000000e+00         0                      16
# 2021-04-28  0.000000e+00         0                      17
# 2021-05-05  0.000000e+00         0                      18
# 2021-05-12  0.000000e+00         0                      19
# 2021-05-19  0.000000e+00         0                      20
# 2021-05-26  0.000000e+00         0                      21
# 2021-06-02  0.000000e+00         0                      22
# 2021-06-09  0.000000e+00         0                      23
# 2021-06-16  0.000000e+00         0                      24
# 2021-06-23  0.000000e+00         0                      25
# 2021-06-30  0.000000e+00         0                      26
# 2021-07-07  0.000000e+00         0                      27
# 2021-07-14  0.000000e+00         0                      28
# 2021-07-21  0.000000e+00         0                      29
# 2021-07-28  0.000000e+00         0                      30
# 2021-08-04  0.000000e+00         0                      31
# 2021-08-11  0.000000e+00         0                      32
# 2021-08-18  0.000000e+00         0                      33
# 2021-08-25  0.000000e+00         0                      34
#
#             Number_of_week_in_month  Month  Season
# Date
# 2021-01-06                        1      1       1
# 2021-01-13                        2      1       1
# 2021-01-20                        3      1       1
# 2021-01-27                        4      1       1
# 2021-02-03                        1      2       1
# 2021-02-10                        2      2       1
# 2021-02-17                        3      2       1
# 2021-02-24                        4      2       1
# 2021-03-03                        1      3       2
# 2021-03-10                        2      3       2
# 2021-03-17                        3      3       2
# 2021-03-24                        4      3       2
# 2021-03-31                        5      3       2
# 2021-04-07                        1      4       2
# 2021-04-14                        2      4       2
# 2021-04-21                        3      4       2
# 2021-04-28                        4      4       2
# 2021-05-05                        1      5       2
# 2021-05-12                        2      5       2
# 2021-05-19                        3      5       2
# 2021-05-26                        4      5       2
# 2021-06-02                        0      6       3
# 2021-06-09                        1      6       3
# 2021-06-16                        2      6       3
# 2021-06-23                        3      6       3
# 2021-06-30                        4      6       3
# 2021-07-07                        1      7       3
# 2021-07-14                        2      7       3
# 2021-07-21                        3      7       3
# 2021-07-28                        4      7       3
# 2021-08-04                        1      8       3
# 2021-08-11                        2      8       3
# 2021-08-18                        3      8       3
# 2021-08-25                        4      8       3

# %%
train_6_7d_reindex = train_6_7d["RUB"].reset_index(inplace=False)
train_6_7d_covariates = train_6_7d.drop("RUB", inplace=False, axis=1).reset_index()

val_6_7d_reindex = val_6_7d.loc["2021-01-01":"2021-03-31","RUB"].reset_index(inplace=False) #["RUB"]
val_6_7d_covariates = val_6_7d.drop("RUB", inplace=False, axis=1).reset_index()

# %%
total_6_7d = pd.concat([train_6_7d, val_6_7d.loc["2021-01-01":"2021-03-31"]])
total_6_7d_reindex = total_6_7d["RUB"].reset_index(inplace=False)

# %%
series_7d_total = TimeSeries.from_dataframe(total_6_7d_reindex, time_col='Date', value_cols='RUB', freq='7d') #, fill_missing_dates=False

# %%
covariates_7d = pd.concat([train_6_7d_covariates, val_6_7d_covariates])

# %%
series_7d_train = TimeSeries.from_dataframe(train_6_7d_reindex, time_col='Date', value_cols='RUB', freq='7d', fill_missing_dates=True)
series_7d_val = TimeSeries.from_dataframe(val_6_7d_reindex, time_col='Date', value_cols='RUB', freq='7d', fill_missing_dates=True)

# %%
list(train_6_7d_covariates.columns.values)
# Out:
# ['Date',
#  'Holidays',
#  'Number_of_week_in_year',
#  'Number_of_week_in_month',
#  'Month',
#  'Season']

# %%
series_7d_future_covariates = TimeSeries.from_dataframe(
    covariates_7d,
    time_col="Date",
    value_cols=[
        "Holidays",
        "Number_of_week_in_year",
        "Number_of_week_in_month",
        "Month",
        "Season",
    ],
    freq="7d",
    fill_missing_dates=True,
)

# %%
train_7d_split = series_7d_train
val_7d_split = series_7d_val

# %%
model7d = AutoARIMA()
model7d.fit(train_7d_split, future_covariates=series_7d_future_covariates) # future_covariates=series_7d_future_covariates
prediction7d = model7d.predict(n=13, future_covariates=series_7d_future_covariates) # future_covariates=series_7d_future_covariates

# %%
val_7d_split.plot()
prediction7d.plot(label='forecast', low_quantile=0.05, high_quantile=0.95)
plt.legend()

# %%
mean_absolute_error(val_7d_split.pd_dataframe(), prediction7d.pd_dataframe())
# Out:
# 1693114.2762273499

# %%
df_prediction7d = prediction7d.pd_dataframe()

# %%
df_prediction1d
# Out:
# component             RUB
# Date
# 2021-01-01       0.000000
# 2021-01-02       0.000000
# 2021-01-03       0.000000
# 2021-01-04 -111067.947116
# 2021-01-05 -147182.097504
# ...                   ...
# 2021-03-27       0.000000
# 2021-03-28       0.000000
# 2021-03-29       0.000000
# 2021-03-30  -56403.802713
# 2021-03-31 -268085.160802
#
# [90 rows x 1 columns]

# %%
df_prediction7d.resample("1D").sum()# + df_prediction1d
# Out:
# component            RUB
# Date
# 2021-01-06  9.253802e+05
# 2021-01-07  0.000000e+00
# 2021-01-08  0.000000e+00
# 2021-01-09  0.000000e+00
# 2021-01-10  0.000000e+00
# ...                  ...
# 2021-03-27  0.000000e+00
# 2021-03-28  0.000000e+00
# 2021-03-29  0.000000e+00
# 2021-03-30  0.000000e+00
# 2021-03-31 -3.201299e+06
#
# [85 rows x 1 columns]

# %%
df_prediction7d_resampled = pd.merge(df_prediction7d.resample("1D").sum(), first_quarter, how='outer', left_index=True, right_index=True).fillna(0).loc[:"2021-03-31"][["RUB_x"]]

# %%
# Валид из отборочного этапа давал 1026000 (для другого валид. ряда)

# Здесь попробуем более простое решение - просто среднее двух моделей.
mean_absolute_error(val_6_1d_reindex["RUB"], (df_prediction1d["RUB"] + df_prediction7d_resampled["RUB_x"])/2.0)
# Out:
# 188484.96345126862

# %%
val_df = pd.DataFrame()
val_df.index = df_prediction1d["RUB"].index
val_df["y"] = val_6_1d_reindex["RUB"].values
val_df["yhat"] = ((df_prediction1d["RUB"] + df_prediction7d_resampled["RUB_x"])/2.0)

# %%
BU6_group_stage = pd.read_csv("train_6_ans_ts.csv", usecols=[1,2])
BU6_group_stage.set_index("Дата транзакции", inplace=True)
BU6_group_stage.index.name = "Date"

# %%
val_df["yhat_groupstage"] = BU6_group_stage.loc[:"2021-03-31", "Сумма в RUB"].values

# %%
BU6_group_stage.loc[:"2021-03-31", "Сумма в RUB"]
# Out:
# Date
# 2021-01-01   -3.356157e+00
# 2021-01-02   -3.356157e+00
# 2021-01-03   -3.356157e+00
# 2021-01-04   -1.084487e+01
# 2021-01-05   -3.192175e+00
#                   ...
# 2021-03-27   -3.311735e+00
# 2021-03-28   -3.311735e+00
# 2021-03-29   -2.356820e+02
# 2021-03-30   -3.292386e+00
# 2021-03-31   -3.201792e+06
# Name: Сумма в RUB, Length: 90, dtype: float64

# %%
val_df
# Out:
#                        y          yhat  yhat_groupstage
# Date
# 2021-01-01  0.000000e+00  0.000000e+00    -3.356157e+00
# 2021-01-02  0.000000e+00  0.000000e+00    -3.356157e+00
# 2021-01-03  0.000000e+00  0.000000e+00    -3.356157e+00
# 2021-01-04  0.000000e+00 -5.553397e+04    -1.084487e+01
# 2021-01-05  0.000000e+00 -7.359105e+04    -3.192175e+00
# ...                  ...           ...              ...
# 2021-03-27  0.000000e+00  0.000000e+00    -3.311735e+00
# 2021-03-28  0.000000e+00  0.000000e+00    -3.311735e+00
# 2021-03-29  0.000000e+00  0.000000e+00    -2.356820e+02
# 2021-03-30  0.000000e+00 -2.820190e+04    -3.292386e+00
# 2021-03-31 -1.327575e+06 -1.734692e+06    -3.201792e+06
#
# [90 rows x 3 columns]

# %%
# y - истинное значение, yhat - значение новой модели, yhat_groupstage - значения старой модели. Качественно почти совпадают.
sns.lineplot(data=val_df)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mean_absolute_error(val_6_1d_reindex["RUB"], val_df["yhat_groupstage"])
# Out:
# 387706.1061633216

# %%
##############################################################################################################################################################################################

# %%
# Refit на total

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    ) 
model1d.fit(series_1d_total, future_covariates=series_1d_future_covariates)
prediction1d_total = model1d.predict(n=91, future_covariates=series_1d_future_covariates)
df_prediction1d_total = prediction1d_total.pd_dataframe()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.08119108264276928, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08119108264276928
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=7.643743486585145, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.643743486585145
# [LightGBM] [Warning] lambda_l1 is set=0.037706634624958206, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.037706634624958206
# [LightGBM] [Warning] bagging_fraction is set=0.9927172037242908, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9927172037242908
# [LightGBM] [Warning] lambda_l2 is set=1.0400456820426082e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0400456820426082e-07
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
df_prediction1d_total[df_prediction1d_total["RUB"]>0] = 0

# %%
model7d = AutoARIMA()
model7d.fit(series_7d_total, future_covariates=series_7d_future_covariates) 
prediction7d_total = model7d.predict(n=13, future_covariates=series_7d_future_covariates) 
df_prediction7d_total = prediction7d_total.pd_dataframe()

# %%
df_prediction7d_total[df_prediction7d_total["RUB"]>0] = 0

# %%
df_prediction7d_total_resampled = pd.merge(df_prediction7d_total.resample("1D").sum(), first_quarter, how='outer', left_index=True, right_index=True).fillna(0).loc["2021-04-01":"2021-06-30"][["RUB_x"]]

# %%
train_6_ans_play_off = pd.DataFrame()
train_6_ans_play_off["Дата транзакции"] = pd.date_range(start="2021-04-01", end="2021-06-30", freq="1D")
train_6_ans_play_off["Сумма в RUB"] = ((df_prediction1d_total["RUB"] + df_prediction7d_total_resampled["RUB_x"])/2.0).values
train_6_ans_play_off["Сумма в RUB"] = train_6_ans_play_off["Сумма в RUB"].groupby(train_6_ans_play_off["Дата транзакции"].dt.month).cumsum().values

train_6_ans_play_off["Месяц"] = train_6_ans_play_off["Дата транзакции"].dt.month
train_6_ans_play_off["БЕ"] = 6

# %%
train_6_ans_play_off
# Out:
#    Дата транзакции   Сумма в RUB  Месяц  БЕ
# 0       2021-04-01  0.000000e+00      4   6
# 1       2021-04-02  0.000000e+00      4   6
# 2       2021-04-03 -9.608619e+03      4   6
# 3       2021-04-04 -6.092461e+04      4   6
# 4       2021-04-05 -1.663732e+05      4   6
# ..             ...           ...    ...  ..
# 86      2021-06-26 -3.828821e+06      6   6
# 87      2021-06-27 -3.828821e+06      6   6
# 88      2021-06-28 -3.828821e+06      6   6
# 89      2021-06-29 -3.828821e+06      6   6
# 90      2021-06-30 -5.400632e+06      6   6
#
# [91 rows x 4 columns]

# %%
train_6_ans_play_off.to_csv("train_6_ans_play_off.csv")
