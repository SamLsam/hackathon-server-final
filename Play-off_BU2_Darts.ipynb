# %% [raw]
# Привет!
# В преддверии финала хотели бы поделиться обратной связью от экспертов:
#
# Всем спасибо за проделанную работу и предоставленные решения.
#
# Мы решили выдать данные за 1 квартал 21 года, чтобы у вас была возможность
# самим оценить работу моделей и скорректировать некоторые моменты.
# По окончании данного этапа мы ожидаем от вас реализацию ваших идей,
# прогноз на 2 квартал 21 года, а также твердый и четкий ответ, на вопрос о том,
# могут ли предоставленные дополнительные данные о БЕ номер 3 и 5 помочь улучшить точность моделей.
#
# Пожалуйста, по итогам своей работы предоставьте файл с прогнозами в виде кумулятивных сумм,
# аналогично тому, как это представлено в файле с объяснением подсчета метрики.

# %% [raw]
# Фидбэк по вашему решению:
# Советуем углубить анализ в контексте определения дней транзакции,
# поискать закономерности, создать дополнительные признаки и усложнить модели.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import holidays
import calendar
import datetime

# %%
from sklearn.metrics import mean_absolute_error

# %%
import optuna
from darts import TimeSeries
from darts.models import AutoARIMA, LightGBMModel

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.set(font_scale=1.25)

# %%
data = pd.read_csv("train.csv")

# %%
train = pd.DataFrame()
train["Unit"] = data["БЕ"]
train["Date"] = data["Дата транзакции"]
train["RUB"] = data["Сумма в RUB"]

# %%
train_0 = train[train["Unit"]==0][["Date", "RUB"]]
train_0.set_index(pd.to_datetime(train_0["Date"]), inplace=True)
train_0.drop(["Date"], inplace=True, axis=1)

train_1 = train[train["Unit"]==1][["Date", "RUB"]]
train_1.set_index(pd.to_datetime(train_1["Date"]), inplace=True)
train_1.drop(["Date"], inplace=True, axis=1)

train_2 = train[train["Unit"]==2][["Date", "RUB"]]
train_2.set_index(pd.to_datetime(train_2["Date"]), inplace=True)
train_2.drop(["Date"], inplace=True, axis=1)

train_3 = train[train["Unit"]==3][["Date", "RUB"]]
train_3.set_index(pd.to_datetime(train_3["Date"]), inplace=True)
train_3.drop(["Date"], inplace=True, axis=1)

train_4 = train[train["Unit"]==4][["Date", "RUB"]]
train_4.set_index(pd.to_datetime(train_4["Date"]), inplace=True)
train_4.drop(["Date"], inplace=True, axis=1)

train_5 = train[train["Unit"]==5][["Date", "RUB"]]
train_5.set_index(pd.to_datetime(train_5["Date"]), inplace=True)
train_5.drop(["Date"], inplace=True, axis=1)

train_6 = train[train["Unit"]==6][["Date", "RUB"]]
train_6.set_index(pd.to_datetime(train_6["Date"]), inplace=True)
train_6.drop(["Date"], inplace=True, axis=1)

# %%
train_2.tail()
# Out:
#                      RUB
# Date
# 2020-11-25 -3.931631e+06
# 2020-12-09 -3.151188e+06
# 2020-12-16 -2.368075e+06
# 2020-12-23 -5.822107e+06
# 2020-12-30 -4.076472e+06

# %%
train_2_1d = train_2.resample('1D').sum()

train_2_1d = pd.concat([train_2_1d, pd.DataFrame([0], columns=["RUB"], index=[pd.to_datetime("2020-12-31")])])
train_2_1d.index.name = "Date"

# %%
train_2_1d.tail()
# Out:
#                      RUB
# Date
# 2020-12-27  0.000000e+00
# 2020-12-28  0.000000e+00
# 2020-12-29  0.000000e+00
# 2020-12-30 -4.076472e+06
# 2020-12-31  0.000000e+00

# %%
sns.lineplot(data=train_2_1d)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##############################################################################################################################################################################################

# %%
### Generalized valid data ###
# Данные, выданные к финалу - первый квартал 2021 года
data = pd.read_excel("1кв2021_1.xlsx")

# %%
# Работаем аналагично train
val = pd.DataFrame()
val["Unit"] = data["БЕ"]
val["Date"] = data["Расчет ликвидности - дата"]
val["RUB"] = data["Сумма в валюте транзакции"]

# %%
val_0 = val[val["Unit"]==0][["Date", "RUB"]]
val_0.set_index(pd.to_datetime(val_0["Date"], dayfirst=True), inplace=True)
val_0.drop("Date", inplace=True, axis=1)

val_1 = val[val["Unit"]==1][["Date", "RUB"]]
val_1.set_index(pd.to_datetime(val_1["Date"], dayfirst=True), inplace=True)
val_1.drop("Date", inplace=True, axis=1)

val_2 = val[val["Unit"]==2][["Date", "RUB"]]
val_2.set_index(pd.to_datetime(val_2["Date"], dayfirst=True), inplace=True)
val_2.drop("Date", inplace=True, axis=1)

val_3 = val[val["Unit"]==3][["Date", "RUB"]]
val_3.set_index(pd.to_datetime(val_3["Date"], dayfirst=True), inplace=True)
val_3.drop("Date", inplace=True, axis=1)

val_4 = val[val["Unit"]==4][["Date", "RUB"]]
val_4.set_index(pd.to_datetime(val_4["Date"], dayfirst=True), inplace=True)
val_4.drop("Date", inplace=True, axis=1)

val_5 = val[val["Unit"]==5][["Date", "RUB"]]
val_5.set_index(pd.to_datetime(val_5["Date"], dayfirst=True), inplace=True)
val_5.drop("Date", inplace=True, axis=1)

val_6 = val[val["Unit"]==6][["Date", "RUB"]]
val_6.set_index(pd.to_datetime(val_6["Date"], dayfirst=True), inplace=True)
val_6.drop("Date", inplace=True, axis=1)

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*B1oKvhOuYoTdFEnwl8SEpg.png">

# %% [raw]
# Рисунок 1 - Схематичное изображение future covariates на временном интревале.
# Источник: https://medium.com/unit8-machine-learning-publication/time-series-forecasting-using-past-and-future-external-data-with-darts-1f0539585993

# %%
first_quarter = pd.DataFrame()
first_quarter.index = pd.date_range(start='1/1/2021', end='31/08/2021')
first_quarter["RUB"] = 0

val_0_1d = pd.DataFrame()
val_0_1d.index = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_0_1d.index.name = "Date"
val_0_1d["RUB"] = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_1_1d = pd.DataFrame()
val_1_1d.index = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_1_1d.index.name = "Date"
val_1_1d["RUB"] = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_2_1d = pd.DataFrame()
val_2_1d.index = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_2_1d.index.name = "Date"
val_2_1d["RUB"] = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_3_1d = pd.DataFrame()
val_3_1d.index = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_3_1d.index.name = "Date"
val_3_1d["RUB"] = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_4_1d = pd.DataFrame()
val_4_1d.index = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_4_1d.index.name = "Date"
val_4_1d["RUB"] = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_5_1d = pd.DataFrame()
val_5_1d.index = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_5_1d.index.name = "Date"
val_5_1d["RUB"] = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_6_1d = pd.DataFrame()
val_6_1d.index = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_6_1d.index.name = "Date"
val_6_1d["RUB"] = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

# %%
##############################################################################################################################################################################################

# %%
# Feature engineering
# Добавляем регрессоры

# %%
def dayofweek(df):
    df["Dayofweek"] = df.index.dayofweek
    return df

# %%
def get_holidays(df):
    df["Holidays"] = pd.Series(df.index).apply(lambda x: holidays.CountryHoliday('RUS').get(x)).values
    df["Holidays"] = df["Holidays"].astype('bool').astype('int')
    return df

# %%
def number_of_week_in_year(df):
    df["Number_of_week_in_year"] = df.index.isocalendar().week
    df["Number_of_week_in_year"] = df["Number_of_week_in_year"].astype(int)
    return df

# %%
def number_of_week_in_month(df):
    def week_of_month(tgtdate):
        days_this_month = calendar.mdays[tgtdate.month]
        for i in range(1, days_this_month):
            d = datetime.datetime(tgtdate.year, tgtdate.month, i)
            if d.day - d.weekday() > 0:
                startdate = d
                break
        return (tgtdate - startdate).days //7 + 1
    df["Number_of_week_in_month"] = df.index.to_series().apply(week_of_month)
    return df

# %%
def number_of_day_in_month(df):
    df["Number_of_day_in_month"] = df.index.day
    return df

# %%
def number_of_day_in_year(df):
    df["Number_of_day_in_year"] = df.index.dayofyear
    return df

# %%
def get_month(df):
    df["Month"] = df.index.month
    return df

# %%
def get_season(df):
    df["Season"] = df.index.month%12 // 3 + 1
    return df

# %%
def payday(df, payday):
    df["Payday"] = 0 
    df.loc[df.index.day_name() == payday, "Payday"] = 1
    return df

# %%
(
    train_2_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)

    .pipe(payday, payday="Wednesday")
)
# Out:
#                      RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2017-01-11 -4.402282e+06          2         0                       2
# 2017-01-12  0.000000e+00          3         0                       2
# 2017-01-13  0.000000e+00          4         0                       2
# 2017-01-14  0.000000e+00          5         0                       2
# 2017-01-15  0.000000e+00          6         0                       2
# ...                  ...        ...       ...                     ...
# 2020-12-27  0.000000e+00          6         0                      52
# 2020-12-28  0.000000e+00          0         0                      53
# 2020-12-29  0.000000e+00          1         0                      53
# 2020-12-30 -4.076472e+06          2         0                      53
# 2020-12-31  0.000000e+00          3         1                      53
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2017-01-11                        2                      11
# 2017-01-12                        2                      12
# 2017-01-13                        2                      13
# 2017-01-14                        2                      14
# 2017-01-15                        2                      15
# ...                             ...                     ...
# 2020-12-27                        3                      27
# 2020-12-28                        4                      28
# 2020-12-29                        4                      29
# 2020-12-30                        4                      30
# 2020-12-31                        4                      31
#
#             Number_of_day_in_year  Month  Season  Payday
# Date
# 2017-01-11                     11      1       1       1
# 2017-01-12                     12      1       1       0
# 2017-01-13                     13      1       1       0
# 2017-01-14                     14      1       1       0
# 2017-01-15                     15      1       1       0
# ...                           ...    ...     ...     ...
# 2020-12-27                    362     12       1       0
# 2020-12-28                    363     12       1       0
# 2020-12-29                    364     12       1       0
# 2020-12-30                    365     12       1       1
# 2020-12-31                    366     12       1       0
#
# [1451 rows x 10 columns]

# %%
(
    val_2_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)
    .pipe(payday, payday="Wednesday")
)
# Out:
#             RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2021-01-01  0.0          4         1                      53
# 2021-01-02  0.0          5         1                      53
# 2021-01-03  0.0          6         1                      53
# 2021-01-04  0.0          0         1                       1
# 2021-01-05  0.0          1         1                       1
# ...         ...        ...       ...                     ...
# 2021-08-27  0.0          4         0                      34
# 2021-08-28  0.0          5         0                      34
# 2021-08-29  0.0          6         0                      34
# 2021-08-30  0.0          0         0                      35
# 2021-08-31  0.0          1         0                      35
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2021-01-01                        0                       1
# 2021-01-02                        0                       2
# 2021-01-03                        0                       3
# 2021-01-04                        1                       4
# 2021-01-05                        1                       5
# ...                             ...                     ...
# 2021-08-27                        4                      27
# 2021-08-28                        4                      28
# 2021-08-29                        4                      29
# 2021-08-30                        5                      30
# 2021-08-31                        5                      31
#
#             Number_of_day_in_year  Month  Season  Payday
# Date
# 2021-01-01                      1      1       1       0
# 2021-01-02                      2      1       1       0
# 2021-01-03                      3      1       1       0
# 2021-01-04                      4      1       1       0
# 2021-01-05                      5      1       1       0
# ...                           ...    ...     ...     ...
# 2021-08-27                    239      8       3       0
# 2021-08-28                    240      8       3       0
# 2021-08-29                    241      8       3       0
# 2021-08-30                    242      8       3       0
# 2021-08-31                    243      8       3       0
#
# [243 rows x 10 columns]

# %%
list(train_2_1d.columns.values)
# Out:
# ['RUB',
#  'Dayofweek',
#  'Holidays',
#  'Number_of_week_in_year',
#  'Number_of_week_in_month',
#  'Number_of_day_in_month',
#  'Number_of_day_in_year',
#  'Month',
#  'Season',
#  'Payday']

# %%
##############################################################################################################################################################################################

# %%
# Darts модели

# %%
train_2_1d_reindex = train_2_1d["RUB"].reset_index(inplace=False)
train_2_1d_covariates = train_2_1d.drop("RUB", inplace=False, axis=1).reset_index()

val_2_1d_reindex = val_2_1d.loc["2021-01-01":"2021-03-31","RUB"].reset_index(inplace=False) #["RUB"]
val_2_1d_covariates = val_2_1d.drop("RUB", inplace=False, axis=1).reset_index()

# %%
total_2_1d = pd.concat([train_2_1d, val_2_1d.loc["2021-01-01":"2021-03-31"]])
total_2_1d_reindex = total_2_1d["RUB"].reset_index(inplace=False)

# %%
series_1d_total = TimeSeries.from_dataframe(total_2_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
covariates = pd.concat([train_2_1d_covariates, val_2_1d_covariates])

# %%
series_1d_train = TimeSeries.from_dataframe(train_2_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)
series_1d_val = TimeSeries.from_dataframe(val_2_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
series_1d_future_covariates = TimeSeries.from_dataframe(
    covariates,
    time_col="Date",
    value_cols=[
        "Dayofweek",
        "Holidays",
        "Number_of_week_in_year",
        "Number_of_week_in_month",
        "Number_of_day_in_month",
        "Number_of_day_in_year",
        "Month",
        "Season",
        "Payday",
    ],
    freq="1d",
    fill_missing_dates=True,
)

# %%
train_1d_split, local_val_1d_split = series_1d_train.split_before(0.80)
val_1d_split = series_1d_val

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
def objective_LGB(trial):

    # 
    model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=trial.suggest_float("learning_rate", 1e-3, 1.0, log=True),
        lambda_l1=trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
        lambda_l2=trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
        min_gain_to_split=trial.suggest_float("min_gain_to_split", 0, 10.0),
        num_leaves=trial.suggest_int("num_leaves", 8, 256),
        feature_fraction=trial.suggest_uniform("feature_fraction", 0.0001, 1.0),
        bagging_fraction=trial.suggest_uniform("bagging_fraction", 0.0001, 1.0),
        bagging_freq=trial.suggest_int("bagging_freq", 0, 30),
        min_child_samples=trial.suggest_int("min_child_samples", 1, 100),
        min_data_in_leaf=trial.suggest_int("min_data_in_leaf", 3, 100),
        feature_pre_filter=False
    )  

    model1d.fit(train_1d_split, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(local_val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    local_val = mean_absolute_error(local_val_1d_split.pd_dataframe(), fixed_prediction1d)
    

    model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    global_val = mean_absolute_error(val_1d_split.pd_dataframe(), fixed_prediction1d)
    

    val = np.mean([local_val, global_val])

    trial.set_user_attr("Valid_score", val)

    print(f"MAE: {val}\n")

    return val

# %%
study_LGB = optuna.create_study(direction="minimize")
study_LGB.optimize(objective_LGB, n_trials=300, gc_after_trial=True) #300 - можно и больше, но как показывает лог, этого более чем достаточно
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.5448757748370827, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5448757748370827
# [LightGBM] [Warning] min_data_in_leaf is set=95, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=95
# [LightGBM] [Warning] min_gain_to_split is set=0.06312749192765699, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.06312749192765699
# [LightGBM] [Warning] lambda_l1 is set=0.04748690060239335, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04748690060239335
# [LightGBM] [Warning] bagging_fraction is set=0.42525031972162886, subsample=1.0 will be ignored. Current value: bagging_fraction=0.42525031972162886
# [LightGBM] [Warning] lambda_l2 is set=4.431992274378612e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.431992274378612e-06
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.5448757748370827, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5448757748370827
# [LightGBM] [Warning] min_data_in_leaf is set=95, min_child_samples=99 will be ignored. Current value: min_data_in_leaf=95
# [LightGBM] [Warning] min_gain_to_split is set=0.06312749192765699, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.06312749192765699
# [LightGBM] [Warning] lambda_l1 is set=0.04748690060239335, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04748690060239335
# [LightGBM] [Warning] bagging_fraction is set=0.42525031972162886, subsample=1.0 will be ignored. Current value: bagging_fraction=0.42525031972162886
# [LightGBM] [Warning] lambda_l2 is set=4.431992274378612e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.431992274378612e-06
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# MAE: 328586.1278695174
#
# [LightGBM] [Warning] feature_fraction is set=0.5838818026855978, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5838818026855978
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=81 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_gain_to_split is set=8.82147830999024, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.82147830999024
# [LightGBM] [Warning] lambda_l1 is set=5.797535516504556e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.797535516504556e-08
# [LightGBM] [Warning] bagging_fraction is set=0.7094683473245055, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7094683473245055
# [LightGBM] [Warning] lambda_l2 is set=0.00024071535139471868, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00024071535139471868
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.5838818026855978, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5838818026855978
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=81 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_gain_to_split is set=8.82147830999024, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.82147830999024
# [LightGBM] [Warning] lambda_l1 is set=5.797535516504556e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.797535516504556e-08
# [LightGBM] [Warning] bagging_fraction is set=0.7094683473245055, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7094683473245055
# [LightGBM] [Warning] lambda_l2 is set=0.00024071535139471868, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00024071535139471868
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# MAE: 265378.8848666434
#
# [LightGBM] [Warning] feature_fraction is set=0.5954897400616224, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5954897400616224
# [LightGBM] [Warning] min_data_in_leaf is set=86, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=86
# [LightGBM] [Warning] min_gain_to_split is set=8.68421518610597, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.68421518610597
# [LightGBM] [Warning] lambda_l1 is set=0.17929611825724615, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.17929611825724615
# [LightGBM] [Warning] bagging_fraction is set=0.2669449096075677, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2669449096075677
# [LightGBM] [Warning] lambda_l2 is set=1.5595105583119713e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5595105583119713e-05
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.5954897400616224, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5954897400616224
# [LightGBM] [Warning] min_data_in_leaf is set=86, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=86
# [LightGBM] [Warning] min_gain_to_split is set=8.68421518610597, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.68421518610597
# [LightGBM] [Warning] lambda_l1 is set=0.17929611825724615, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.17929611825724615
# [LightGBM] [Warning] bagging_fraction is set=0.2669449096075677, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2669449096075677
# [LightGBM] [Warning] lambda_l2 is set=1.5595105583119713e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5595105583119713e-05
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# MAE: 393797.88436293555
#
# [LightGBM] [Warning] feature_fraction is set=0.6699654454981511, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6699654454981511
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=9.425143641279503, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.425143641279503
# [LightGBM] [Warning] lambda_l1 is set=0.002246369417379237, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.002246369417379237
# [LightGBM] [Warning] bagging_fraction is set=0.4022522931267178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4022522931267178
# [LightGBM] [Warning] lambda_l2 is set=2.7997235439744777e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.7997235439744777e-07
# [LightGBM] [Warning] bagging_freq is set=12, subsample_freq=0 will be ignored. Current value: bagging_freq=12
# [LightGBM] [Warning] feature_fraction is set=0.6699654454981511, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6699654454981511
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=9.425143641279503, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.425143641279503
# [LightGBM] [Warning] lambda_l1 is set=0.002246369417379237, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.002246369417379237
# [LightGBM] [Warning] bagging_fraction is set=0.4022522931267178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4022522931267178
# [LightGBM] [Warning] lambda_l2 is set=2.7997235439744777e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.7997235439744777e-07
# [LightGBM] [Warning] bagging_freq is set=12, subsample_freq=0 will be ignored. Current value: bagging_freq=12
# MAE: 260768.4917528954
#
# [LightGBM] [Warning] feature_fraction is set=0.4443177890160395, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4443177890160395
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=36 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=8.207402603175996, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.207402603175996
# [LightGBM] [Warning] lambda_l1 is set=0.0002982649060360786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002982649060360786
# [LightGBM] [Warning] bagging_fraction is set=0.971426288418033, subsample=1.0 will be ignored. Current value: bagging_fraction=0.971426288418033
# [LightGBM] [Warning] lambda_l2 is set=3.582529177708903e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.582529177708903e-07
# [LightGBM] [Warning] bagging_freq is set=21, subsample_freq=0 will be ignored. Current value: bagging_freq=21
# [LightGBM] [Warning] feature_fraction is set=0.4443177890160395, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4443177890160395
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=36 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=8.207402603175996, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.207402603175996
# [LightGBM] [Warning] lambda_l1 is set=0.0002982649060360786, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002982649060360786
# [LightGBM] [Warning] bagging_fraction is set=0.971426288418033, subsample=1.0 will be ignored. Current value: bagging_fraction=0.971426288418033
# [LightGBM] [Warning] lambda_l2 is set=3.582529177708903e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.582529177708903e-07
# [LightGBM] [Warning] bagging_freq is set=21, subsample_freq=0 will be ignored. Current value: bagging_freq=21
# MAE: 340725.45099447225
#
# [LightGBM] [Warning] feature_fraction is set=0.11719578760763529, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11719578760763529
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=58 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=8.261291880926787, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.261291880926787
# [LightGBM] [Warning] lambda_l1 is set=2.629550461876063e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.629550461876063e-07
# [LightGBM] [Warning] bagging_fraction is set=0.03190386902444179, subsample=1.0 will be ignored. Current value: bagging_fraction=0.03190386902444179
# [LightGBM] [Warning] lambda_l2 is set=0.09708182226644531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09708182226644531
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.11719578760763529, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11719578760763529
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=58 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=8.261291880926787, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.261291880926787
# [LightGBM] [Warning] lambda_l1 is set=2.629550461876063e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.629550461876063e-07
# [LightGBM] [Warning] bagging_fraction is set=0.03190386902444179, subsample=1.0 will be ignored. Current value: bagging_fraction=0.03190386902444179
# [LightGBM] [Warning] lambda_l2 is set=0.09708182226644531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09708182226644531
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# MAE: 390577.8504690366
#
# [LightGBM] [Warning] feature_fraction is set=0.660880057746812, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.660880057746812
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=9 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] min_gain_to_split is set=3.205897341550088, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.205897341550088
# [LightGBM] [Warning] lambda_l1 is set=3.9715486130801565e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.9715486130801565e-06
# [LightGBM] [Warning] bagging_fraction is set=0.2028069418819194, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2028069418819194
# [LightGBM] [Warning] lambda_l2 is set=0.002197370783372866, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.002197370783372866
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] feature_fraction is set=0.660880057746812, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.660880057746812
# [LightGBM] [Warning] min_data_in_leaf is set=59, min_child_samples=9 will be ignored. Current value: min_data_in_leaf=59
# [LightGBM] [Warning] min_gain_to_split is set=3.205897341550088, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.205897341550088
# [LightGBM] [Warning] lambda_l1 is set=3.9715486130801565e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.9715486130801565e-06
# [LightGBM] [Warning] bagging_fraction is set=0.2028069418819194, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2028069418819194
# [LightGBM] [Warning] lambda_l2 is set=0.002197370783372866, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.002197370783372866
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# MAE: 506407.502345478
#
# [LightGBM] [Warning] feature_fraction is set=0.01306044448833295, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.01306044448833295
# [LightGBM] [Warning] min_data_in_leaf is set=70, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=70
# [LightGBM] [Warning] min_gain_to_split is set=4.663028318626158, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.663028318626158
# [LightGBM] [Warning] lambda_l1 is set=1.6878792073556943, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.6878792073556943
# [LightGBM] [Warning] bagging_fraction is set=0.372268085203746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.372268085203746
# [LightGBM] [Warning] lambda_l2 is set=6.743912542764215e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.743912542764215e-06
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# [LightGBM] [Warning] feature_fraction is set=0.01306044448833295, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.01306044448833295
# [LightGBM] [Warning] min_data_in_leaf is set=70, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=70
# [LightGBM] [Warning] min_gain_to_split is set=4.663028318626158, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.663028318626158
# [LightGBM] [Warning] lambda_l1 is set=1.6878792073556943, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.6878792073556943
# [LightGBM] [Warning] bagging_fraction is set=0.372268085203746, subsample=1.0 will be ignored. Current value: bagging_fraction=0.372268085203746
# [LightGBM] [Warning] lambda_l2 is set=6.743912542764215e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.743912542764215e-06
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# MAE: 547477.4264887414
#
# [LightGBM] [Warning] feature_fraction is set=0.3777583724201651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3777583724201651
# [LightGBM] [Warning] min_data_in_leaf is set=81, min_child_samples=35 will be ignored. Current value: min_data_in_leaf=81
# [LightGBM] [Warning] min_gain_to_split is set=0.14368954310408966, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.14368954310408966
# [LightGBM] [Warning] lambda_l1 is set=1.1262376703638947e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1262376703638947e-08
# [LightGBM] [Warning] bagging_fraction is set=0.01946014252469786, subsample=1.0 will be ignored. Current value: bagging_fraction=0.01946014252469786
# [LightGBM] [Warning] lambda_l2 is set=4.430103213182588e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.430103213182588e-05
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.3777583724201651, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3777583724201651
# [LightGBM] [Warning] min_data_in_leaf is set=81, min_child_samples=35 will be ignored. Current value: min_data_in_leaf=81
# [LightGBM] [Warning] min_gain_to_split is set=0.14368954310408966, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.14368954310408966
# [LightGBM] [Warning] lambda_l1 is set=1.1262376703638947e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1262376703638947e-08
# [LightGBM] [Warning] bagging_fraction is set=0.01946014252469786, subsample=1.0 will be ignored. Current value: bagging_fraction=0.01946014252469786
# [LightGBM] [Warning] lambda_l2 is set=4.430103213182588e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.430103213182588e-05
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# MAE: 733777.1706519704
#
# [LightGBM] [Warning] feature_fraction is set=0.5543118558973329, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5543118558973329
# [LightGBM] [Warning] min_data_in_leaf is set=73, min_child_samples=79 will be ignored. Current value: min_data_in_leaf=73
# [LightGBM] [Warning] min_gain_to_split is set=4.63323504572687, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.63323504572687
# [LightGBM] [Warning] lambda_l1 is set=6.7423601937394445e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.7423601937394445e-06
# [LightGBM] [Warning] bagging_fraction is set=0.4754772551885225, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4754772551885225
# [LightGBM] [Warning] lambda_l2 is set=6.608504725192068e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.608504725192068e-05
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# [LightGBM] [Warning] feature_fraction is set=0.5543118558973329, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5543118558973329
# [LightGBM] [Warning] min_data_in_leaf is set=73, min_child_samples=79 will be ignored. Current value: min_data_in_leaf=73
# [LightGBM] [Warning] min_gain_to_split is set=4.63323504572687, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.63323504572687
# [LightGBM] [Warning] lambda_l1 is set=6.7423601937394445e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.7423601937394445e-06
# [LightGBM] [Warning] bagging_fraction is set=0.4754772551885225, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4754772551885225
# [LightGBM] [Warning] lambda_l2 is set=6.608504725192068e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.608504725192068e-05
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# MAE: 344799.00242337806
#
# [LightGBM] [Warning] feature_fraction is set=0.9582490117884959, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9582490117884959
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=3 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=6.492852744842491, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.492852744842491
# [LightGBM] [Warning] lambda_l1 is set=0.004707637649898433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.004707637649898433
# [LightGBM] [Warning] bagging_fraction is set=0.6932813002239745, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6932813002239745
# [LightGBM] [Warning] lambda_l2 is set=2.3597598089210428e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3597598089210428e-08
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# [LightGBM] [Warning] feature_fraction is set=0.9582490117884959, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9582490117884959
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=3 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_gain_to_split is set=6.492852744842491, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.492852744842491
# [LightGBM] [Warning] lambda_l1 is set=0.004707637649898433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.004707637649898433
# [LightGBM] [Warning] bagging_fraction is set=0.6932813002239745, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6932813002239745
# [LightGBM] [Warning] lambda_l2 is set=2.3597598089210428e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3597598089210428e-08
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# MAE: 275820.30973147246
#
# [LightGBM] [Warning] feature_fraction is set=0.8249158170488124, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8249158170488124
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=62 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=9.812144639219897, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.812144639219897
# [LightGBM] [Warning] lambda_l1 is set=0.00023610500735345586, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00023610500735345586
# [LightGBM] [Warning] bagging_fraction is set=0.7056178740991897, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7056178740991897
# [LightGBM] [Warning] lambda_l2 is set=5.592404612176711, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.592404612176711
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# [LightGBM] [Warning] feature_fraction is set=0.8249158170488124, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8249158170488124
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=62 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=9.812144639219897, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.812144639219897
# [LightGBM] [Warning] lambda_l1 is set=0.00023610500735345586, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00023610500735345586
# [LightGBM] [Warning] bagging_fraction is set=0.7056178740991897, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7056178740991897
# [LightGBM] [Warning] lambda_l2 is set=5.592404612176711, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.592404612176711
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# MAE: 240696.72500061366
#
# [LightGBM] [Warning] feature_fraction is set=0.8272297929487533, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8272297929487533
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=55 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=9.810855514980942, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.810855514980942
# [LightGBM] [Warning] lambda_l1 is set=0.0003363559033293859, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0003363559033293859
# [LightGBM] [Warning] bagging_fraction is set=0.6507565125272097, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6507565125272097
# [LightGBM] [Warning] lambda_l2 is set=2.204405665285049, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.204405665285049
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.8272297929487533, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8272297929487533
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=55 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=9.810855514980942, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.810855514980942
# [LightGBM] [Warning] lambda_l1 is set=0.0003363559033293859, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0003363559033293859
# [LightGBM] [Warning] bagging_fraction is set=0.6507565125272097, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6507565125272097
# [LightGBM] [Warning] lambda_l2 is set=2.204405665285049, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.204405665285049
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 255882.70933127246
#
# [LightGBM] [Warning] feature_fraction is set=0.9453770412568385, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9453770412568385
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=64 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] min_gain_to_split is set=9.960955183761099, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.960955183761099
# [LightGBM] [Warning] lambda_l1 is set=9.06011078656136e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.06011078656136e-05
# [LightGBM] [Warning] bagging_fraction is set=0.675118107648927, subsample=1.0 will be ignored. Current value: bagging_fraction=0.675118107648927
# [LightGBM] [Warning] lambda_l2 is set=9.699203676117014, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.699203676117014
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.9453770412568385, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9453770412568385
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=64 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] min_gain_to_split is set=9.960955183761099, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.960955183761099
# [LightGBM] [Warning] lambda_l1 is set=9.06011078656136e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.06011078656136e-05
# [LightGBM] [Warning] bagging_fraction is set=0.675118107648927, subsample=1.0 will be ignored. Current value: bagging_fraction=0.675118107648927
# [LightGBM] [Warning] lambda_l2 is set=9.699203676117014, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.699203676117014
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 260857.7792871073
#
# [LightGBM] [Warning] feature_fraction is set=0.814186571362018, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.814186571362018
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=37 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] min_gain_to_split is set=6.9973659579109535, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.9973659579109535
# [LightGBM] [Warning] lambda_l1 is set=5.917310000324369e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.917310000324369e-05
# [LightGBM] [Warning] bagging_fraction is set=0.8849010046034119, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8849010046034119
# [LightGBM] [Warning] lambda_l2 is set=3.7985844252796728, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.7985844252796728
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.814186571362018, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.814186571362018
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=37 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] min_gain_to_split is set=6.9973659579109535, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.9973659579109535
# [LightGBM] [Warning] lambda_l1 is set=5.917310000324369e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.917310000324369e-05
# [LightGBM] [Warning] bagging_fraction is set=0.8849010046034119, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8849010046034119
# [LightGBM] [Warning] lambda_l2 is set=3.7985844252796728, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.7985844252796728
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 325974.97816067876
#
# [LightGBM] [Warning] feature_fraction is set=0.7846384863496956, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7846384863496956
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=21 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.7670434949838665, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.7670434949838665
# [LightGBM] [Warning] lambda_l1 is set=0.004047462597486627, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.004047462597486627
# [LightGBM] [Warning] bagging_fraction is set=0.6034802977692258, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6034802977692258
# [LightGBM] [Warning] lambda_l2 is set=0.11901435957169512, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11901435957169512
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.7846384863496956, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7846384863496956
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=21 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.7670434949838665, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.7670434949838665
# [LightGBM] [Warning] lambda_l1 is set=0.004047462597486627, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.004047462597486627
# [LightGBM] [Warning] bagging_fraction is set=0.6034802977692258, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6034802977692258
# [LightGBM] [Warning] lambda_l2 is set=0.11901435957169512, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11901435957169512
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# MAE: 283897.26246232376
#
# [LightGBM] [Warning] feature_fraction is set=0.8079161986639101, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8079161986639101
# [LightGBM] [Warning] min_data_in_leaf is set=46, min_child_samples=68 will be ignored. Current value: min_data_in_leaf=46
# [LightGBM] [Warning] min_gain_to_split is set=2.3156622562856266, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.3156622562856266
# [LightGBM] [Warning] lambda_l1 is set=1.0015129244053398e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0015129244053398e-05
# [LightGBM] [Warning] bagging_fraction is set=0.8276148681104325, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8276148681104325
# [LightGBM] [Warning] lambda_l2 is set=0.23481739642662075, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.23481739642662075
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# [LightGBM] [Warning] feature_fraction is set=0.8079161986639101, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8079161986639101
# [LightGBM] [Warning] min_data_in_leaf is set=46, min_child_samples=68 will be ignored. Current value: min_data_in_leaf=46
# [LightGBM] [Warning] min_gain_to_split is set=2.3156622562856266, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.3156622562856266
# [LightGBM] [Warning] lambda_l1 is set=1.0015129244053398e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0015129244053398e-05
# [LightGBM] [Warning] bagging_fraction is set=0.8276148681104325, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8276148681104325
# [LightGBM] [Warning] lambda_l2 is set=0.23481739642662075, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.23481739642662075
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# MAE: 268155.62976998027
#
# [LightGBM] [Warning] feature_fraction is set=0.32694340248201104, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.32694340248201104
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=7.4377370194389005, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.4377370194389005
# [LightGBM] [Warning] lambda_l1 is set=0.03822407402679285, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03822407402679285
# [LightGBM] [Warning] bagging_fraction is set=0.8264265191032061, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8264265191032061
# [LightGBM] [Warning] lambda_l2 is set=0.009076492061163916, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.009076492061163916
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.32694340248201104, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.32694340248201104
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=7.4377370194389005, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.4377370194389005
# [LightGBM] [Warning] lambda_l1 is set=0.03822407402679285, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03822407402679285
# [LightGBM] [Warning] bagging_fraction is set=0.8264265191032061, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8264265191032061
# [LightGBM] [Warning] lambda_l2 is set=0.009076492061163916, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.009076492061163916
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# MAE: 251631.73446024457
#
# [LightGBM] [Warning] feature_fraction is set=0.3093808232754206, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3093808232754206
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=45 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] min_gain_to_split is set=7.211501172815531, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.211501172815531
# [LightGBM] [Warning] lambda_l1 is set=2.7380871349918476, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.7380871349918476
# [LightGBM] [Warning] bagging_fraction is set=0.8390012815681169, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8390012815681169
# [LightGBM] [Warning] lambda_l2 is set=0.004382880970118931, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.004382880970118931
# [LightGBM] [Warning] bagging_freq is set=16, subsample_freq=0 will be ignored. Current value: bagging_freq=16
# [LightGBM] [Warning] feature_fraction is set=0.3093808232754206, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3093808232754206
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=45 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] min_gain_to_split is set=7.211501172815531, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.211501172815531
# [LightGBM] [Warning] lambda_l1 is set=2.7380871349918476, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.7380871349918476
# [LightGBM] [Warning] bagging_fraction is set=0.8390012815681169, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8390012815681169
# [LightGBM] [Warning] lambda_l2 is set=0.004382880970118931, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.004382880970118931
# [LightGBM] [Warning] bagging_freq is set=16, subsample_freq=0 will be ignored. Current value: bagging_freq=16
# MAE: 278890.85928299534
#
# [LightGBM] [Warning] feature_fraction is set=0.24287635098624624, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.24287635098624624
# [LightGBM] [Warning] min_data_in_leaf is set=52, min_child_samples=23 will be ignored. Current value: min_data_in_leaf=52
# [LightGBM] [Warning] min_gain_to_split is set=5.6471734143471775, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.6471734143471775
# [LightGBM] [Warning] lambda_l1 is set=0.06391248259594264, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06391248259594264
# [LightGBM] [Warning] bagging_fraction is set=0.5714789951552767, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5714789951552767
# [LightGBM] [Warning] lambda_l2 is set=0.006613406767709537, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.006613406767709537
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.24287635098624624, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.24287635098624624
# [LightGBM] [Warning] min_data_in_leaf is set=52, min_child_samples=23 will be ignored. Current value: min_data_in_leaf=52
# [LightGBM] [Warning] min_gain_to_split is set=5.6471734143471775, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.6471734143471775
# [LightGBM] [Warning] lambda_l1 is set=0.06391248259594264, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06391248259594264
# [LightGBM] [Warning] bagging_fraction is set=0.5714789951552767, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5714789951552767
# [LightGBM] [Warning] lambda_l2 is set=0.006613406767709537, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.006613406767709537
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# MAE: 357535.9945080554
#
# [LightGBM] [Warning] feature_fraction is set=0.20358887930763067, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.20358887930763067
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] min_gain_to_split is set=7.7589616897477764, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.7589616897477764
# [LightGBM] [Warning] lambda_l1 is set=0.6292378607230158, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6292378607230158
# [LightGBM] [Warning] bagging_fraction is set=0.7660067840085005, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7660067840085005
# [LightGBM] [Warning] lambda_l2 is set=0.4280404837390448, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.4280404837390448
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.20358887930763067, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.20358887930763067
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] min_gain_to_split is set=7.7589616897477764, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.7589616897477764
# [LightGBM] [Warning] lambda_l1 is set=0.6292378607230158, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6292378607230158
# [LightGBM] [Warning] bagging_fraction is set=0.7660067840085005, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7660067840085005
# [LightGBM] [Warning] lambda_l2 is set=0.4280404837390448, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.4280404837390448
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# MAE: 246103.5840075438
#
# [LightGBM] [Warning] feature_fraction is set=0.21472488730021771, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21472488730021771
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=21 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] min_gain_to_split is set=7.602286932306491, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.602286932306491
# [LightGBM] [Warning] lambda_l1 is set=0.47063744538598234, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.47063744538598234
# [LightGBM] [Warning] bagging_fraction is set=0.7801912537349165, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7801912537349165
# [LightGBM] [Warning] lambda_l2 is set=0.47927573164905574, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.47927573164905574
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.21472488730021771, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21472488730021771
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=21 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] min_gain_to_split is set=7.602286932306491, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.602286932306491
# [LightGBM] [Warning] lambda_l1 is set=0.47063744538598234, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.47063744538598234
# [LightGBM] [Warning] bagging_fraction is set=0.7801912537349165, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7801912537349165
# [LightGBM] [Warning] lambda_l2 is set=0.47927573164905574, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.47927573164905574
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# MAE: 243163.625356752
#
# [LightGBM] [Warning] feature_fraction is set=0.1868900292673939, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1868900292673939
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=22 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=5.7470474523066954, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.7470474523066954
# [LightGBM] [Warning] lambda_l1 is set=4.797881812320047, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.797881812320047
# [LightGBM] [Warning] bagging_fraction is set=0.7623516599272651, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7623516599272651
# [LightGBM] [Warning] lambda_l2 is set=1.1160707090644704, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1160707090644704
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.1868900292673939, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1868900292673939
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=22 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=5.7470474523066954, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.7470474523066954
# [LightGBM] [Warning] lambda_l1 is set=4.797881812320047, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.797881812320047
# [LightGBM] [Warning] bagging_fraction is set=0.7623516599272651, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7623516599272651
# [LightGBM] [Warning] lambda_l2 is set=1.1160707090644704, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1160707090644704
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# MAE: 246881.90051175264
#
# [LightGBM] [Warning] feature_fraction is set=0.07768758378940491, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.07768758378940491
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=13 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] min_gain_to_split is set=7.940113476150788, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.940113476150788
# [LightGBM] [Warning] lambda_l1 is set=0.46131492473977953, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.46131492473977953
# [LightGBM] [Warning] bagging_fraction is set=0.9941788426245576, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9941788426245576
# [LightGBM] [Warning] lambda_l2 is set=0.3846855491748333, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3846855491748333
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.07768758378940491, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.07768758378940491
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=13 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] min_gain_to_split is set=7.940113476150788, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.940113476150788
# [LightGBM] [Warning] lambda_l1 is set=0.46131492473977953, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.46131492473977953
# [LightGBM] [Warning] bagging_fraction is set=0.9941788426245576, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9941788426245576
# [LightGBM] [Warning] lambda_l2 is set=0.3846855491748333, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3846855491748333
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# MAE: 250917.80501923407
#
# [LightGBM] [Warning] feature_fraction is set=0.17434579338674228, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.17434579338674228
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=27 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=8.930858165570392, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.930858165570392
# [LightGBM] [Warning] lambda_l1 is set=9.392333474465275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.392333474465275
# [LightGBM] [Warning] bagging_fraction is set=0.538323334768171, subsample=1.0 will be ignored. Current value: bagging_fraction=0.538323334768171
# [LightGBM] [Warning] lambda_l2 is set=0.032422586934434595, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.032422586934434595
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.17434579338674228, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.17434579338674228
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=27 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=8.930858165570392, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.930858165570392
# ...
# [LightGBM] [Warning] lambda_l1 is set=2.4809728881122086, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4809728881122086
# [LightGBM] [Warning] bagging_fraction is set=0.8050097979030687, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8050097979030687
# [LightGBM] [Warning] lambda_l2 is set=2.4263616933793726, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.4263616933793726
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 235348.173518582
#
# [LightGBM] [Warning] feature_fraction is set=0.0072049726748896065, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0072049726748896065
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=8 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=0.4378414010845972, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.4378414010845972
# [LightGBM] [Warning] lambda_l1 is set=3.921769686095752, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.921769686095752
# [LightGBM] [Warning] bagging_fraction is set=0.8625621313328815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8625621313328815
# [LightGBM] [Warning] lambda_l2 is set=1.709440881146163, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.709440881146163
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# [LightGBM] [Warning] feature_fraction is set=0.0072049726748896065, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0072049726748896065
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=8 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=0.4378414010845972, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.4378414010845972
# [LightGBM] [Warning] lambda_l1 is set=3.921769686095752, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.921769686095752
# [LightGBM] [Warning] bagging_fraction is set=0.8625621313328815, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8625621313328815
# [LightGBM] [Warning] lambda_l2 is set=1.709440881146163, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.709440881146163
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# MAE: 300003.5464965765
#
# [LightGBM] [Warning] feature_fraction is set=0.15031114010333463, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.15031114010333463
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=13 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] min_gain_to_split is set=1.240271545776914, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.240271545776914
# [LightGBM] [Warning] lambda_l1 is set=0.36674402805010897, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.36674402805010897
# [LightGBM] [Warning] bagging_fraction is set=0.8111033691804523, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8111033691804523
# [LightGBM] [Warning] lambda_l2 is set=3.2448743059822176, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.2448743059822176
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# [LightGBM] [Warning] feature_fraction is set=0.15031114010333463, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.15031114010333463
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=13 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] min_gain_to_split is set=1.240271545776914, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.240271545776914
# [LightGBM] [Warning] lambda_l1 is set=0.36674402805010897, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.36674402805010897
# [LightGBM] [Warning] bagging_fraction is set=0.8111033691804523, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8111033691804523
# [LightGBM] [Warning] lambda_l2 is set=3.2448743059822176, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.2448743059822176
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 231682.13333594322
#
# [LightGBM] [Warning] feature_fraction is set=0.07423692224074807, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.07423692224074807
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=11 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.635229497872556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.635229497872556
# [LightGBM] [Warning] lambda_l1 is set=2.813127021090632, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.813127021090632
# [LightGBM] [Warning] bagging_fraction is set=0.8320562150186703, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8320562150186703
# [LightGBM] [Warning] lambda_l2 is set=0.5510070551791563, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5510070551791563
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# [LightGBM] [Warning] feature_fraction is set=0.07423692224074807, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.07423692224074807
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=11 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.635229497872556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.635229497872556
# [LightGBM] [Warning] lambda_l1 is set=2.813127021090632, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.813127021090632
# [LightGBM] [Warning] bagging_fraction is set=0.8320562150186703, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8320562150186703
# [LightGBM] [Warning] lambda_l2 is set=0.5510070551791563, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5510070551791563
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# MAE: 228782.12151968124
#
# [LightGBM] [Warning] feature_fraction is set=0.10844770959168676, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10844770959168676
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=12 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=5.51638398203054, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.51638398203054
# [LightGBM] [Warning] lambda_l1 is set=2.6720275368611266, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.6720275368611266
# [LightGBM] [Warning] bagging_fraction is set=0.8754224138657669, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8754224138657669
# [LightGBM] [Warning] lambda_l2 is set=0.5430069306100184, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5430069306100184
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# [LightGBM] [Warning] feature_fraction is set=0.10844770959168676, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10844770959168676
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=12 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=5.51638398203054, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.51638398203054
# [LightGBM] [Warning] lambda_l1 is set=2.6720275368611266, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.6720275368611266
# [LightGBM] [Warning] bagging_fraction is set=0.8754224138657669, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8754224138657669
# [LightGBM] [Warning] lambda_l2 is set=0.5430069306100184, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5430069306100184
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 235397.9990974457
#
# [LightGBM] [Warning] feature_fraction is set=0.13045085180802127, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13045085180802127
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=23 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=0.030806541374564005, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.030806541374564005
# [LightGBM] [Warning] lambda_l1 is set=2.6571328651968096, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.6571328651968096
# [LightGBM] [Warning] bagging_fraction is set=0.8520232561549477, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8520232561549477
# [LightGBM] [Warning] lambda_l2 is set=0.8890761903650468, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8890761903650468
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# [LightGBM] [Warning] feature_fraction is set=0.13045085180802127, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13045085180802127
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=23 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=0.030806541374564005, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.030806541374564005
# [LightGBM] [Warning] lambda_l1 is set=2.6571328651968096, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.6571328651968096
# [LightGBM] [Warning] bagging_fraction is set=0.8520232561549477, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8520232561549477
# [LightGBM] [Warning] lambda_l2 is set=0.8890761903650468, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8890761903650468
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# MAE: 237785.21654522984
#
# [LightGBM] [Warning] feature_fraction is set=0.09360907073059174, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09360907073059174
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=7 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] min_gain_to_split is set=7.194898340594977, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.194898340594977
# [LightGBM] [Warning] lambda_l1 is set=0.40990818343778634, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.40990818343778634
# [LightGBM] [Warning] bagging_fraction is set=0.07969760911792362, subsample=1.0 will be ignored. Current value: bagging_fraction=0.07969760911792362
# [LightGBM] [Warning] lambda_l2 is set=1.3578521985495595, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.3578521985495595
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# [LightGBM] [Warning] feature_fraction is set=0.09360907073059174, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09360907073059174
# [LightGBM] [Warning] min_data_in_leaf is set=56, min_child_samples=7 will be ignored. Current value: min_data_in_leaf=56
# [LightGBM] [Warning] min_gain_to_split is set=7.194898340594977, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.194898340594977
# [LightGBM] [Warning] lambda_l1 is set=0.40990818343778634, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.40990818343778634
# [LightGBM] [Warning] bagging_fraction is set=0.07969760911792362, subsample=1.0 will be ignored. Current value: bagging_fraction=0.07969760911792362
# [LightGBM] [Warning] lambda_l2 is set=1.3578521985495595, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.3578521985495595
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 619340.9702422693
#
# [LightGBM] [Warning] feature_fraction is set=0.07697813861546683, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.07697813861546683
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=10 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.201888735449538, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.201888735449538
# [LightGBM] [Warning] lambda_l1 is set=4.77130539429615, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.77130539429615
# [LightGBM] [Warning] bagging_fraction is set=0.8315249377703192, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8315249377703192
# [LightGBM] [Warning] lambda_l2 is set=5.665941426409672e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.665941426409672e-06
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.07697813861546683, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.07697813861546683
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=10 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.201888735449538, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.201888735449538
# [LightGBM] [Warning] lambda_l1 is set=4.77130539429615, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.77130539429615
# [LightGBM] [Warning] bagging_fraction is set=0.8315249377703192, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8315249377703192
# [LightGBM] [Warning] lambda_l2 is set=5.665941426409672e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.665941426409672e-06
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# MAE: 250414.6773600636
#
# [LightGBM] [Warning] feature_fraction is set=0.0376258367518353, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0376258367518353
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=17 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=2.9984111960000006, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.9984111960000006
# [LightGBM] [Warning] lambda_l1 is set=1.3055568835178384, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3055568835178384
# [LightGBM] [Warning] bagging_fraction is set=0.8103280704156444, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8103280704156444
# [LightGBM] [Warning] lambda_l2 is set=2.2984215304743807, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2984215304743807
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# [LightGBM] [Warning] feature_fraction is set=0.0376258367518353, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0376258367518353
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=17 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=2.9984111960000006, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.9984111960000006
# [LightGBM] [Warning] lambda_l1 is set=1.3055568835178384, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3055568835178384
# [LightGBM] [Warning] bagging_fraction is set=0.8103280704156444, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8103280704156444
# [LightGBM] [Warning] lambda_l2 is set=2.2984215304743807, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2984215304743807
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 236617.4467288515

# %%
# {'learning_rate': 0.007334316672219153,
#  'lambda_l1': 0.3092859757132077,
#  'lambda_l2': 3.597182451975432,
#  'min_gain_to_split': 0.022331760093498687,
#  'num_leaves': 223,
#  'feature_fraction': 0.10729740920514112,
#  'bagging_fraction': 0.8441536887414838,
#  'bagging_freq': 19,
#  'min_child_samples': 11,
#  'min_data_in_leaf': 3}
study_LGB.best_params
# Out:
# {'learning_rate': 0.007334316672219153,
#  'lambda_l1': 0.3092859757132077,
#  'lambda_l2': 3.597182451975432,
#  'min_gain_to_split': 0.022331760093498687,
#  'num_leaves': 223,
#  'feature_fraction': 0.10729740920514112,
#  'bagging_fraction': 0.8441536887414838,
#  'bagging_freq': 19,
#  'min_child_samples': 11,
#  'min_data_in_leaf': 3}

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    )  
model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
prediction1d = model1d.predict(n=90, future_covariates=series_1d_future_covariates)

df_prediction1d = prediction1d.pd_dataframe()
df_prediction1d[df_prediction1d["RUB"]>0] = 0
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.10729740920514112, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10729740920514112
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=11 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=0.022331760093498687, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.022331760093498687
# [LightGBM] [Warning] lambda_l1 is set=0.3092859757132077, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3092859757132077
# [LightGBM] [Warning] bagging_fraction is set=0.8441536887414838, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8441536887414838
# [LightGBM] [Warning] lambda_l2 is set=3.597182451975432, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.597182451975432
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19

# %%
series_1d_val.plot()
prediction1d.plot(label='forecast', low_quantile=0.05, high_quantile=0.95)
plt.legend()

# %%
mean_absolute_error(val_2_1d_reindex["RUB"], df_prediction1d["RUB"])
# Out:
# 259113.28496054246

# %%
val_df = pd.DataFrame()
val_df.index = df_prediction1d["RUB"].index
val_df["y"] = val_2_1d_reindex["RUB"].values
val_df["yhat"] = (df_prediction1d["RUB"])

# %%
BU2_group_stage = pd.read_csv("train_2_ans_ts.csv", usecols=[1,2])
BU2_group_stage.set_index("Дата транзакции", inplace=True)
BU2_group_stage.index.name = "Date"

# %%
val_df["yhat_groupstage"] = BU2_group_stage.loc[:"2021-03-31", "Сумма в RUB"].values

# %%
BU2_group_stage.loc[:"2021-03-31", "Сумма в RUB"]
# Out:
# Date
# 2021-01-01    -73550.991104
# 2021-01-02   -586195.476418
# 2021-01-03    -34416.708004
# 2021-01-04   -570312.375991
# 2021-01-05    -70317.101545
#                   ...
# 2021-03-27   -603919.524998
# 2021-03-28    -71470.817874
# 2021-03-29   -600546.299286
# 2021-03-30    -58758.651140
# 2021-03-31   -581068.707005
# Name: Сумма в RUB, Length: 90, dtype: float64

# %%
val_df
# Out:
#                        y          yhat  yhat_groupstage
# Date
# 2021-01-01      0.000000 -29600.903626    -73550.991104
# 2021-01-02      0.000000  -9693.732133   -586195.476418
# 2021-01-03      0.000000      0.000000    -34416.708004
# 2021-01-04      0.000000 -12081.987340   -570312.375991
# 2021-01-05      0.000000 -55404.938337    -70317.101545
# ...                  ...           ...              ...
# 2021-03-27      0.000000  -1516.142832   -603919.524998
# 2021-03-28      0.000000      0.000000    -71470.817874
# 2021-03-29      0.000000      0.000000   -600546.299286
# 2021-03-30      0.000000   -287.482933    -58758.651140
# 2021-03-31 -15095.541401 -26013.876832   -581068.707005
#
# [90 rows x 3 columns]

# %%
sns.lineplot(data=val_df)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mean_absolute_error(val_2_1d_reindex["RUB"], val_df["yhat_groupstage"])
# Out:
# 770464.806891032

# %%
##############################################################################################################################################################################################

# %%
# Refit на total

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    ) 
model1d.fit(series_1d_total, future_covariates=series_1d_future_covariates)
prediction1d_total = model1d.predict(n=91, future_covariates=series_1d_future_covariates)

df_prediction1d_total = prediction1d_total.pd_dataframe()
df_prediction1d_total[df_prediction1d_total["RUB"]>0] = 0
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.10729740920514112, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10729740920514112
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=11 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=0.022331760093498687, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.022331760093498687
# [LightGBM] [Warning] lambda_l1 is set=0.3092859757132077, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3092859757132077
# [LightGBM] [Warning] bagging_fraction is set=0.8441536887414838, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8441536887414838
# [LightGBM] [Warning] lambda_l2 is set=3.597182451975432, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.597182451975432
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19

# %%
#Собираем предикт вместе
train_2_ans_play_off = pd.DataFrame()
train_2_ans_play_off["Дата транзакции"] = pd.date_range(start="2021-04-01", end="2021-06-30", freq="1D")
train_2_ans_play_off["Сумма в RUB"] = (df_prediction1d_total["RUB"]).values
train_2_ans_play_off["Сумма в RUB"] = train_2_ans_play_off["Сумма в RUB"].groupby(train_2_ans_play_off["Дата транзакции"].dt.month).cumsum().values

train_2_ans_play_off["Месяц"] = train_2_ans_play_off["Дата транзакции"].dt.month
train_2_ans_play_off["БЕ"] = 2

# %%
train_2_ans_play_off
# Out:
#    Дата транзакции   Сумма в RUB  Месяц  БЕ
# 0       2021-04-01  0.000000e+00      4   2
# 1       2021-04-02 -7.373489e+04      4   2
# 2       2021-04-03 -1.550404e+05      4   2
# 3       2021-04-04 -2.273117e+05      4   2
# 4       2021-04-05 -6.756245e+05      4   2
# ..             ...           ...    ...  ..
# 86      2021-06-26 -7.182501e+06      6   2
# 87      2021-06-27 -7.184892e+06      6   2
# 88      2021-06-28 -7.184892e+06      6   2
# 89      2021-06-29 -7.184892e+06      6   2
# 90      2021-06-30 -8.996735e+06      6   2
#
# [91 rows x 4 columns]

# %%
train_2_ans_play_off.to_csv("train_2_ans_play_off.csv")
