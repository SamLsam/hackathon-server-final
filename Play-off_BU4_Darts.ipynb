# %% [raw]
# Привет!
# В преддверии финала хотели бы поделиться обратной связью от экспертов:
#
# Всем спасибо за проделанную работу и предоставленные решения.
#
# Мы решили выдать данные за 1 квартал 21 года, чтобы у вас была возможность
# самим оценить работу моделей и скорректировать некоторые моменты.
# По окончании данного этапа мы ожидаем от вас реализацию ваших идей,
# прогноз на 2 квартал 21 года, а также твердый и четкий ответ, на вопрос о том,
# могут ли предоставленные дополнительные данные о БЕ номер 3 и 5 помочь улучшить точность моделей.
#
# Пожалуйста, по итогам своей работы предоставьте файл с прогнозами в виде кумулятивных сумм,
# аналогично тому, как это представлено в файле с объяснением подсчета метрики.

# %% [raw]
# Фидбэк по вашему решению:
# Советуем углубить анализ в контексте определения дней транзакции,
# поискать закономерности, создать дополнительные признаки и усложнить модели.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import holidays
import calendar
import datetime

# %%
from sklearn.metrics import mean_absolute_error

# %%
import optuna
from darts import TimeSeries
from darts.models import AutoARIMA, LightGBMModel

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.set(font_scale=1.25)

# %%
data = pd.read_csv("train.csv")

# %%
train = pd.DataFrame()
train["Unit"] = data["БЕ"]
train["Date"] = data["Дата транзакции"]
train["RUB"] = data["Сумма в RUB"]

# %%
train_0 = train[train["Unit"]==0][["Date", "RUB"]]
train_0.set_index(pd.to_datetime(train_0["Date"]), inplace=True)
train_0.drop(["Date"], inplace=True, axis=1)

train_1 = train[train["Unit"]==1][["Date", "RUB"]]
train_1.set_index(pd.to_datetime(train_1["Date"]), inplace=True)
train_1.drop(["Date"], inplace=True, axis=1)

train_2 = train[train["Unit"]==2][["Date", "RUB"]]
train_2.set_index(pd.to_datetime(train_2["Date"]), inplace=True)
train_2.drop(["Date"], inplace=True, axis=1)

train_3 = train[train["Unit"]==3][["Date", "RUB"]]
train_3.set_index(pd.to_datetime(train_3["Date"]), inplace=True)
train_3.drop(["Date"], inplace=True, axis=1)

train_4 = train[train["Unit"]==4][["Date", "RUB"]]
train_4.set_index(pd.to_datetime(train_4["Date"]), inplace=True)
train_4.drop(["Date"], inplace=True, axis=1)

train_5 = train[train["Unit"]==5][["Date", "RUB"]]
train_5.set_index(pd.to_datetime(train_5["Date"]), inplace=True)
train_5.drop(["Date"], inplace=True, axis=1)

train_6 = train[train["Unit"]==6][["Date", "RUB"]]
train_6.set_index(pd.to_datetime(train_6["Date"]), inplace=True)
train_6.drop(["Date"], inplace=True, axis=1)

# %%
train_4.tail()
# Out:
#                      RUB
# Date
# 2020-12-03 -1.827086e+07
# 2020-12-10 -2.430930e+07
# 2020-12-17 -2.360431e+07
# 2020-12-24 -2.186163e+07
# 2020-12-28 -3.086100e+06

# %%
train_4_1d = train_4.resample('1D').sum()
train_4_1d = pd.concat([train_4_1d, pd.DataFrame([0, 0, 0], columns=["RUB"], index=[pd.to_datetime("2020-12-29"), pd.to_datetime("2020-12-30"), pd.to_datetime("2020-12-31")])])
train_4_1d.index.name = "Date"

# %%
train_4_1d.tail()
# Out:
#                      RUB
# Date
# 2020-12-27  0.000000e+00
# 2020-12-28 -3.086100e+06
# 2020-12-29  0.000000e+00
# 2020-12-30  0.000000e+00
# 2020-12-31  0.000000e+00

# %%
sns.lineplot(data=train_4_1d)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##############################################################################################################################################################################################

# %%
### Generalized valid data ###
# Данные, выданные к финалу - первый квартал 2021 года
data = pd.read_excel("1кв2021_1.xlsx")

# %%
val = pd.DataFrame()
val["Unit"] = data["БЕ"]
val["Date"] = data["Расчет ликвидности - дата"]
val["RUB"] = data["Сумма в валюте транзакции"]

# %%
val_0 = val[val["Unit"]==0][["Date", "RUB"]]
val_0.set_index(pd.to_datetime(val_0["Date"], dayfirst=True), inplace=True)
val_0.drop("Date", inplace=True, axis=1)

val_1 = val[val["Unit"]==1][["Date", "RUB"]]
val_1.set_index(pd.to_datetime(val_1["Date"], dayfirst=True), inplace=True)
val_1.drop("Date", inplace=True, axis=1)

val_2 = val[val["Unit"]==2][["Date", "RUB"]]
val_2.set_index(pd.to_datetime(val_2["Date"], dayfirst=True), inplace=True)
val_2.drop("Date", inplace=True, axis=1)

val_3 = val[val["Unit"]==3][["Date", "RUB"]]
val_3.set_index(pd.to_datetime(val_3["Date"], dayfirst=True), inplace=True)
val_3.drop("Date", inplace=True, axis=1)

val_4 = val[val["Unit"]==4][["Date", "RUB"]]
val_4.set_index(pd.to_datetime(val_4["Date"], dayfirst=True), inplace=True)
val_4.drop("Date", inplace=True, axis=1)

val_5 = val[val["Unit"]==5][["Date", "RUB"]]
val_5.set_index(pd.to_datetime(val_5["Date"], dayfirst=True), inplace=True)
val_5.drop("Date", inplace=True, axis=1)

val_6 = val[val["Unit"]==6][["Date", "RUB"]]
val_6.set_index(pd.to_datetime(val_6["Date"], dayfirst=True), inplace=True)
val_6.drop("Date", inplace=True, axis=1)

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*B1oKvhOuYoTdFEnwl8SEpg.png">

# %% [raw]
# Рисунок 1 - Схематичное изображение future covariates на временном интревале.
# Источник: https://medium.com/unit8-machine-learning-publication/time-series-forecasting-using-past-and-future-external-data-with-darts-1f0539585993

# %%
first_quarter = pd.DataFrame()
first_quarter.index = pd.date_range(start='1/1/2021', end='31/08/2021')
first_quarter["RUB"] = 0

val_0_1d = pd.DataFrame()
val_0_1d.index = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_0_1d.index.name = "Date"
val_0_1d["RUB"] = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_1_1d = pd.DataFrame()
val_1_1d.index = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_1_1d.index.name = "Date"
val_1_1d["RUB"] = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_2_1d = pd.DataFrame()
val_2_1d.index = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_2_1d.index.name = "Date"
val_2_1d["RUB"] = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_3_1d = pd.DataFrame()
val_3_1d.index = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_3_1d.index.name = "Date"
val_3_1d["RUB"] = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_4_1d = pd.DataFrame()
val_4_1d.index = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_4_1d.index.name = "Date"
val_4_1d["RUB"] = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_5_1d = pd.DataFrame()
val_5_1d.index = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_5_1d.index.name = "Date"
val_5_1d["RUB"] = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_6_1d = pd.DataFrame()
val_6_1d.index = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_6_1d.index.name = "Date"
val_6_1d["RUB"] = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

# %%
##############################################################################################################################################################################################

# %%
# Feature engineering
# Добавляем регрессоры

# %%
def dayofweek(df):
    df["Dayofweek"] = df.index.dayofweek
    return df

# %%
def get_holidays(df):
    df["Holidays"] = pd.Series(df.index).apply(lambda x: holidays.CountryHoliday('RUS').get(x)).values
    df["Holidays"] = df["Holidays"].astype('bool').astype('int')
    return df

# %%
def number_of_week_in_year(df):
    df["Number_of_week_in_year"] = df.index.isocalendar().week
    df["Number_of_week_in_year"] = df["Number_of_week_in_year"].astype(int)
    return df

# %%
def number_of_week_in_month(df):
    def week_of_month(tgtdate):
        days_this_month = calendar.mdays[tgtdate.month]
        for i in range(1, days_this_month):
            d = datetime.datetime(tgtdate.year, tgtdate.month, i)
            if d.day - d.weekday() > 0:
                startdate = d
                break
        return (tgtdate - startdate).days //7 + 1
    df["Number_of_week_in_month"] = df.index.to_series().apply(week_of_month)
    return df

# %%
def number_of_day_in_month(df):
    df["Number_of_day_in_month"] = df.index.day
    return df

# %%
def number_of_day_in_year(df):
    df["Number_of_day_in_year"] = df.index.dayofyear
    return df

# %%
def get_month(df):
    df["Month"] = df.index.month
    return df

# %%
def get_season(df):
    df["Season"] = df.index.month%12 // 3 + 1
    return df

# %%
def payday(df, payday):
    df["Payday"] = 0 
    df.loc[df.index.day_name() == payday, "Payday"] = 1
    return df

# %%
(
    train_4_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)
    .pipe(payday, payday="Thursday")
)
# Out:
#                      RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2017-01-12 -1.882559e+07          3         0                       2
# 2017-01-13  0.000000e+00          4         0                       2
# 2017-01-14  0.000000e+00          5         0                       2
# 2017-01-15  0.000000e+00          6         0                       2
# 2017-01-16  0.000000e+00          0         0                       3
# ...                  ...        ...       ...                     ...
# 2020-12-27  0.000000e+00          6         0                      52
# 2020-12-28 -3.086100e+06          0         0                      53
# 2020-12-29  0.000000e+00          1         0                      53
# 2020-12-30  0.000000e+00          2         0                      53
# 2020-12-31  0.000000e+00          3         1                      53
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2017-01-12                        2                      12
# 2017-01-13                        2                      13
# 2017-01-14                        2                      14
# 2017-01-15                        2                      15
# 2017-01-16                        3                      16
# ...                             ...                     ...
# 2020-12-27                        3                      27
# 2020-12-28                        4                      28
# 2020-12-29                        4                      29
# 2020-12-30                        4                      30
# 2020-12-31                        4                      31
#
#             Number_of_day_in_year  Month  Season  Payday
# Date
# 2017-01-12                     12      1       1       1
# 2017-01-13                     13      1       1       0
# 2017-01-14                     14      1       1       0
# 2017-01-15                     15      1       1       0
# 2017-01-16                     16      1       1       0
# ...                           ...    ...     ...     ...
# 2020-12-27                    362     12       1       0
# 2020-12-28                    363     12       1       0
# 2020-12-29                    364     12       1       0
# 2020-12-30                    365     12       1       0
# 2020-12-31                    366     12       1       1
#
# [1450 rows x 10 columns]

# %%
(
    val_4_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)
    .pipe(payday, payday="Thursday")
)
# Out:
#             RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2021-01-01  0.0          4         1                      53
# 2021-01-02  0.0          5         1                      53
# 2021-01-03  0.0          6         1                      53
# 2021-01-04  0.0          0         1                       1
# 2021-01-05  0.0          1         1                       1
# ...         ...        ...       ...                     ...
# 2021-08-27  0.0          4         0                      34
# 2021-08-28  0.0          5         0                      34
# 2021-08-29  0.0          6         0                      34
# 2021-08-30  0.0          0         0                      35
# 2021-08-31  0.0          1         0                      35
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2021-01-01                        0                       1
# 2021-01-02                        0                       2
# 2021-01-03                        0                       3
# 2021-01-04                        1                       4
# 2021-01-05                        1                       5
# ...                             ...                     ...
# 2021-08-27                        4                      27
# 2021-08-28                        4                      28
# 2021-08-29                        4                      29
# 2021-08-30                        5                      30
# 2021-08-31                        5                      31
#
#             Number_of_day_in_year  Month  Season  Payday
# Date
# 2021-01-01                      1      1       1       0
# 2021-01-02                      2      1       1       0
# 2021-01-03                      3      1       1       0
# 2021-01-04                      4      1       1       0
# 2021-01-05                      5      1       1       0
# ...                           ...    ...     ...     ...
# 2021-08-27                    239      8       3       0
# 2021-08-28                    240      8       3       0
# 2021-08-29                    241      8       3       0
# 2021-08-30                    242      8       3       0
# 2021-08-31                    243      8       3       0
#
# [243 rows x 10 columns]

# %%
list(train_4_1d.columns.values)
# Out:
# ['RUB',
#  'Dayofweek',
#  'Holidays',
#  'Number_of_week_in_year',
#  'Number_of_week_in_month',
#  'Number_of_day_in_month',
#  'Number_of_day_in_year',
#  'Month',
#  'Season',
#  'Payday']

# %%
##############################################################################################################################################################################################

# %%
# Darts модели

# %%
train_4_1d_reindex = train_4_1d["RUB"].reset_index(inplace=False)
train_4_1d_covariates = train_4_1d.drop("RUB", inplace=False, axis=1).reset_index()

val_4_1d_reindex = val_4_1d.loc["2021-01-01":"2021-03-31","RUB"].reset_index(inplace=False)
val_4_1d_covariates = val_4_1d.drop("RUB", inplace=False, axis=1).reset_index()

# %%
total_4_1d = pd.concat([train_4_1d, val_4_1d.loc["2021-01-01":"2021-03-31"]])
total_4_1d_reindex = total_4_1d["RUB"].reset_index(inplace=False)

# %%
series_1d_total = TimeSeries.from_dataframe(total_4_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
covariates = pd.concat([train_4_1d_covariates, val_4_1d_covariates])

# %%
series_1d_train = TimeSeries.from_dataframe(train_4_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)
series_1d_val = TimeSeries.from_dataframe(val_4_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
series_1d_future_covariates = TimeSeries.from_dataframe(
    covariates,
    time_col="Date",
    value_cols=[
        "Dayofweek",
        "Holidays",
        "Number_of_week_in_year",
        "Number_of_week_in_month",
        "Number_of_day_in_month",
        "Number_of_day_in_year",
        "Month",
        "Season",
        "Payday",
    ],
    freq="1d",
    fill_missing_dates=True,
)

# %%
train_1d_split, local_val_1d_split = series_1d_train.split_before(0.80)
val_1d_split = series_1d_val

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
def objective_LGB(trial):

    # 
    model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=trial.suggest_float("learning_rate", 1e-3, 1.0, log=True),
        lambda_l1=trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
        lambda_l2=trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
        min_gain_to_split=trial.suggest_float("min_gain_to_split", 0, 10.0),
        num_leaves=trial.suggest_int("num_leaves", 8, 256),
        feature_fraction=trial.suggest_uniform("feature_fraction", 0.0001, 1.0),
        bagging_fraction=trial.suggest_uniform("bagging_fraction", 0.0001, 1.0),
        bagging_freq=trial.suggest_int("bagging_freq", 0, 30),
        min_child_samples=trial.suggest_int("min_child_samples", 1, 100),
        min_data_in_leaf=trial.suggest_int("min_data_in_leaf", 3, 100),
        feature_pre_filter=False
    )  

    model1d.fit(train_1d_split, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(local_val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    local_val = mean_absolute_error(local_val_1d_split.pd_dataframe(), fixed_prediction1d)
    
    model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    global_val = mean_absolute_error(val_1d_split.pd_dataframe(), fixed_prediction1d)
    
    val = np.mean([local_val, global_val])

    trial.set_user_attr("Valid_score", val)

    print(f"MAE: {val}\n")

    return val

# %%
study_LGB = optuna.create_study(direction="minimize")
study_LGB.optimize(objective_LGB, n_trials=300, gc_after_trial=True)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.6817389605576728, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6817389605576728
# [LightGBM] [Warning] min_data_in_leaf is set=96, min_child_samples=86 will be ignored. Current value: min_data_in_leaf=96
# [LightGBM] [Warning] min_gain_to_split is set=0.40386083849938026, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.40386083849938026
# [LightGBM] [Warning] lambda_l1 is set=5.8905223486218476e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.8905223486218476e-05
# [LightGBM] [Warning] bagging_fraction is set=0.45174223133547514, subsample=1.0 will be ignored. Current value: bagging_fraction=0.45174223133547514
# [LightGBM] [Warning] lambda_l2 is set=1.9187429054312945e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.9187429054312945e-07
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# [LightGBM] [Warning] feature_fraction is set=0.6817389605576728, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6817389605576728
# [LightGBM] [Warning] min_data_in_leaf is set=96, min_child_samples=86 will be ignored. Current value: min_data_in_leaf=96
# [LightGBM] [Warning] min_gain_to_split is set=0.40386083849938026, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.40386083849938026
# [LightGBM] [Warning] lambda_l1 is set=5.8905223486218476e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.8905223486218476e-05
# [LightGBM] [Warning] bagging_fraction is set=0.45174223133547514, subsample=1.0 will be ignored. Current value: bagging_fraction=0.45174223133547514
# [LightGBM] [Warning] lambda_l2 is set=1.9187429054312945e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.9187429054312945e-07
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# MAE: 1710618.1159573204
#
# [LightGBM] [Warning] feature_fraction is set=0.8481236456198873, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8481236456198873
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=81 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] min_gain_to_split is set=1.606797570450812, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.606797570450812
# [LightGBM] [Warning] lambda_l1 is set=3.8373186177061256e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.8373186177061256e-07
# [LightGBM] [Warning] bagging_fraction is set=0.32460705025701264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.32460705025701264
# [LightGBM] [Warning] lambda_l2 is set=0.011943722853528101, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.011943722853528101
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8481236456198873, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8481236456198873
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=81 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] min_gain_to_split is set=1.606797570450812, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.606797570450812
# [LightGBM] [Warning] lambda_l1 is set=3.8373186177061256e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.8373186177061256e-07
# [LightGBM] [Warning] bagging_fraction is set=0.32460705025701264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.32460705025701264
# [LightGBM] [Warning] lambda_l2 is set=0.011943722853528101, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.011943722853528101
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# MAE: 1577817.5274400818
#
# [LightGBM] [Warning] feature_fraction is set=0.3710753168513551, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3710753168513551
# [LightGBM] [Warning] min_data_in_leaf is set=66, min_child_samples=3 will be ignored. Current value: min_data_in_leaf=66
# [LightGBM] [Warning] min_gain_to_split is set=7.513931214936196, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.513931214936196
# [LightGBM] [Warning] lambda_l1 is set=0.000981580973684268, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.000981580973684268
# [LightGBM] [Warning] bagging_fraction is set=0.27422860416387856, subsample=1.0 will be ignored. Current value: bagging_fraction=0.27422860416387856
# [LightGBM] [Warning] lambda_l2 is set=1.220508455083699e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.220508455083699e-07
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# [LightGBM] [Warning] feature_fraction is set=0.3710753168513551, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3710753168513551
# [LightGBM] [Warning] min_data_in_leaf is set=66, min_child_samples=3 will be ignored. Current value: min_data_in_leaf=66
# [LightGBM] [Warning] min_gain_to_split is set=7.513931214936196, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.513931214936196
# [LightGBM] [Warning] lambda_l1 is set=0.000981580973684268, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.000981580973684268
# [LightGBM] [Warning] bagging_fraction is set=0.27422860416387856, subsample=1.0 will be ignored. Current value: bagging_fraction=0.27422860416387856
# [LightGBM] [Warning] lambda_l2 is set=1.220508455083699e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.220508455083699e-07
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# MAE: 2645768.900591324
#
# [LightGBM] [Warning] feature_fraction is set=0.4275946619732679, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4275946619732679
# [LightGBM] [Warning] min_data_in_leaf is set=82, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=82
# [LightGBM] [Warning] min_gain_to_split is set=9.775412892194042, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.775412892194042
# [LightGBM] [Warning] lambda_l1 is set=1.791139671590085e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.791139671590085e-05
# [LightGBM] [Warning] bagging_fraction is set=0.3957559186121264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3957559186121264
# [LightGBM] [Warning] lambda_l2 is set=0.0013387079869055319, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0013387079869055319
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4275946619732679, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4275946619732679
# [LightGBM] [Warning] min_data_in_leaf is set=82, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=82
# [LightGBM] [Warning] min_gain_to_split is set=9.775412892194042, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.775412892194042
# [LightGBM] [Warning] lambda_l1 is set=1.791139671590085e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.791139671590085e-05
# [LightGBM] [Warning] bagging_fraction is set=0.3957559186121264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3957559186121264
# [LightGBM] [Warning] lambda_l2 is set=0.0013387079869055319, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0013387079869055319
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# MAE: 2382649.4796562633
#
# [LightGBM] [Warning] feature_fraction is set=0.09701756122862173, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09701756122862173
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=94 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=2.7789960745702458, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.7789960745702458
# [LightGBM] [Warning] lambda_l1 is set=3.078985714846444e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.078985714846444e-08
# [LightGBM] [Warning] bagging_fraction is set=0.437864749095511, subsample=1.0 will be ignored. Current value: bagging_fraction=0.437864749095511
# [LightGBM] [Warning] lambda_l2 is set=4.021282251191121e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.021282251191121e-07
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# [LightGBM] [Warning] feature_fraction is set=0.09701756122862173, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09701756122862173
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=94 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=2.7789960745702458, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.7789960745702458
# [LightGBM] [Warning] lambda_l1 is set=3.078985714846444e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.078985714846444e-08
# [LightGBM] [Warning] bagging_fraction is set=0.437864749095511, subsample=1.0 will be ignored. Current value: bagging_fraction=0.437864749095511
# [LightGBM] [Warning] lambda_l2 is set=4.021282251191121e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.021282251191121e-07
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 1383699.38879618
#
# [LightGBM] [Warning] feature_fraction is set=0.6653225092743043, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6653225092743043
# [LightGBM] [Warning] min_data_in_leaf is set=47, min_child_samples=17 will be ignored. Current value: min_data_in_leaf=47
# [LightGBM] [Warning] min_gain_to_split is set=6.820541845264186, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.820541845264186
# [LightGBM] [Warning] lambda_l1 is set=0.013553775162118364, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.013553775162118364
# [LightGBM] [Warning] bagging_fraction is set=0.6573197931747019, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6573197931747019
# [LightGBM] [Warning] lambda_l2 is set=0.0001584738968175702, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0001584738968175702
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# [LightGBM] [Warning] feature_fraction is set=0.6653225092743043, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6653225092743043
# [LightGBM] [Warning] min_data_in_leaf is set=47, min_child_samples=17 will be ignored. Current value: min_data_in_leaf=47
# [LightGBM] [Warning] min_gain_to_split is set=6.820541845264186, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.820541845264186
# [LightGBM] [Warning] lambda_l1 is set=0.013553775162118364, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.013553775162118364
# [LightGBM] [Warning] bagging_fraction is set=0.6573197931747019, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6573197931747019
# [LightGBM] [Warning] lambda_l2 is set=0.0001584738968175702, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0001584738968175702
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# MAE: 1363922.1273153662
#
# [LightGBM] [Warning] feature_fraction is set=0.8544329941970071, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8544329941970071
# [LightGBM] [Warning] min_data_in_leaf is set=73, min_child_samples=38 will be ignored. Current value: min_data_in_leaf=73
# [LightGBM] [Warning] min_gain_to_split is set=6.671371447218396, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.671371447218396
# [LightGBM] [Warning] lambda_l1 is set=0.011799011494512771, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.011799011494512771
# [LightGBM] [Warning] bagging_fraction is set=0.8492058034055971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8492058034055971
# [LightGBM] [Warning] lambda_l2 is set=3.16625545580142e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.16625545580142e-08
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# [LightGBM] [Warning] feature_fraction is set=0.8544329941970071, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8544329941970071
# [LightGBM] [Warning] min_data_in_leaf is set=73, min_child_samples=38 will be ignored. Current value: min_data_in_leaf=73
# [LightGBM] [Warning] min_gain_to_split is set=6.671371447218396, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.671371447218396
# [LightGBM] [Warning] lambda_l1 is set=0.011799011494512771, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.011799011494512771
# [LightGBM] [Warning] bagging_fraction is set=0.8492058034055971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8492058034055971
# [LightGBM] [Warning] lambda_l2 is set=3.16625545580142e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.16625545580142e-08
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# MAE: 1520935.5417277338
#
# [LightGBM] [Warning] feature_fraction is set=0.4998213791846834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4998213791846834
# [LightGBM] [Warning] min_data_in_leaf is set=47, min_child_samples=92 will be ignored. Current value: min_data_in_leaf=47
# [LightGBM] [Warning] min_gain_to_split is set=6.635818960769278, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.635818960769278
# [LightGBM] [Warning] lambda_l1 is set=9.975862508970942e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.975862508970942e-07
# [LightGBM] [Warning] bagging_fraction is set=0.5069478384221586, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5069478384221586
# [LightGBM] [Warning] lambda_l2 is set=6.698276965271137e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.698276965271137e-08
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4998213791846834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4998213791846834
# [LightGBM] [Warning] min_data_in_leaf is set=47, min_child_samples=92 will be ignored. Current value: min_data_in_leaf=47
# [LightGBM] [Warning] min_gain_to_split is set=6.635818960769278, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.635818960769278
# [LightGBM] [Warning] lambda_l1 is set=9.975862508970942e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.975862508970942e-07
# [LightGBM] [Warning] bagging_fraction is set=0.5069478384221586, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5069478384221586
# [LightGBM] [Warning] lambda_l2 is set=6.698276965271137e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.698276965271137e-08
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# MAE: 1960774.8866584385
#
# [LightGBM] [Warning] feature_fraction is set=0.6308624481036862, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6308624481036862
# [LightGBM] [Warning] min_data_in_leaf is set=62, min_child_samples=77 will be ignored. Current value: min_data_in_leaf=62
# [LightGBM] [Warning] min_gain_to_split is set=6.569064068883257, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.569064068883257
# [LightGBM] [Warning] lambda_l1 is set=1.3420101330911092e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3420101330911092e-05
# [LightGBM] [Warning] bagging_fraction is set=0.27561333613896855, subsample=1.0 will be ignored. Current value: bagging_fraction=0.27561333613896855
# [LightGBM] [Warning] lambda_l2 is set=0.1374371096026332, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1374371096026332
# [LightGBM] [Warning] bagging_freq is set=14, subsample_freq=0 will be ignored. Current value: bagging_freq=14
# [LightGBM] [Warning] feature_fraction is set=0.6308624481036862, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6308624481036862
# [LightGBM] [Warning] min_data_in_leaf is set=62, min_child_samples=77 will be ignored. Current value: min_data_in_leaf=62
# [LightGBM] [Warning] min_gain_to_split is set=6.569064068883257, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.569064068883257
# [LightGBM] [Warning] lambda_l1 is set=1.3420101330911092e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3420101330911092e-05
# [LightGBM] [Warning] bagging_fraction is set=0.27561333613896855, subsample=1.0 will be ignored. Current value: bagging_fraction=0.27561333613896855
# [LightGBM] [Warning] lambda_l2 is set=0.1374371096026332, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1374371096026332
# [LightGBM] [Warning] bagging_freq is set=14, subsample_freq=0 will be ignored. Current value: bagging_freq=14
# MAE: 1715993.7388922786
#
# [LightGBM] [Warning] feature_fraction is set=0.27166590033962956, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.27166590033962956
# [LightGBM] [Warning] min_data_in_leaf is set=70, min_child_samples=12 will be ignored. Current value: min_data_in_leaf=70
# [LightGBM] [Warning] min_gain_to_split is set=4.122677266664773, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.122677266664773
# [LightGBM] [Warning] lambda_l1 is set=1.428477773524401e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.428477773524401e-08
# [LightGBM] [Warning] bagging_fraction is set=0.4064700322063267, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4064700322063267
# [LightGBM] [Warning] lambda_l2 is set=6.275267918352296e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.275267918352296e-06
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# [LightGBM] [Warning] feature_fraction is set=0.27166590033962956, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.27166590033962956
# [LightGBM] [Warning] min_data_in_leaf is set=70, min_child_samples=12 will be ignored. Current value: min_data_in_leaf=70
# [LightGBM] [Warning] min_gain_to_split is set=4.122677266664773, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.122677266664773
# [LightGBM] [Warning] lambda_l1 is set=1.428477773524401e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.428477773524401e-08
# [LightGBM] [Warning] bagging_fraction is set=0.4064700322063267, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4064700322063267
# [LightGBM] [Warning] lambda_l2 is set=6.275267918352296e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.275267918352296e-06
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# MAE: 1733159.1954967435
#
# [LightGBM] [Warning] feature_fraction is set=0.9948013947580157, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9948013947580157
# [LightGBM] [Warning] min_data_in_leaf is set=37, min_child_samples=57 will be ignored. Current value: min_data_in_leaf=37
# [LightGBM] [Warning] min_gain_to_split is set=9.668318345104836, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.668318345104836
# [LightGBM] [Warning] lambda_l1 is set=3.2454175515179053, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.2454175515179053
# [LightGBM] [Warning] bagging_fraction is set=0.7868076738685152, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7868076738685152
# [LightGBM] [Warning] lambda_l2 is set=8.431091846802982, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.431091846802982
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# [LightGBM] [Warning] feature_fraction is set=0.9948013947580157, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9948013947580157
# [LightGBM] [Warning] min_data_in_leaf is set=37, min_child_samples=57 will be ignored. Current value: min_data_in_leaf=37
# [LightGBM] [Warning] min_gain_to_split is set=9.668318345104836, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.668318345104836
# [LightGBM] [Warning] lambda_l1 is set=3.2454175515179053, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.2454175515179053
# [LightGBM] [Warning] bagging_fraction is set=0.7868076738685152, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7868076738685152
# [LightGBM] [Warning] lambda_l2 is set=8.431091846802982, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.431091846802982
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# MAE: 2579375.1126850806
#
# [LightGBM] [Warning] feature_fraction is set=0.03894620456315534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03894620456315534
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=3.150542417214905, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.150542417214905
# [LightGBM] [Warning] lambda_l1 is set=0.08376549475897954, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.08376549475897954
# [LightGBM] [Warning] bagging_fraction is set=0.02616335093564759, subsample=1.0 will be ignored. Current value: bagging_fraction=0.02616335093564759
# [LightGBM] [Warning] lambda_l2 is set=2.0224543516915866e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0224543516915866e-05
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.03894620456315534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03894620456315534
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=3.150542417214905, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.150542417214905
# [LightGBM] [Warning] lambda_l1 is set=0.08376549475897954, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.08376549475897954
# [LightGBM] [Warning] bagging_fraction is set=0.02616335093564759, subsample=1.0 will be ignored. Current value: bagging_fraction=0.02616335093564759
# [LightGBM] [Warning] lambda_l2 is set=2.0224543516915866e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0224543516915866e-05
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# MAE: 1780654.6107850904
#
# [LightGBM] [Warning] feature_fraction is set=0.06473361875693351, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06473361875693351
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=64 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=4.71488712191013, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.71488712191013
# [LightGBM] [Warning] lambda_l1 is set=0.1395516369002009, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1395516369002009
# [LightGBM] [Warning] bagging_fraction is set=0.6442781280428133, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6442781280428133
# [LightGBM] [Warning] lambda_l2 is set=1.38797720107838e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.38797720107838e-05
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.06473361875693351, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06473361875693351
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=64 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=4.71488712191013, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.71488712191013
# [LightGBM] [Warning] lambda_l1 is set=0.1395516369002009, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1395516369002009
# [LightGBM] [Warning] bagging_fraction is set=0.6442781280428133, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6442781280428133
# [LightGBM] [Warning] lambda_l2 is set=1.38797720107838e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.38797720107838e-05
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# MAE: 1479852.9207646933
#
# [LightGBM] [Warning] feature_fraction is set=0.22298880107061275, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.22298880107061275
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=35 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] min_gain_to_split is set=2.5549459834910335, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.5549459834910335
# [LightGBM] [Warning] lambda_l1 is set=0.0013261532339857017, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0013261532339857017
# [LightGBM] [Warning] bagging_fraction is set=0.9790812449101751, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9790812449101751
# [LightGBM] [Warning] lambda_l2 is set=0.0002054983877896755, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0002054983877896755
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# [LightGBM] [Warning] feature_fraction is set=0.22298880107061275, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.22298880107061275
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=35 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] min_gain_to_split is set=2.5549459834910335, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=2.5549459834910335
# [LightGBM] [Warning] lambda_l1 is set=0.0013261532339857017, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0013261532339857017
# [LightGBM] [Warning] bagging_fraction is set=0.9790812449101751, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9790812449101751
# [LightGBM] [Warning] lambda_l2 is set=0.0002054983877896755, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0002054983877896755
# [LightGBM] [Warning] bagging_freq is set=23, subsample_freq=0 will be ignored. Current value: bagging_freq=23
# MAE: 2419215.9412172344
#
# [LightGBM] [Warning] feature_fraction is set=0.6121632764036544, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6121632764036544
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=23 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] min_gain_to_split is set=8.334815097470893, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.334815097470893
# [LightGBM] [Warning] lambda_l1 is set=1.3560617693551512e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3560617693551512e-08
# [LightGBM] [Warning] bagging_fraction is set=0.6154858242124479, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6154858242124479
# [LightGBM] [Warning] lambda_l2 is set=2.2089615019792852e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2089615019792852e-06
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# [LightGBM] [Warning] feature_fraction is set=0.6121632764036544, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6121632764036544
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=23 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] min_gain_to_split is set=8.334815097470893, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.334815097470893
# [LightGBM] [Warning] lambda_l1 is set=1.3560617693551512e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3560617693551512e-08
# [LightGBM] [Warning] bagging_fraction is set=0.6154858242124479, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6154858242124479
# [LightGBM] [Warning] lambda_l2 is set=2.2089615019792852e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2089615019792852e-06
# [LightGBM] [Warning] bagging_freq is set=19, subsample_freq=0 will be ignored. Current value: bagging_freq=19
# MAE: 1337351.2209907633
#
# [LightGBM] [Warning] feature_fraction is set=0.6295273167284866, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6295273167284866
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=17 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] min_gain_to_split is set=8.299435105598162, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.299435105598162
# [LightGBM] [Warning] lambda_l1 is set=4.352134306465957, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.352134306465957
# [LightGBM] [Warning] bagging_fraction is set=0.6385860908258834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6385860908258834
# [LightGBM] [Warning] lambda_l2 is set=0.000256551435371951, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.000256551435371951
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] feature_fraction is set=0.6295273167284866, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6295273167284866
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=17 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] min_gain_to_split is set=8.299435105598162, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.299435105598162
# [LightGBM] [Warning] lambda_l1 is set=4.352134306465957, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.352134306465957
# [LightGBM] [Warning] bagging_fraction is set=0.6385860908258834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6385860908258834
# [LightGBM] [Warning] lambda_l2 is set=0.000256551435371951, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.000256551435371951
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# MAE: 1415661.3113935636
#
# [LightGBM] [Warning] feature_fraction is set=0.7189774898925192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7189774898925192
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=8.13089160834999, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.13089160834999
# [LightGBM] [Warning] lambda_l1 is set=0.0075451751622953, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0075451751622953
# [LightGBM] [Warning] bagging_fraction is set=0.6197466991946654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6197466991946654
# [LightGBM] [Warning] lambda_l2 is set=2.322233782928513e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.322233782928513e-06
# [LightGBM] [Warning] bagging_freq is set=17, subsample_freq=0 will be ignored. Current value: bagging_freq=17
# [LightGBM] [Warning] feature_fraction is set=0.7189774898925192, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7189774898925192
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=8.13089160834999, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.13089160834999
# [LightGBM] [Warning] lambda_l1 is set=0.0075451751622953, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0075451751622953
# [LightGBM] [Warning] bagging_fraction is set=0.6197466991946654, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6197466991946654
# [LightGBM] [Warning] lambda_l2 is set=2.322233782928513e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.322233782928513e-06
# [LightGBM] [Warning] bagging_freq is set=17, subsample_freq=0 will be ignored. Current value: bagging_freq=17
# MAE: 1456167.49462016
#
# [LightGBM] [Warning] feature_fraction is set=0.5335979094346678, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5335979094346678
# [LightGBM] [Warning] min_data_in_leaf is set=38, min_child_samples=2 will be ignored. Current value: min_data_in_leaf=38
# [LightGBM] [Warning] min_gain_to_split is set=5.280867034161067, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.280867034161067
# [LightGBM] [Warning] lambda_l1 is set=1.0506937469086433e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0506937469086433e-06
# [LightGBM] [Warning] bagging_fraction is set=0.8113719416314882, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8113719416314882
# [LightGBM] [Warning] lambda_l2 is set=0.0036039294253349483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0036039294253349483
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# [LightGBM] [Warning] feature_fraction is set=0.5335979094346678, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5335979094346678
# [LightGBM] [Warning] min_data_in_leaf is set=38, min_child_samples=2 will be ignored. Current value: min_data_in_leaf=38
# [LightGBM] [Warning] min_gain_to_split is set=5.280867034161067, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.280867034161067
# [LightGBM] [Warning] lambda_l1 is set=1.0506937469086433e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0506937469086433e-06
# [LightGBM] [Warning] bagging_fraction is set=0.8113719416314882, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8113719416314882
# [LightGBM] [Warning] lambda_l2 is set=0.0036039294253349483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0036039294253349483
# [LightGBM] [Warning] bagging_freq is set=11, subsample_freq=0 will be ignored. Current value: bagging_freq=11
# MAE: 1596523.095077168
#
# [LightGBM] [Warning] feature_fraction is set=0.8105395370998337, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8105395370998337
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=22 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] min_gain_to_split is set=8.816814457179136, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.816814457179136
# [LightGBM] [Warning] lambda_l1 is set=0.22456407924138766, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.22456407924138766
# [LightGBM] [Warning] bagging_fraction is set=0.7182521189931212, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7182521189931212
# [LightGBM] [Warning] lambda_l2 is set=6.44825822395495e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.44825822395495e-05
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# [LightGBM] [Warning] feature_fraction is set=0.8105395370998337, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8105395370998337
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=22 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] min_gain_to_split is set=8.816814457179136, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.816814457179136
# [LightGBM] [Warning] lambda_l1 is set=0.22456407924138766, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.22456407924138766
# [LightGBM] [Warning] bagging_fraction is set=0.7182521189931212, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7182521189931212
# [LightGBM] [Warning] lambda_l2 is set=6.44825822395495e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.44825822395495e-05
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# MAE: 1343226.9867755724
#
# [LightGBM] [Warning] feature_fraction is set=0.8200056210549055, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8200056210549055
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=31 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=9.080566441635355, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.080566441635355
# [LightGBM] [Warning] lambda_l1 is set=0.30299421171884716, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.30299421171884716
# [LightGBM] [Warning] bagging_fraction is set=0.9890988307794351, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9890988307794351
# [LightGBM] [Warning] lambda_l2 is set=9.783518093231247e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.783518093231247e-07
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# [LightGBM] [Warning] feature_fraction is set=0.8200056210549055, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8200056210549055
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=31 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=9.080566441635355, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.080566441635355
# [LightGBM] [Warning] lambda_l1 is set=0.30299421171884716, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.30299421171884716
# [LightGBM] [Warning] bagging_fraction is set=0.9890988307794351, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9890988307794351
# [LightGBM] [Warning] lambda_l2 is set=9.783518093231247e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.783518093231247e-07
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# MAE: 1338126.7308411151
#
# [LightGBM] [Warning] feature_fraction is set=0.97575891199323, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.97575891199323
# [LightGBM] [Warning] min_data_in_leaf is set=35, min_child_samples=45 will be ignored. Current value: min_data_in_leaf=35
# [LightGBM] [Warning] min_gain_to_split is set=8.990454732456785, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.990454732456785
# [LightGBM] [Warning] lambda_l1 is set=9.847071237617981e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.847071237617981e-05
# [LightGBM] [Warning] bagging_fraction is set=0.9908115119695178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9908115119695178
# [LightGBM] [Warning] lambda_l2 is set=1.1691014282433264e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1691014282433264e-06
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.97575891199323, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.97575891199323
# [LightGBM] [Warning] min_data_in_leaf is set=35, min_child_samples=45 will be ignored. Current value: min_data_in_leaf=35
# [LightGBM] [Warning] min_gain_to_split is set=8.990454732456785, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.990454732456785
# [LightGBM] [Warning] lambda_l1 is set=9.847071237617981e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.847071237617981e-05
# [LightGBM] [Warning] bagging_fraction is set=0.9908115119695178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9908115119695178
# [LightGBM] [Warning] lambda_l2 is set=1.1691014282433264e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1691014282433264e-06
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# MAE: 1756563.9076790982
#
# [LightGBM] [Warning] feature_fraction is set=0.8207861817896607, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8207861817896607
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=28 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=8.819323862997615, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.819323862997615
# [LightGBM] [Warning] lambda_l1 is set=0.6733788645055245, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6733788645055245
# [LightGBM] [Warning] bagging_fraction is set=0.8804567696713747, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8804567696713747
# [LightGBM] [Warning] lambda_l2 is set=3.3905002241229034e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.3905002241229034e-05
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# [LightGBM] [Warning] feature_fraction is set=0.8207861817896607, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8207861817896607
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=28 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=8.819323862997615, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.819323862997615
# [LightGBM] [Warning] lambda_l1 is set=0.6733788645055245, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6733788645055245
# [LightGBM] [Warning] bagging_fraction is set=0.8804567696713747, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8804567696713747
# [LightGBM] [Warning] lambda_l2 is set=3.3905002241229034e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.3905002241229034e-05
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# MAE: 1394877.052411573
#
# [LightGBM] [Warning] feature_fraction is set=0.7803149332452406, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7803149332452406
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=7.702599805692412, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.702599805692412
# [LightGBM] [Warning] lambda_l1 is set=0.2979121507664603, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2979121507664603
# [LightGBM] [Warning] bagging_fraction is set=0.7257803198426147, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7257803198426147
# [LightGBM] [Warning] lambda_l2 is set=1.1209505634974714e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1209505634974714e-08
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# [LightGBM] [Warning] feature_fraction is set=0.7803149332452406, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7803149332452406
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=26 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=7.702599805692412, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.702599805692412
# [LightGBM] [Warning] lambda_l1 is set=0.2979121507664603, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2979121507664603
# [LightGBM] [Warning] bagging_fraction is set=0.7257803198426147, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7257803198426147
# [LightGBM] [Warning] lambda_l2 is set=1.1209505634974714e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1209505634974714e-08
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# MAE: 1352613.5808282727
#
# [LightGBM] [Warning] feature_fraction is set=0.9034849503348027, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9034849503348027
# [LightGBM] [Warning] min_data_in_leaf is set=26, min_child_samples=13 will be ignored. Current value: min_data_in_leaf=26
# [LightGBM] [Warning] min_gain_to_split is set=9.865668130935747, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.865668130935747
# [LightGBM] [Warning] lambda_l1 is set=7.305422940282355, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.305422940282355
# [LightGBM] [Warning] bagging_fraction is set=0.5425351469702951, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5425351469702951
# [LightGBM] [Warning] lambda_l2 is set=1.2663613830133372e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.2663613830133372e-06
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# [LightGBM] [Warning] feature_fraction is set=0.9034849503348027, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9034849503348027
# [LightGBM] [Warning] min_data_in_leaf is set=26, min_child_samples=13 will be ignored. Current value: min_data_in_leaf=26
# [LightGBM] [Warning] min_gain_to_split is set=9.865668130935747, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.865668130935747
# [LightGBM] [Warning] lambda_l1 is set=7.305422940282355, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.305422940282355
# [LightGBM] [Warning] bagging_fraction is set=0.5425351469702951, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5425351469702951
# [LightGBM] [Warning] lambda_l2 is set=1.2663613830133372e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.2663613830133372e-06
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# MAE: 1478419.9349642582
#
# [LightGBM] [Warning] feature_fraction is set=0.5787197303221705, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5787197303221705
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=30 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] min_gain_to_split is set=5.627483475857151, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.627483475857151
# [LightGBM] [Warning] lambda_l1 is set=0.04724846290558468, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04724846290558468
# [LightGBM] [Warning] bagging_fraction is set=0.9063420309674367, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9063420309674367
# [LightGBM] [Warning] lambda_l2 is set=5.429983228699648e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.429983228699648e-05
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.5787197303221705, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5787197303221705
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=30 will be ignored. Current value: min_data_in_leaf=14
# ...
# [LightGBM] [Warning] lambda_l1 is set=1.9592270453180018, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.9592270453180018
# [LightGBM] [Warning] bagging_fraction is set=0.479560525699858, subsample=1.0 will be ignored. Current value: bagging_fraction=0.479560525699858
# [LightGBM] [Warning] lambda_l2 is set=2.9773255325990515, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.9773255325990515
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 1318542.6658757878
#
# [LightGBM] [Warning] feature_fraction is set=0.02978850668562691, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.02978850668562691
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=6.436968943228041, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.436968943228041
# [LightGBM] [Warning] lambda_l1 is set=0.8770923868150686, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.8770923868150686
# [LightGBM] [Warning] bagging_fraction is set=0.4548294624746968, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4548294624746968
# [LightGBM] [Warning] lambda_l2 is set=5.563390184937411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.563390184937411
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.02978850668562691, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.02978850668562691
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=6.436968943228041, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.436968943228041
# [LightGBM] [Warning] lambda_l1 is set=0.8770923868150686, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.8770923868150686
# [LightGBM] [Warning] bagging_fraction is set=0.4548294624746968, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4548294624746968
# [LightGBM] [Warning] lambda_l2 is set=5.563390184937411, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.563390184937411
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# MAE: 1412153.0206134487
#
# [LightGBM] [Warning] feature_fraction is set=0.08126987141853505, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08126987141853505
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.2380765494147035, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.2380765494147035
# [LightGBM] [Warning] lambda_l1 is set=0.6103165133993943, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6103165133993943
# [LightGBM] [Warning] bagging_fraction is set=0.5098359963129921, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5098359963129921
# [LightGBM] [Warning] lambda_l2 is set=9.903274401085765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.903274401085765
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.08126987141853505, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08126987141853505
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.2380765494147035, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.2380765494147035
# [LightGBM] [Warning] lambda_l1 is set=0.6103165133993943, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6103165133993943
# [LightGBM] [Warning] bagging_fraction is set=0.5098359963129921, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5098359963129921
# [LightGBM] [Warning] lambda_l2 is set=9.903274401085765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.903274401085765
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# MAE: 1623585.1956360163
#
# [LightGBM] [Warning] feature_fraction is set=0.055732020591476195, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.055732020591476195
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=6.7117081977753745, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.7117081977753745
# [LightGBM] [Warning] lambda_l1 is set=1.3470419544680852, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3470419544680852
# [LightGBM] [Warning] bagging_fraction is set=0.5302067128135647, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5302067128135647
# [LightGBM] [Warning] lambda_l2 is set=3.629705701277982, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.629705701277982
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.055732020591476195, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.055732020591476195
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=6.7117081977753745, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.7117081977753745
# [LightGBM] [Warning] lambda_l1 is set=1.3470419544680852, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3470419544680852
# [LightGBM] [Warning] bagging_fraction is set=0.5302067128135647, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5302067128135647
# [LightGBM] [Warning] lambda_l2 is set=3.629705701277982, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.629705701277982
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 1278055.654763008
#
# [LightGBM] [Warning] feature_fraction is set=0.09914259288084226, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09914259288084226
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=47 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] min_gain_to_split is set=8.260469710563692, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.260469710563692
# [LightGBM] [Warning] lambda_l1 is set=3.9464314787165, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.9464314787165
# [LightGBM] [Warning] bagging_fraction is set=0.20593705483665636, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20593705483665636
# [LightGBM] [Warning] lambda_l2 is set=2.2762568779388572, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2762568779388572
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.09914259288084226, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09914259288084226
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=47 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] min_gain_to_split is set=8.260469710563692, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.260469710563692
# [LightGBM] [Warning] lambda_l1 is set=3.9464314787165, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.9464314787165
# [LightGBM] [Warning] bagging_fraction is set=0.20593705483665636, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20593705483665636
# [LightGBM] [Warning] lambda_l2 is set=2.2762568779388572, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.2762568779388572
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# MAE: 1375714.696817849
#
# [LightGBM] [Warning] feature_fraction is set=0.0021467858090816194, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0021467858090816194
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=97 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=7.51279662128835, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.51279662128835
# [LightGBM] [Warning] lambda_l1 is set=1.1092566411192681, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1092566411192681
# [LightGBM] [Warning] bagging_fraction is set=0.4921075717094781, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4921075717094781
# [LightGBM] [Warning] lambda_l2 is set=5.061826399818533, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.061826399818533
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.0021467858090816194, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0021467858090816194
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=97 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] min_gain_to_split is set=7.51279662128835, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.51279662128835
# [LightGBM] [Warning] lambda_l1 is set=1.1092566411192681, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1092566411192681
# [LightGBM] [Warning] bagging_fraction is set=0.4921075717094781, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4921075717094781
# [LightGBM] [Warning] lambda_l2 is set=5.061826399818533, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.061826399818533
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 3307272.823275254
#
# [LightGBM] [Warning] feature_fraction is set=0.067511210595229, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.067511210595229
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=61 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=7.2357327549941, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.2357327549941
# [LightGBM] [Warning] lambda_l1 is set=6.790784700914412, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.790784700914412
# [LightGBM] [Warning] bagging_fraction is set=0.5766418860771511, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5766418860771511
# [LightGBM] [Warning] lambda_l2 is set=1.5720713359865186, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5720713359865186
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.067511210595229, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.067511210595229
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=61 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=7.2357327549941, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.2357327549941
# [LightGBM] [Warning] lambda_l1 is set=6.790784700914412, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.790784700914412
# [LightGBM] [Warning] bagging_fraction is set=0.5766418860771511, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5766418860771511
# [LightGBM] [Warning] lambda_l2 is set=1.5720713359865186, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5720713359865186
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# MAE: 1243796.8872735656
#
# [LightGBM] [Warning] feature_fraction is set=0.09306518933944671, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09306518933944671
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=66 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=6.957646249874358, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.957646249874358
# [LightGBM] [Warning] lambda_l1 is set=2.389254489895084, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.389254489895084
# [LightGBM] [Warning] bagging_fraction is set=0.5173432037485045, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5173432037485045
# [LightGBM] [Warning] lambda_l2 is set=7.051835717183682, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.051835717183682
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.09306518933944671, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09306518933944671
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=66 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=6.957646249874358, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.957646249874358
# [LightGBM] [Warning] lambda_l1 is set=2.389254489895084, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.389254489895084
# [LightGBM] [Warning] bagging_fraction is set=0.5173432037485045, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5173432037485045
# [LightGBM] [Warning] lambda_l2 is set=7.051835717183682, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.051835717183682
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 1269041.6529354537
#
# [LightGBM] [Warning] feature_fraction is set=0.04065042459280245, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.04065042459280245
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=94 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=6.442888023514207, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.442888023514207
# [LightGBM] [Warning] lambda_l1 is set=1.751439299872521, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.751439299872521
# [LightGBM] [Warning] bagging_fraction is set=0.5512214666338248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5512214666338248
# [LightGBM] [Warning] lambda_l2 is set=0.002166240041701609, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.002166240041701609
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.04065042459280245, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.04065042459280245
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=94 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=6.442888023514207, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.442888023514207
# [LightGBM] [Warning] lambda_l1 is set=1.751439299872521, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.751439299872521
# [LightGBM] [Warning] bagging_fraction is set=0.5512214666338248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5512214666338248
# [LightGBM] [Warning] lambda_l2 is set=0.002166240041701609, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.002166240041701609
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# MAE: 1281342.1046397837

# %%
# {'learning_rate': 0.00563634023909283,
#  'lambda_l1': 4.0081899175921105,
#  'lambda_l2': 6.319718896443305,
#  'min_gain_to_split': 7.778512739781448,
#  'num_leaves': 91,
#  'feature_fraction': 0.1174792601155319,
#  'bagging_fraction': 0.49890546631284705,
#  'bagging_freq': 0,
#  'min_child_samples': 100,
#  'min_data_in_leaf': 12}
study_LGB.best_params
# Out:
# {'learning_rate': 0.00563634023909283,
#  'lambda_l1': 4.0081899175921105,
#  'lambda_l2': 6.319718896443305,
#  'min_gain_to_split': 7.778512739781448,
#  'num_leaves': 91,
#  'feature_fraction': 0.1174792601155319,
#  'bagging_fraction': 0.49890546631284705,
#  'bagging_freq': 0,
#  'min_child_samples': 100,
#  'min_data_in_leaf': 12}

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    )  
model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
prediction1d = model1d.predict(n=90, future_covariates=series_1d_future_covariates)

df_prediction1d = prediction1d.pd_dataframe()
df_prediction1d[df_prediction1d["RUB"]>0] = 0
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.1174792601155319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1174792601155319
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] min_gain_to_split is set=7.778512739781448, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.778512739781448
# [LightGBM] [Warning] lambda_l1 is set=4.0081899175921105, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.0081899175921105
# [LightGBM] [Warning] bagging_fraction is set=0.49890546631284705, subsample=1.0 will be ignored. Current value: bagging_fraction=0.49890546631284705
# [LightGBM] [Warning] lambda_l2 is set=6.319718896443305, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.319718896443305
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0

# %%
series_1d_val.plot()
prediction1d.plot(label='forecast', low_quantile=0.05, high_quantile=0.95)
plt.legend()

# %%
mean_absolute_error(val_4_1d_reindex["RUB"], df_prediction1d["RUB"])
# Out:
# 1126196.8561590752

# %%
val_df = pd.DataFrame()
val_df.index = df_prediction1d["RUB"].index
val_df["y"] = val_4_1d_reindex["RUB"].values
val_df["yhat"] = (df_prediction1d["RUB"])

# %%
BU0_group_stage = pd.read_csv("train_4_ans_ts.csv", usecols=[1,2])
BU0_group_stage.set_index("Дата транзакции", inplace=True)
BU0_group_stage.index.name = "Date"

# %%
val_df["yhat_groupstage"] = BU0_group_stage.loc[:"2021-03-31", "Сумма в RUB"].values

# %%
BU0_group_stage.loc[:"2021-03-31", "Сумма в RUB"]
# Out:
# Date
# 2021-01-01   -3.892027e+06
# 2021-01-02   -3.794252e+05
# 2021-01-03   -3.879359e+06
# 2021-01-04   -3.722009e+05
# 2021-01-05   -3.831978e+06
#                   ...
# 2021-03-27   -3.277198e+05
# 2021-03-28   -3.908244e+06
# 2021-03-29   -5.317032e+05
# 2021-03-30   -3.891273e+06
# 2021-03-31   -4.740060e+05
# Name: Сумма в RUB, Length: 90, dtype: float64

# %%
val_df
# Out:
#               y           yhat  yhat_groupstage
# Date
# 2021-01-01  0.0       0.000000    -3.892027e+06
# 2021-01-02  0.0       0.000000    -3.794252e+05
# 2021-01-03  0.0 -106431.464317    -3.879359e+06
# 2021-01-04  0.0 -331992.529179    -3.722009e+05
# 2021-01-05  0.0 -689541.825300    -3.831978e+06
# ...         ...            ...              ...
# 2021-03-27  0.0       0.000000    -3.277198e+05
# 2021-03-28  0.0  -20723.335054    -3.908244e+06
# 2021-03-29  0.0       0.000000    -5.317032e+05
# 2021-03-30  0.0       0.000000    -3.891273e+06
# 2021-03-31  0.0       0.000000    -4.740060e+05
#
# [90 rows x 3 columns]

# %%
sns.lineplot(data=val_df)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mean_absolute_error(val_4_1d_reindex["RUB"], val_df["yhat_groupstage"])
# Out:
# 4666760.257136128

# %%
##############################################################################################################################################################################################

# %%
# Refit на total

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    ) 
model1d.fit(series_1d_total, future_covariates=series_1d_future_covariates)
prediction1d_total = model1d.predict(n=91, future_covariates=series_1d_future_covariates)
df_prediction1d_total = prediction1d_total.pd_dataframe()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.1174792601155319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1174792601155319
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] min_gain_to_split is set=7.778512739781448, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.778512739781448
# [LightGBM] [Warning] lambda_l1 is set=4.0081899175921105, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.0081899175921105
# [LightGBM] [Warning] bagging_fraction is set=0.49890546631284705, subsample=1.0 will be ignored. Current value: bagging_fraction=0.49890546631284705
# [LightGBM] [Warning] lambda_l2 is set=6.319718896443305, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.319718896443305
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0

# %%
df_prediction1d_total[df_prediction1d_total["RUB"]>0] = 0

# %%
train_4_ans_play_off = pd.DataFrame()
train_4_ans_play_off["Дата транзакции"] = pd.date_range(start="2021-04-01", end="2021-06-30", freq="1D")
train_4_ans_play_off["Сумма в RUB"] = (df_prediction1d_total["RUB"]).values
train_4_ans_play_off["Сумма в RUB"] = train_4_ans_play_off["Сумма в RUB"].groupby(train_4_ans_play_off["Дата транзакции"].dt.month).cumsum().values

train_4_ans_play_off["Месяц"] = train_4_ans_play_off["Дата транзакции"].dt.month
train_4_ans_play_off["БЕ"] = 4

# %%
train_4_ans_play_off
# Out:
#    Дата транзакции   Сумма в RUB  Месяц  БЕ
# 0       2021-04-01 -6.905618e+06      4   4
# 1       2021-04-02 -6.905618e+06      4   4
# 2       2021-04-03 -6.905618e+06      4   4
# 3       2021-04-04 -6.905618e+06      4   4
# 4       2021-04-05 -6.962121e+06      4   4
# ..             ...           ...    ...  ..
# 86      2021-06-26 -6.307732e+07      6   4
# 87      2021-06-27 -6.308762e+07      6   4
# 88      2021-06-28 -6.314334e+07      6   4
# 89      2021-06-29 -6.320328e+07      6   4
# 90      2021-06-30 -6.351176e+07      6   4
#
# [91 rows x 4 columns]

# %%
train_4_ans_play_off.to_csv("train_4_ans_play_off.csv")
