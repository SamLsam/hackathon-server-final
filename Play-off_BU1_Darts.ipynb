# %% [raw]
# Привет!
# В преддверии финала хотели бы поделиться обратной связью от экспертов:
#
# Всем спасибо за проделанную работу и предоставленные решения.
#
# Мы решили выдать данные за 1 квартал 21 года, чтобы у вас была возможность
# самим оценить работу моделей и скорректировать некоторые моменты.
# По окончании данного этапа мы ожидаем от вас реализацию ваших идей,
# прогноз на 2 квартал 21 года, а также твердый и четкий ответ, на вопрос о том,
# могут ли предоставленные дополнительные данные о БЕ номер 3 и 5 помочь улучшить точность моделей.
#
# Пожалуйста, по итогам своей работы предоставьте файл с прогнозами в виде кумулятивных сумм,
# аналогично тому, как это представлено в файле с объяснением подсчета метрики.

# %% [raw]
# Фидбэк по вашему решению:
# Советуем углубить анализ в контексте определения дней транзакции,
# поискать закономерности, создать дополнительные признаки и усложнить модели.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import holidays
import calendar
import datetime

# %%
from sklearn.metrics import mean_absolute_error

# %%
import optuna
from darts import TimeSeries
from darts.models import AutoARIMA, LightGBMModel

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.set(font_scale=1.25)

# %%
data = pd.read_csv("train.csv")

# %%
train = pd.DataFrame()
train["Unit"] = data["БЕ"]
train["Date"] = data["Дата транзакции"]
train["RUB"] = data["Сумма в RUB"]

# %%
train_0 = train[train["Unit"]==0][["Date", "RUB"]]
train_0.set_index(pd.to_datetime(train_0["Date"]), inplace=True)
train_0.drop(["Date"], inplace=True, axis=1)

train_1 = train[train["Unit"]==1][["Date", "RUB"]]
train_1.set_index(pd.to_datetime(train_1["Date"]), inplace=True)
train_1.drop(["Date"], inplace=True, axis=1)

train_2 = train[train["Unit"]==2][["Date", "RUB"]]
train_2.set_index(pd.to_datetime(train_2["Date"]), inplace=True)
train_2.drop(["Date"], inplace=True, axis=1)

train_3 = train[train["Unit"]==3][["Date", "RUB"]]
train_3.set_index(pd.to_datetime(train_3["Date"]), inplace=True)
train_3.drop(["Date"], inplace=True, axis=1)

train_4 = train[train["Unit"]==4][["Date", "RUB"]]
train_4.set_index(pd.to_datetime(train_4["Date"]), inplace=True)
train_4.drop(["Date"], inplace=True, axis=1)

train_5 = train[train["Unit"]==5][["Date", "RUB"]]
train_5.set_index(pd.to_datetime(train_5["Date"]), inplace=True)
train_5.drop(["Date"], inplace=True, axis=1)

train_6 = train[train["Unit"]==6][["Date", "RUB"]]
train_6.set_index(pd.to_datetime(train_6["Date"]), inplace=True)
train_6.drop(["Date"], inplace=True, axis=1)

# %%
train_1.tail()
# Out:
#                      RUB
# Date
# 2020-12-02 -1.528662e+03
# 2020-12-09 -1.796149e+07
# 2020-12-16 -1.805048e+07
# 2020-12-23 -1.927071e+07
# 2020-12-30 -8.601562e+06

# %%
train_1_1d = train_1.resample('1D').sum()
train_1_1d = pd.concat([train_1_1d, pd.DataFrame([0], columns=["RUB"], index=[pd.to_datetime("2020-12-31")])])
train_1_1d.index.name = "Date"

# %%
train_1_1d.tail()
# Out:
#                      RUB
# Date
# 2020-12-27  0.000000e+00
# 2020-12-28  0.000000e+00
# 2020-12-29  0.000000e+00
# 2020-12-30 -8.601562e+06
# 2020-12-31  0.000000e+00

# %%
sns.lineplot(data=train_1_1d)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##############################################################################################################################################################################################

# %%
### Generalized valid data ###
# Данные, выданные к финалу - первый квартал 2021 года
data = pd.read_excel("1кв2021_1.xlsx")

# %%
# Работаем аналагично train
val = pd.DataFrame()
val["Unit"] = data["БЕ"]
val["Date"] = data["Расчет ликвидности - дата"]
val["RUB"] = data["Сумма в валюте транзакции"]

# %%
val_0 = val[val["Unit"]==0][["Date", "RUB"]]
val_0.set_index(pd.to_datetime(val_0["Date"], dayfirst=True), inplace=True)
val_0.drop("Date", inplace=True, axis=1)

val_1 = val[val["Unit"]==1][["Date", "RUB"]]
val_1.set_index(pd.to_datetime(val_1["Date"], dayfirst=True), inplace=True)
val_1.drop("Date", inplace=True, axis=1)

val_2 = val[val["Unit"]==2][["Date", "RUB"]]
val_2.set_index(pd.to_datetime(val_2["Date"], dayfirst=True), inplace=True)
val_2.drop("Date", inplace=True, axis=1)

val_3 = val[val["Unit"]==3][["Date", "RUB"]]
val_3.set_index(pd.to_datetime(val_3["Date"], dayfirst=True), inplace=True)
val_3.drop("Date", inplace=True, axis=1)

val_4 = val[val["Unit"]==4][["Date", "RUB"]]
val_4.set_index(pd.to_datetime(val_4["Date"], dayfirst=True), inplace=True)
val_4.drop("Date", inplace=True, axis=1)

val_5 = val[val["Unit"]==5][["Date", "RUB"]]
val_5.set_index(pd.to_datetime(val_5["Date"], dayfirst=True), inplace=True)
val_5.drop("Date", inplace=True, axis=1)

val_6 = val[val["Unit"]==6][["Date", "RUB"]]
val_6.set_index(pd.to_datetime(val_6["Date"], dayfirst=True), inplace=True)
val_6.drop("Date", inplace=True, axis=1)

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*B1oKvhOuYoTdFEnwl8SEpg.png">

# %% [raw]
# Рисунок 1 - Схематичное изображение future covariates на временном интревале.
# Источник: https://medium.com/unit8-machine-learning-publication/time-series-forecasting-using-past-and-future-external-data-with-darts-1f0539585993

# %%
first_quarter = pd.DataFrame()
first_quarter.index = pd.date_range(start='1/1/2021', end='31/08/2021') # Немного с запасом
first_quarter["RUB"] = 0

val_0_1d = pd.DataFrame()
val_0_1d.index = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_0_1d.index.name = "Date"
val_0_1d["RUB"] = pd.merge(val_0, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_1_1d = pd.DataFrame()
val_1_1d.index = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_1_1d.index.name = "Date"
val_1_1d["RUB"] = pd.merge(val_1, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_2_1d = pd.DataFrame()
val_2_1d.index = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_2_1d.index.name = "Date"
val_2_1d["RUB"] = pd.merge(val_2, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_3_1d = pd.DataFrame()
val_3_1d.index = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_3_1d.index.name = "Date"
val_3_1d["RUB"] = pd.merge(val_3, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_4_1d = pd.DataFrame()
val_4_1d.index = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_4_1d.index.name = "Date"
val_4_1d["RUB"] = pd.merge(val_4, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_5_1d = pd.DataFrame()
val_5_1d.index = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_5_1d.index.name = "Date"
val_5_1d["RUB"] = pd.merge(val_5, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

val_6_1d = pd.DataFrame()
val_6_1d.index = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"].index
val_6_1d.index.name = "Date"
val_6_1d["RUB"] = pd.merge(val_6, first_quarter, how='outer', left_index=True, right_index=True).fillna(0)["RUB_x"]

# %%
##############################################################################################################################################################################################

# %%
# Feature engineering
# Добавляем регрессоры

# %%
def dayofweek(df):
    df["Dayofweek"] = df.index.dayofweek
    return df

# %%
def get_holidays(df):
    df["Holidays"] = pd.Series(df.index).apply(lambda x: holidays.CountryHoliday('RUS').get(x)).values
    df["Holidays"] = df["Holidays"].astype('bool').astype('int')
    return df

# %%
def number_of_week_in_year(df):
    df["Number_of_week_in_year"] = df.index.isocalendar().week
    df["Number_of_week_in_year"] = df["Number_of_week_in_year"].astype(int)
    return df

# %%
def number_of_week_in_month(df):
    def week_of_month(tgtdate):
        days_this_month = calendar.mdays[tgtdate.month]
        for i in range(1, days_this_month):
            d = datetime.datetime(tgtdate.year, tgtdate.month, i)
            if d.day - d.weekday() > 0:
                startdate = d
                break
        return (tgtdate - startdate).days //7 + 1
    df["Number_of_week_in_month"] = df.index.to_series().apply(week_of_month)
    return df

# %%
def number_of_day_in_month(df):
    df["Number_of_day_in_month"] = df.index.day
    return df

# %%
def number_of_day_in_year(df):
    df["Number_of_day_in_year"] = df.index.dayofyear
    return df

# %%
def get_month(df):
    df["Month"] = df.index.month
    return df

# %%
def get_season(df):
    df["Season"] = df.index.month%12 // 3 + 1
    return df

# %%
def payday(df, payday): # BU0: "Tuesday"
    df["Payday"] = 0 
    df.loc[df.index.day_name() == payday, "Payday"] = 1
    return df

# %%
# Сводим через pipeline
(
    train_1_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)
    .pipe(payday, payday="Wednesday")
)
# Out:
#                      RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2017-01-11 -1.375782e+07          2         0                       2
# 2017-01-12  0.000000e+00          3         0                       2
# 2017-01-13  0.000000e+00          4         0                       2
# 2017-01-14  0.000000e+00          5         0                       2
# 2017-01-15  0.000000e+00          6         0                       2
# ...                  ...        ...       ...                     ...
# 2020-12-27  0.000000e+00          6         0                      52
# 2020-12-28  0.000000e+00          0         0                      53
# 2020-12-29  0.000000e+00          1         0                      53
# 2020-12-30 -8.601562e+06          2         0                      53
# 2020-12-31  0.000000e+00          3         1                      53
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2017-01-11                        2                      11
# 2017-01-12                        2                      12
# 2017-01-13                        2                      13
# 2017-01-14                        2                      14
# 2017-01-15                        2                      15
# ...                             ...                     ...
# 2020-12-27                        3                      27
# 2020-12-28                        4                      28
# 2020-12-29                        4                      29
# 2020-12-30                        4                      30
# 2020-12-31                        4                      31
#
#             Number_of_day_in_year  Month  Season  Payday
# Date
# 2017-01-11                     11      1       1       1
# 2017-01-12                     12      1       1       0
# 2017-01-13                     13      1       1       0
# 2017-01-14                     14      1       1       0
# 2017-01-15                     15      1       1       0
# ...                           ...    ...     ...     ...
# 2020-12-27                    362     12       1       0
# 2020-12-28                    363     12       1       0
# 2020-12-29                    364     12       1       0
# 2020-12-30                    365     12       1       1
# 2020-12-31                    366     12       1       0
#
# [1451 rows x 10 columns]

# %%
(
    val_1_1d.pipe(dayofweek)
    .pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(number_of_day_in_month)
    .pipe(number_of_day_in_year)
    .pipe(get_month)
    .pipe(get_season)
    .pipe(payday, payday="Wednesday")
)
# Out:
#             RUB  Dayofweek  Holidays  Number_of_week_in_year  \
# Date
# 2021-01-01  0.0          4         1                      53
# 2021-01-02  0.0          5         1                      53
# 2021-01-03  0.0          6         1                      53
# 2021-01-04  0.0          0         1                       1
# 2021-01-05  0.0          1         1                       1
# ...         ...        ...       ...                     ...
# 2021-08-27  0.0          4         0                      34
# 2021-08-28  0.0          5         0                      34
# 2021-08-29  0.0          6         0                      34
# 2021-08-30  0.0          0         0                      35
# 2021-08-31  0.0          1         0                      35
#
#             Number_of_week_in_month  Number_of_day_in_month  \
# Date
# 2021-01-01                        0                       1
# 2021-01-02                        0                       2
# 2021-01-03                        0                       3
# 2021-01-04                        1                       4
# 2021-01-05                        1                       5
# ...                             ...                     ...
# 2021-08-27                        4                      27
# 2021-08-28                        4                      28
# 2021-08-29                        4                      29
# 2021-08-30                        5                      30
# 2021-08-31                        5                      31
#
#             Number_of_day_in_year  Month  Season  Payday
# Date
# 2021-01-01                      1      1       1       0
# 2021-01-02                      2      1       1       0
# 2021-01-03                      3      1       1       0
# 2021-01-04                      4      1       1       0
# 2021-01-05                      5      1       1       0
# ...                           ...    ...     ...     ...
# 2021-08-27                    239      8       3       0
# 2021-08-28                    240      8       3       0
# 2021-08-29                    241      8       3       0
# 2021-08-30                    242      8       3       0
# 2021-08-31                    243      8       3       0
#
# [243 rows x 10 columns]

# %%
list(train_1_1d.columns.values)
# Out:
# ['RUB',
#  'Dayofweek',
#  'Holidays',
#  'Number_of_week_in_year',
#  'Number_of_week_in_month',
#  'Number_of_day_in_month',
#  'Number_of_day_in_year',
#  'Month',
#  'Season',
#  'Payday']

# %%
##############################################################################################################################################################################################

# %%
# Darts модели

# %%
#train - данные до 2021
#val - данные первого квартала 2021
#total - их объединение
#covariates - общие для всех регрессоры
train_1_1d_reindex = train_1_1d["RUB"].reset_index(inplace=False)
train_1_1d_covariates = train_1_1d.drop("RUB", inplace=False, axis=1).reset_index()

val_1_1d_reindex = val_1_1d.loc["2021-01-01":"2021-03-31","RUB"].reset_index(inplace=False)
val_1_1d_covariates = val_1_1d.drop("RUB", inplace=False, axis=1).reset_index()

# %%
total_1_1d = pd.concat([train_1_1d, val_1_1d.loc["2021-01-01":"2021-03-31"]])
total_1_1d_reindex = total_1_1d["RUB"].reset_index(inplace=False)

# %%
series_1d_total = TimeSeries.from_dataframe(total_1_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
covariates = pd.concat([train_1_1d_covariates, val_1_1d_covariates])

# %%
series_1d_train = TimeSeries.from_dataframe(train_1_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)
series_1d_val = TimeSeries.from_dataframe(val_1_1d_reindex, time_col='Date', value_cols='RUB', freq='1d', fill_missing_dates=True)

# %%
series_1d_future_covariates = TimeSeries.from_dataframe(
    covariates,
    time_col="Date",
    value_cols=[
        "Dayofweek",
        "Holidays",
        "Number_of_week_in_year",
        "Number_of_week_in_month",
        "Number_of_day_in_month",
        "Number_of_day_in_year",
        "Month",
        "Season",
        #"Changepoint",
        "Payday",
    ],
    freq="1d",
    fill_missing_dates=True,
)

# %%
train_1d_split, local_val_1d_split = series_1d_train.split_before(0.80)
val_1d_split = series_1d_val

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
def objective_LGB(trial):

    # 
    model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=trial.suggest_float("learning_rate", 1e-3, 1.0, log=True),
        lambda_l1=trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
        lambda_l2=trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
        min_gain_to_split=trial.suggest_float("min_gain_to_split", 0, 10.0),
        num_leaves=trial.suggest_int("num_leaves", 8, 256),
        feature_fraction=trial.suggest_uniform("feature_fraction", 0.0001, 1.0),
        bagging_fraction=trial.suggest_uniform("bagging_fraction", 0.0001, 1.0),
        bagging_freq=trial.suggest_int("bagging_freq", 0, 30),
        min_child_samples=trial.suggest_int("min_child_samples", 1, 100),
        min_data_in_leaf=trial.suggest_int("min_data_in_leaf", 3, 100),
        feature_pre_filter=False
    )  
    # Настройка на валид внутри train (local valid)
    model1d.fit(train_1d_split, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(local_val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    local_val = mean_absolute_error(local_val_1d_split.pd_dataframe(), fixed_prediction1d)
    
    # Настройка на валид первого квартала 2021 года (данные, выданные к финалу)
    model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
    prediction1d = model1d.predict(n=len(val_1d_split), future_covariates=series_1d_future_covariates)
    fixed_prediction1d = prediction1d.pd_dataframe()
    fixed_prediction1d[fixed_prediction1d["RUB"] > 0] = 0
    global_val = mean_absolute_error(val_1d_split.pd_dataframe(), fixed_prediction1d)
    
    # Как вариант, использовать усредненное значение MAE двух разбиений для оптимизации гиперпараметров
    val = np.mean([local_val, global_val])

    trial.set_user_attr("Valid_score", val)

    print(f"MAE: {val}\n")

    return val

# %%
study_LGB = optuna.create_study(direction="minimize")
study_LGB.optimize(objective_LGB, n_trials=300, gc_after_trial=True) #300 - можно и больше, но как показывает лог, этого более чем достаточно
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.32323012581947913, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.32323012581947913
# [LightGBM] [Warning] min_data_in_leaf is set=75, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=75
# [LightGBM] [Warning] min_gain_to_split is set=5.383806386372577, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.383806386372577
# [LightGBM] [Warning] lambda_l1 is set=0.251496853292622, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.251496853292622
# [LightGBM] [Warning] bagging_fraction is set=0.2660335665356872, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2660335665356872
# [LightGBM] [Warning] lambda_l2 is set=0.005279675878766463, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.005279675878766463
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.32323012581947913, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.32323012581947913
# [LightGBM] [Warning] min_data_in_leaf is set=75, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=75
# [LightGBM] [Warning] min_gain_to_split is set=5.383806386372577, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.383806386372577
# [LightGBM] [Warning] lambda_l1 is set=0.251496853292622, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.251496853292622
# [LightGBM] [Warning] bagging_fraction is set=0.2660335665356872, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2660335665356872
# [LightGBM] [Warning] lambda_l2 is set=0.005279675878766463, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.005279675878766463
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# MAE: 1241191.3385933791
#
# [LightGBM] [Warning] feature_fraction is set=0.08057904474877385, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08057904474877385
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=51 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] min_gain_to_split is set=1.39360352447088, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.39360352447088
# [LightGBM] [Warning] lambda_l1 is set=2.779392346340942e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.779392346340942e-07
# [LightGBM] [Warning] bagging_fraction is set=0.22159784067894472, subsample=1.0 will be ignored. Current value: bagging_fraction=0.22159784067894472
# [LightGBM] [Warning] lambda_l2 is set=1.554793456503049e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.554793456503049e-05
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.08057904474877385, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08057904474877385
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=51 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] min_gain_to_split is set=1.39360352447088, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.39360352447088
# [LightGBM] [Warning] lambda_l1 is set=2.779392346340942e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.779392346340942e-07
# [LightGBM] [Warning] bagging_fraction is set=0.22159784067894472, subsample=1.0 will be ignored. Current value: bagging_fraction=0.22159784067894472
# [LightGBM] [Warning] lambda_l2 is set=1.554793456503049e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.554793456503049e-05
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# MAE: 1022556.3570632997
#
# [LightGBM] [Warning] feature_fraction is set=0.7015556179738083, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7015556179738083
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=9 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] min_gain_to_split is set=0.6110150466387176, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.6110150466387176
# [LightGBM] [Warning] lambda_l1 is set=0.5918985494193788, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5918985494193788
# [LightGBM] [Warning] bagging_fraction is set=0.19171821416199575, subsample=1.0 will be ignored. Current value: bagging_fraction=0.19171821416199575
# [LightGBM] [Warning] lambda_l2 is set=0.0031011540718233707, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0031011540718233707
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# [LightGBM] [Warning] feature_fraction is set=0.7015556179738083, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7015556179738083
# [LightGBM] [Warning] min_data_in_leaf is set=67, min_child_samples=9 will be ignored. Current value: min_data_in_leaf=67
# [LightGBM] [Warning] min_gain_to_split is set=0.6110150466387176, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.6110150466387176
# [LightGBM] [Warning] lambda_l1 is set=0.5918985494193788, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5918985494193788
# [LightGBM] [Warning] bagging_fraction is set=0.19171821416199575, subsample=1.0 will be ignored. Current value: bagging_fraction=0.19171821416199575
# [LightGBM] [Warning] lambda_l2 is set=0.0031011540718233707, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0031011540718233707
# [LightGBM] [Warning] bagging_freq is set=13, subsample_freq=0 will be ignored. Current value: bagging_freq=13
# MAE: 1212061.3624635902
#
# [LightGBM] [Warning] feature_fraction is set=0.02757892866109146, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.02757892866109146
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_gain_to_split is set=9.647519395786965, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.647519395786965
# [LightGBM] [Warning] lambda_l1 is set=7.43948750693054, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.43948750693054
# [LightGBM] [Warning] bagging_fraction is set=0.5569229977925347, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5569229977925347
# [LightGBM] [Warning] lambda_l2 is set=0.0011453598373319792, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0011453598373319792
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# [LightGBM] [Warning] feature_fraction is set=0.02757892866109146, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.02757892866109146
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_gain_to_split is set=9.647519395786965, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.647519395786965
# [LightGBM] [Warning] lambda_l1 is set=7.43948750693054, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.43948750693054
# [LightGBM] [Warning] bagging_fraction is set=0.5569229977925347, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5569229977925347
# [LightGBM] [Warning] lambda_l2 is set=0.0011453598373319792, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0011453598373319792
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# MAE: 1599930.9185551964
#
# [LightGBM] [Warning] feature_fraction is set=0.8834857229393136, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8834857229393136
# [LightGBM] [Warning] min_data_in_leaf is set=89, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=89
# [LightGBM] [Warning] min_gain_to_split is set=3.2307135813408627, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.2307135813408627
# [LightGBM] [Warning] lambda_l1 is set=1.0052092509423636e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0052092509423636e-06
# [LightGBM] [Warning] bagging_fraction is set=0.5714684120582796, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5714684120582796
# [LightGBM] [Warning] lambda_l2 is set=3.941616544682245e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.941616544682245e-08
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.8834857229393136, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8834857229393136
# [LightGBM] [Warning] min_data_in_leaf is set=89, min_child_samples=96 will be ignored. Current value: min_data_in_leaf=89
# [LightGBM] [Warning] min_gain_to_split is set=3.2307135813408627, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.2307135813408627
# [LightGBM] [Warning] lambda_l1 is set=1.0052092509423636e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0052092509423636e-06
# [LightGBM] [Warning] bagging_fraction is set=0.5714684120582796, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5714684120582796
# [LightGBM] [Warning] lambda_l2 is set=3.941616544682245e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.941616544682245e-08
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# MAE: 1060324.93005464
#
# [LightGBM] [Warning] feature_fraction is set=0.7629366242021861, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7629366242021861
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=85 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=6.434361619974688, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.434361619974688
# [LightGBM] [Warning] lambda_l1 is set=0.6903730239645816, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6903730239645816
# [LightGBM] [Warning] bagging_fraction is set=0.15677029070481993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.15677029070481993
# [LightGBM] [Warning] lambda_l2 is set=1.7654983708254552e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.7654983708254552e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.7629366242021861, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7629366242021861
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=85 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] min_gain_to_split is set=6.434361619974688, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.434361619974688
# [LightGBM] [Warning] lambda_l1 is set=0.6903730239645816, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.6903730239645816
# [LightGBM] [Warning] bagging_fraction is set=0.15677029070481993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.15677029070481993
# [LightGBM] [Warning] lambda_l2 is set=1.7654983708254552e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.7654983708254552e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# MAE: 1073663.2563412434
#
# [LightGBM] [Warning] feature_fraction is set=0.8011249696596581, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8011249696596581
# [LightGBM] [Warning] min_data_in_leaf is set=88, min_child_samples=81 will be ignored. Current value: min_data_in_leaf=88
# [LightGBM] [Warning] min_gain_to_split is set=3.909756212458888, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.909756212458888
# [LightGBM] [Warning] lambda_l1 is set=1.6239450311725751e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.6239450311725751e-06
# [LightGBM] [Warning] bagging_fraction is set=0.37343749335593235, subsample=1.0 will be ignored. Current value: bagging_fraction=0.37343749335593235
# [LightGBM] [Warning] lambda_l2 is set=0.0019375216931256576, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0019375216931256576
# [LightGBM] [Warning] bagging_freq is set=14, subsample_freq=0 will be ignored. Current value: bagging_freq=14
# [LightGBM] [Warning] feature_fraction is set=0.8011249696596581, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8011249696596581
# [LightGBM] [Warning] min_data_in_leaf is set=88, min_child_samples=81 will be ignored. Current value: min_data_in_leaf=88
# [LightGBM] [Warning] min_gain_to_split is set=3.909756212458888, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.909756212458888
# [LightGBM] [Warning] lambda_l1 is set=1.6239450311725751e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.6239450311725751e-06
# [LightGBM] [Warning] bagging_fraction is set=0.37343749335593235, subsample=1.0 will be ignored. Current value: bagging_fraction=0.37343749335593235
# [LightGBM] [Warning] lambda_l2 is set=0.0019375216931256576, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0019375216931256576
# [LightGBM] [Warning] bagging_freq is set=14, subsample_freq=0 will be ignored. Current value: bagging_freq=14
# MAE: 1209551.234035179
#
# [LightGBM] [Warning] feature_fraction is set=0.34583802516158285, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.34583802516158285
# [LightGBM] [Warning] min_data_in_leaf is set=82, min_child_samples=21 will be ignored. Current value: min_data_in_leaf=82
# [LightGBM] [Warning] min_gain_to_split is set=4.74350795533638, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.74350795533638
# [LightGBM] [Warning] lambda_l1 is set=5.2692277006362126e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.2692277006362126e-05
# [LightGBM] [Warning] bagging_fraction is set=0.5314407883474884, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5314407883474884
# [LightGBM] [Warning] lambda_l2 is set=2.8205194667994366e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.8205194667994366e-05
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.34583802516158285, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.34583802516158285
# [LightGBM] [Warning] min_data_in_leaf is set=82, min_child_samples=21 will be ignored. Current value: min_data_in_leaf=82
# [LightGBM] [Warning] min_gain_to_split is set=4.74350795533638, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.74350795533638
# [LightGBM] [Warning] lambda_l1 is set=5.2692277006362126e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.2692277006362126e-05
# [LightGBM] [Warning] bagging_fraction is set=0.5314407883474884, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5314407883474884
# [LightGBM] [Warning] lambda_l2 is set=2.8205194667994366e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.8205194667994366e-05
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# MAE: 1154311.0419227066
#
# [LightGBM] [Warning] feature_fraction is set=0.702427062963335, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.702427062963335
# [LightGBM] [Warning] min_data_in_leaf is set=96, min_child_samples=41 will be ignored. Current value: min_data_in_leaf=96
# [LightGBM] [Warning] min_gain_to_split is set=1.1747545270875936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.1747545270875936
# [LightGBM] [Warning] lambda_l1 is set=0.0009174018828718049, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009174018828718049
# [LightGBM] [Warning] bagging_fraction is set=0.05367628062641385, subsample=1.0 will be ignored. Current value: bagging_fraction=0.05367628062641385
# [LightGBM] [Warning] lambda_l2 is set=0.008114533607154997, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.008114533607154997
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# [LightGBM] [Warning] feature_fraction is set=0.702427062963335, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.702427062963335
# [LightGBM] [Warning] min_data_in_leaf is set=96, min_child_samples=41 will be ignored. Current value: min_data_in_leaf=96
# [LightGBM] [Warning] min_gain_to_split is set=1.1747545270875936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.1747545270875936
# [LightGBM] [Warning] lambda_l1 is set=0.0009174018828718049, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009174018828718049
# [LightGBM] [Warning] bagging_fraction is set=0.05367628062641385, subsample=1.0 will be ignored. Current value: bagging_fraction=0.05367628062641385
# [LightGBM] [Warning] lambda_l2 is set=0.008114533607154997, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.008114533607154997
# [LightGBM] [Warning] bagging_freq is set=8, subsample_freq=0 will be ignored. Current value: bagging_freq=8
# MAE: 3473531.3422606234
#
# [LightGBM] [Warning] feature_fraction is set=0.5476613394198243, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5476613394198243
# [LightGBM] [Warning] min_data_in_leaf is set=78, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=78
# [LightGBM] [Warning] min_gain_to_split is set=3.169532002626292, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.169532002626292
# [LightGBM] [Warning] lambda_l1 is set=1.2050785375700675e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.2050785375700675e-05
# [LightGBM] [Warning] bagging_fraction is set=0.496492738636201, subsample=1.0 will be ignored. Current value: bagging_fraction=0.496492738636201
# [LightGBM] [Warning] lambda_l2 is set=6.195414156805228e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.195414156805228e-08
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# [LightGBM] [Warning] feature_fraction is set=0.5476613394198243, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5476613394198243
# [LightGBM] [Warning] min_data_in_leaf is set=78, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=78
# [LightGBM] [Warning] min_gain_to_split is set=3.169532002626292, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.169532002626292
# [LightGBM] [Warning] lambda_l1 is set=1.2050785375700675e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.2050785375700675e-05
# [LightGBM] [Warning] bagging_fraction is set=0.496492738636201, subsample=1.0 will be ignored. Current value: bagging_fraction=0.496492738636201
# [LightGBM] [Warning] lambda_l2 is set=6.195414156805228e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.195414156805228e-08
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# MAE: 1094069.3597526704
#
# [LightGBM] [Warning] feature_fraction is set=0.06435595147056311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06435595147056311
# [LightGBM] [Warning] min_data_in_leaf is set=41, min_child_samples=59 will be ignored. Current value: min_data_in_leaf=41
# [LightGBM] [Warning] min_gain_to_split is set=7.833336023706748, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.833336023706748
# [LightGBM] [Warning] lambda_l1 is set=2.5339688829630196e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.5339688829630196e-08
# [LightGBM] [Warning] bagging_fraction is set=0.832532735848939, subsample=1.0 will be ignored. Current value: bagging_fraction=0.832532735848939
# [LightGBM] [Warning] lambda_l2 is set=5.963660868130995, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.963660868130995
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# [LightGBM] [Warning] feature_fraction is set=0.06435595147056311, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06435595147056311
# [LightGBM] [Warning] min_data_in_leaf is set=41, min_child_samples=59 will be ignored. Current value: min_data_in_leaf=41
# [LightGBM] [Warning] min_gain_to_split is set=7.833336023706748, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.833336023706748
# [LightGBM] [Warning] lambda_l1 is set=2.5339688829630196e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.5339688829630196e-08
# [LightGBM] [Warning] bagging_fraction is set=0.832532735848939, subsample=1.0 will be ignored. Current value: bagging_fraction=0.832532735848939
# [LightGBM] [Warning] lambda_l2 is set=5.963660868130995, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.963660868130995
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# MAE: 886482.1439607036
#
# [LightGBM] [Warning] feature_fraction is set=0.0012501205271849142, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0012501205271849142
# [LightGBM] [Warning] min_data_in_leaf is set=41, min_child_samples=56 will be ignored. Current value: min_data_in_leaf=41
# [LightGBM] [Warning] min_gain_to_split is set=7.884017542901928, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.884017542901928
# [LightGBM] [Warning] lambda_l1 is set=1.163827687575307e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.163827687575307e-08
# [LightGBM] [Warning] bagging_fraction is set=0.9392666147761595, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9392666147761595
# [LightGBM] [Warning] lambda_l2 is set=1.9736556086433188, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.9736556086433188
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# [LightGBM] [Warning] feature_fraction is set=0.0012501205271849142, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0012501205271849142
# [LightGBM] [Warning] min_data_in_leaf is set=41, min_child_samples=56 will be ignored. Current value: min_data_in_leaf=41
# [LightGBM] [Warning] min_gain_to_split is set=7.884017542901928, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.884017542901928
# [LightGBM] [Warning] lambda_l1 is set=1.163827687575307e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.163827687575307e-08
# [LightGBM] [Warning] bagging_fraction is set=0.9392666147761595, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9392666147761595
# [LightGBM] [Warning] lambda_l2 is set=1.9736556086433188, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.9736556086433188
# [LightGBM] [Warning] bagging_freq is set=22, subsample_freq=0 will be ignored. Current value: bagging_freq=22
# MAE: 2212183.874895706
#
# [LightGBM] [Warning] feature_fraction is set=0.18452671238661095, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.18452671238661095
# [LightGBM] [Warning] min_data_in_leaf is set=39, min_child_samples=60 will be ignored. Current value: min_data_in_leaf=39
# [LightGBM] [Warning] min_gain_to_split is set=7.858127704614826, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.858127704614826
# [LightGBM] [Warning] lambda_l1 is set=1.713828879720088e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.713828879720088e-08
# [LightGBM] [Warning] bagging_fraction is set=0.8345878668713669, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8345878668713669
# [LightGBM] [Warning] lambda_l2 is set=1.1136317792000673e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1136317792000673e-05
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.18452671238661095, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.18452671238661095
# [LightGBM] [Warning] min_data_in_leaf is set=39, min_child_samples=60 will be ignored. Current value: min_data_in_leaf=39
# [LightGBM] [Warning] min_gain_to_split is set=7.858127704614826, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.858127704614826
# [LightGBM] [Warning] lambda_l1 is set=1.713828879720088e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.713828879720088e-08
# [LightGBM] [Warning] bagging_fraction is set=0.8345878668713669, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8345878668713669
# [LightGBM] [Warning] lambda_l2 is set=1.1136317792000673e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1136317792000673e-05
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# MAE: 878016.6972985244
#
# [LightGBM] [Warning] feature_fraction is set=0.21987412794220415, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21987412794220415
# [LightGBM] [Warning] min_data_in_leaf is set=53, min_child_samples=68 will be ignored. Current value: min_data_in_leaf=53
# [LightGBM] [Warning] min_gain_to_split is set=8.337659519757068, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.337659519757068
# [LightGBM] [Warning] lambda_l1 is set=1.5485373102373946e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5485373102373946e-08
# [LightGBM] [Warning] bagging_fraction is set=0.8877779227950385, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8877779227950385
# [LightGBM] [Warning] lambda_l2 is set=0.16389537824798003, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.16389537824798003
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] feature_fraction is set=0.21987412794220415, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21987412794220415
# [LightGBM] [Warning] min_data_in_leaf is set=53, min_child_samples=68 will be ignored. Current value: min_data_in_leaf=53
# [LightGBM] [Warning] min_gain_to_split is set=8.337659519757068, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.337659519757068
# [LightGBM] [Warning] lambda_l1 is set=1.5485373102373946e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5485373102373946e-08
# [LightGBM] [Warning] bagging_fraction is set=0.8877779227950385, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8877779227950385
# [LightGBM] [Warning] lambda_l2 is set=0.16389537824798003, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.16389537824798003
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# MAE: 906477.6022159408
#
# [LightGBM] [Warning] feature_fraction is set=0.1819626288625504, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1819626288625504
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=36 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.8631357108130295, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.8631357108130295
# [LightGBM] [Warning] lambda_l1 is set=0.001771436895285165, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.001771436895285165
# [LightGBM] [Warning] bagging_fraction is set=0.7836044991964503, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7836044991964503
# [LightGBM] [Warning] lambda_l2 is set=2.142930268882858e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.142930268882858e-06
# [LightGBM] [Warning] bagging_freq is set=29, subsample_freq=0 will be ignored. Current value: bagging_freq=29
# [LightGBM] [Warning] feature_fraction is set=0.1819626288625504, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1819626288625504
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=36 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.8631357108130295, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.8631357108130295
# [LightGBM] [Warning] lambda_l1 is set=0.001771436895285165, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.001771436895285165
# [LightGBM] [Warning] bagging_fraction is set=0.7836044991964503, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7836044991964503
# [LightGBM] [Warning] lambda_l2 is set=2.142930268882858e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.142930268882858e-06
# [LightGBM] [Warning] bagging_freq is set=29, subsample_freq=0 will be ignored. Current value: bagging_freq=29
# MAE: 826275.6657018671
#
# [LightGBM] [Warning] feature_fraction is set=0.21996986508066094, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21996986508066094
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.331815674032675, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.331815674032675
# [LightGBM] [Warning] lambda_l1 is set=0.0009760239960274553, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009760239960274553
# [LightGBM] [Warning] bagging_fraction is set=0.747038166403165, subsample=1.0 will be ignored. Current value: bagging_fraction=0.747038166403165
# [LightGBM] [Warning] lambda_l2 is set=1.1914889843472359e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1914889843472359e-06
# [LightGBM] [Warning] bagging_freq is set=29, subsample_freq=0 will be ignored. Current value: bagging_freq=29
# [LightGBM] [Warning] feature_fraction is set=0.21996986508066094, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21996986508066094
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.331815674032675, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.331815674032675
# [LightGBM] [Warning] lambda_l1 is set=0.0009760239960274553, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009760239960274553
# [LightGBM] [Warning] bagging_fraction is set=0.747038166403165, subsample=1.0 will be ignored. Current value: bagging_fraction=0.747038166403165
# [LightGBM] [Warning] lambda_l2 is set=1.1914889843472359e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1914889843472359e-06
# [LightGBM] [Warning] bagging_freq is set=29, subsample_freq=0 will be ignored. Current value: bagging_freq=29
# MAE: 1363304.1152692463
#
# [LightGBM] [Warning] feature_fraction is set=0.5746652728797661, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5746652728797661
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=36 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=9.576693612350581, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.576693612350581
# [LightGBM] [Warning] lambda_l1 is set=0.012155059963700188, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.012155059963700188
# [LightGBM] [Warning] bagging_fraction is set=0.7019081635312373, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7019081635312373
# [LightGBM] [Warning] lambda_l2 is set=1.3586288676702697e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.3586288676702697e-06
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# [LightGBM] [Warning] feature_fraction is set=0.5746652728797661, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5746652728797661
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=36 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] min_gain_to_split is set=9.576693612350581, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.576693612350581
# [LightGBM] [Warning] lambda_l1 is set=0.012155059963700188, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.012155059963700188
# [LightGBM] [Warning] bagging_fraction is set=0.7019081635312373, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7019081635312373
# [LightGBM] [Warning] lambda_l2 is set=1.3586288676702697e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.3586288676702697e-06
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# MAE: 909894.6127965195
#
# [LightGBM] [Warning] feature_fraction is set=0.438454206850008, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.438454206850008
# [LightGBM] [Warning] min_data_in_leaf is set=51, min_child_samples=66 will be ignored. Current value: min_data_in_leaf=51
# [LightGBM] [Warning] min_gain_to_split is set=6.741572649945357, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.741572649945357
# [LightGBM] [Warning] lambda_l1 is set=0.036950567797667234, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.036950567797667234
# [LightGBM] [Warning] bagging_fraction is set=0.9984395725561377, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9984395725561377
# [LightGBM] [Warning] lambda_l2 is set=8.020541136850448e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.020541136850448e-05
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# [LightGBM] [Warning] feature_fraction is set=0.438454206850008, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.438454206850008
# [LightGBM] [Warning] min_data_in_leaf is set=51, min_child_samples=66 will be ignored. Current value: min_data_in_leaf=51
# [LightGBM] [Warning] min_gain_to_split is set=6.741572649945357, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.741572649945357
# [LightGBM] [Warning] lambda_l1 is set=0.036950567797667234, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.036950567797667234
# [LightGBM] [Warning] bagging_fraction is set=0.9984395725561377, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9984395725561377
# [LightGBM] [Warning] lambda_l2 is set=8.020541136850448e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.020541136850448e-05
# [LightGBM] [Warning] bagging_freq is set=18, subsample_freq=0 will be ignored. Current value: bagging_freq=18
# MAE: 979685.9090577015
#
# [LightGBM] [Warning] feature_fraction is set=0.1934936987103516, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1934936987103516
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=31 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=8.564926705677452, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.564926705677452
# [LightGBM] [Warning] lambda_l1 is set=0.00015434247879576396, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00015434247879576396
# [LightGBM] [Warning] bagging_fraction is set=0.7967068400096071, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7967068400096071
# [LightGBM] [Warning] lambda_l2 is set=8.501450494132854e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.501450494132854e-07
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] feature_fraction is set=0.1934936987103516, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1934936987103516
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=31 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=8.564926705677452, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.564926705677452
# [LightGBM] [Warning] lambda_l1 is set=0.00015434247879576396, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00015434247879576396
# [LightGBM] [Warning] bagging_fraction is set=0.7967068400096071, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7967068400096071
# [LightGBM] [Warning] lambda_l2 is set=8.501450494132854e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.501450494132854e-07
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# MAE: 863557.3218344611
#
# [LightGBM] [Warning] feature_fraction is set=0.3848193803336649, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3848193803336649
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=27 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=8.513906065941693, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.513906065941693
# [LightGBM] [Warning] lambda_l1 is set=0.00012684603345895217, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00012684603345895217
# [LightGBM] [Warning] bagging_fraction is set=0.6734911384351437, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6734911384351437
# [LightGBM] [Warning] lambda_l2 is set=7.101535469377026e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.101535469377026e-07
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] feature_fraction is set=0.3848193803336649, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3848193803336649
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=27 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_gain_to_split is set=8.513906065941693, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.513906065941693
# [LightGBM] [Warning] lambda_l1 is set=0.00012684603345895217, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00012684603345895217
# [LightGBM] [Warning] bagging_fraction is set=0.6734911384351437, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6734911384351437
# [LightGBM] [Warning] lambda_l2 is set=7.101535469377026e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.101535469377026e-07
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# MAE: 857718.8428714774
#
# [LightGBM] [Warning] feature_fraction is set=0.42347530034497394, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.42347530034497394
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=4 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=6.909266825830839, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.909266825830839
# [LightGBM] [Warning] lambda_l1 is set=0.006936677750670278, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.006936677750670278
# [LightGBM] [Warning] bagging_fraction is set=0.6870837108764358, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6870837108764358
# [LightGBM] [Warning] lambda_l2 is set=4.408782990630187e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.408782990630187e-07
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] feature_fraction is set=0.42347530034497394, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.42347530034497394
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=4 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=6.909266825830839, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.909266825830839
# [LightGBM] [Warning] lambda_l1 is set=0.006936677750670278, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.006936677750670278
# [LightGBM] [Warning] bagging_fraction is set=0.6870837108764358, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6870837108764358
# [LightGBM] [Warning] lambda_l2 is set=4.408782990630187e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.408782990630187e-07
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# MAE: 979604.7986282362
#
# [LightGBM] [Warning] feature_fraction is set=0.2969832487955779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2969832487955779
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=31 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=8.875269146131398, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.875269146131398
# [LightGBM] [Warning] lambda_l1 is set=0.00010557636511764107, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00010557636511764107
# [LightGBM] [Warning] bagging_fraction is set=0.6451965514595739, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6451965514595739
# [LightGBM] [Warning] lambda_l2 is set=2.443464361540953e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.443464361540953e-07
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# [LightGBM] [Warning] feature_fraction is set=0.2969832487955779, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2969832487955779
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=31 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] min_gain_to_split is set=8.875269146131398, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.875269146131398
# [LightGBM] [Warning] lambda_l1 is set=0.00010557636511764107, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00010557636511764107
# [LightGBM] [Warning] bagging_fraction is set=0.6451965514595739, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6451965514595739
# [LightGBM] [Warning] lambda_l2 is set=2.443464361540953e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.443464361540953e-07
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# MAE: 866513.7963555553
#
# [LightGBM] [Warning] feature_fraction is set=0.13791204859108508, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13791204859108508
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=22 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] min_gain_to_split is set=8.859275729616414, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.859275729616414
# [LightGBM] [Warning] lambda_l1 is set=1.477705492336666e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.477705492336666e-05
# [LightGBM] [Warning] bagging_fraction is set=0.7914263545938343, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7914263545938343
# [LightGBM] [Warning] lambda_l2 is set=3.9193252883966614e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.9193252883966614e-06
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] feature_fraction is set=0.13791204859108508, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13791204859108508
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=22 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] min_gain_to_split is set=8.859275729616414, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.859275729616414
# [LightGBM] [Warning] lambda_l1 is set=1.477705492336666e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.477705492336666e-05
# [LightGBM] [Warning] bagging_fraction is set=0.7914263545938343, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7914263545938343
# [LightGBM] [Warning] lambda_l2 is set=3.9193252883966614e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.9193252883966614e-06
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# MAE: 878694.7427099593
#
# [LightGBM] [Warning] feature_fraction is set=0.40448374243129565, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.40448374243129565
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=29 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=7.26682008249964, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.26682008249964
# [LightGBM] [Warning] lambda_l1 is set=0.0009313711132014877, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009313711132014877
# [LightGBM] [Warning] bagging_fraction is set=0.41592168525105916, subsample=1.0 will be ignored. Current value: bagging_fraction=0.41592168525105916
# [LightGBM] [Warning] lambda_l2 is set=0.00016897798030883455, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00016897798030883455
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] feature_fraction is set=0.40448374243129565, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.40448374243129565
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=29 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=7.26682008249964, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.26682008249964
# [LightGBM] [Warning] lambda_l1 is set=0.0009313711132014877, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0009313711132014877
# [LightGBM] [Warning] bagging_fraction is set=0.41592168525105916, subsample=1.0 will be ignored. Current value: bagging_fraction=0.41592168525105916
# [LightGBM] [Warning] lambda_l2 is set=0.00016897798030883455, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00016897798030883455
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# MAE: 981713.6898873886
#
# [LightGBM] [Warning] feature_fraction is set=0.2595548588482506, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2595548588482506
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=46 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] min_gain_to_split is set=5.84646744317765, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.84646744317765
# [LightGBM] [Warning] lambda_l1 is set=0.00020432509385289404, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00020432509385289404
# [LightGBM] [Warning] bagging_fraction is set=0.6367153546358473, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6367153546358473
# [LightGBM] [Warning] lambda_l2 is set=1.5066360073434896e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.5066360073434896e-07
# [LightGBM] [Warning] bagging_freq is set=16, subsample_freq=0 will be ignored. Current value: bagging_freq=16
# [LightGBM] [Warning] feature_fraction is set=0.2595548588482506, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2595548588482506
# ...
# [LightGBM] [Warning] bagging_fraction is set=0.5099173824280828, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5099173824280828
# [LightGBM] [Warning] lambda_l2 is set=1.8194175858665036e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.8194175858665036e-07
# [LightGBM] [Warning] bagging_freq is set=29, subsample_freq=0 will be ignored. Current value: bagging_freq=29
# MAE: 800916.8536869243
#
# [LightGBM] [Warning] feature_fraction is set=0.2141845136217185, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2141845136217185
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.646175163999874, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.646175163999874
# [LightGBM] [Warning] lambda_l1 is set=0.005376170113997643, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.005376170113997643
# [LightGBM] [Warning] bagging_fraction is set=0.42496680125936875, subsample=1.0 will be ignored. Current value: bagging_fraction=0.42496680125936875
# [LightGBM] [Warning] lambda_l2 is set=3.316600844964461e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.316600844964461e-07
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# [LightGBM] [Warning] feature_fraction is set=0.2141845136217185, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2141845136217185
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.646175163999874, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.646175163999874
# [LightGBM] [Warning] lambda_l1 is set=0.005376170113997643, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.005376170113997643
# [LightGBM] [Warning] bagging_fraction is set=0.42496680125936875, subsample=1.0 will be ignored. Current value: bagging_fraction=0.42496680125936875
# [LightGBM] [Warning] lambda_l2 is set=3.316600844964461e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.316600844964461e-07
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# MAE: 1197073.0821395454
#
# [LightGBM] [Warning] feature_fraction is set=0.1405766862409862, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1405766862409862
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=40 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.080736052869597, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.080736052869597
# [LightGBM] [Warning] lambda_l1 is set=0.024318935332288974, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024318935332288974
# [LightGBM] [Warning] bagging_fraction is set=0.46848187656558327, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46848187656558327
# [LightGBM] [Warning] lambda_l2 is set=7.55789521764462e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.55789521764462e-07
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# [LightGBM] [Warning] feature_fraction is set=0.1405766862409862, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1405766862409862
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=40 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.080736052869597, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.080736052869597
# [LightGBM] [Warning] lambda_l1 is set=0.024318935332288974, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024318935332288974
# [LightGBM] [Warning] bagging_fraction is set=0.46848187656558327, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46848187656558327
# [LightGBM] [Warning] lambda_l2 is set=7.55789521764462e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.55789521764462e-07
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# MAE: 791496.9863877576
#
# [LightGBM] [Warning] feature_fraction is set=0.17446831775571292, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.17446831775571292
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=48 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=6.328741816510031, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.328741816510031
# [LightGBM] [Warning] lambda_l1 is set=0.0113151566238485, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0113151566238485
# [LightGBM] [Warning] bagging_fraction is set=0.4858829711044069, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4858829711044069
# [LightGBM] [Warning] lambda_l2 is set=2.3806485843118143e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3806485843118143e-07
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# [LightGBM] [Warning] feature_fraction is set=0.17446831775571292, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.17446831775571292
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=48 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] min_gain_to_split is set=6.328741816510031, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.328741816510031
# [LightGBM] [Warning] lambda_l1 is set=0.0113151566238485, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0113151566238485
# [LightGBM] [Warning] bagging_fraction is set=0.4858829711044069, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4858829711044069
# [LightGBM] [Warning] lambda_l2 is set=2.3806485843118143e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3806485843118143e-07
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# MAE: 806748.8315688726
#
# [LightGBM] [Warning] feature_fraction is set=0.6796872534644769, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6796872534644769
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=45 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=7.125263917749582, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.125263917749582
# [LightGBM] [Warning] lambda_l1 is set=0.016416821507263656, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.016416821507263656
# [LightGBM] [Warning] bagging_fraction is set=0.44265387868774697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44265387868774697
# [LightGBM] [Warning] lambda_l2 is set=3.5821170228124e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.5821170228124e-06
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# [LightGBM] [Warning] feature_fraction is set=0.6796872534644769, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6796872534644769
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=45 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=7.125263917749582, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.125263917749582
# [LightGBM] [Warning] lambda_l1 is set=0.016416821507263656, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.016416821507263656
# [LightGBM] [Warning] bagging_fraction is set=0.44265387868774697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44265387868774697
# [LightGBM] [Warning] lambda_l2 is set=3.5821170228124e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.5821170228124e-06
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# MAE: 817318.4981674028
#
# [LightGBM] [Warning] feature_fraction is set=0.27542197296697374, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.27542197296697374
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=28 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.860267729043582, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.860267729043582
# [LightGBM] [Warning] lambda_l1 is set=0.04184497648196699, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04184497648196699
# [LightGBM] [Warning] bagging_fraction is set=0.38049306074542477, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38049306074542477
# [LightGBM] [Warning] lambda_l2 is set=5.118986686242937e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.118986686242937e-08
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# [LightGBM] [Warning] feature_fraction is set=0.27542197296697374, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.27542197296697374
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=28 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=6.860267729043582, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.860267729043582
# [LightGBM] [Warning] lambda_l1 is set=0.04184497648196699, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04184497648196699
# [LightGBM] [Warning] bagging_fraction is set=0.38049306074542477, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38049306074542477
# [LightGBM] [Warning] lambda_l2 is set=5.118986686242937e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.118986686242937e-08
# [LightGBM] [Warning] bagging_freq is set=30, subsample_freq=0 will be ignored. Current value: bagging_freq=30
# MAE: 909392.1937144061
#
# [LightGBM] [Warning] feature_fraction is set=0.2411454304043763, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2411454304043763
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=41 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.482541363879259, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.482541363879259
# [LightGBM] [Warning] lambda_l1 is set=0.022614574498435538, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.022614574498435538
# [LightGBM] [Warning] bagging_fraction is set=0.48109195541669164, subsample=1.0 will be ignored. Current value: bagging_fraction=0.48109195541669164
# [LightGBM] [Warning] lambda_l2 is set=3.4704726471065603, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.4704726471065603
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# [LightGBM] [Warning] feature_fraction is set=0.2411454304043763, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2411454304043763
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=41 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] min_gain_to_split is set=6.482541363879259, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.482541363879259
# [LightGBM] [Warning] lambda_l1 is set=0.022614574498435538, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.022614574498435538
# [LightGBM] [Warning] bagging_fraction is set=0.48109195541669164, subsample=1.0 will be ignored. Current value: bagging_fraction=0.48109195541669164
# [LightGBM] [Warning] lambda_l2 is set=3.4704726471065603, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.4704726471065603
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28
# MAE: 816352.8356123631
#
# [LightGBM] [Warning] feature_fraction is set=0.20145510272500106, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.20145510272500106
# [LightGBM] [Warning] min_data_in_leaf is set=93, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=93
# [LightGBM] [Warning] min_gain_to_split is set=5.580631595515226, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.580631595515226
# [LightGBM] [Warning] lambda_l1 is set=0.008620574410137409, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.008620574410137409
# [LightGBM] [Warning] bagging_fraction is set=0.5551903987701197, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5551903987701197
# [LightGBM] [Warning] lambda_l2 is set=1.1512831872884565e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1512831872884565e-07
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# [LightGBM] [Warning] feature_fraction is set=0.20145510272500106, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.20145510272500106
# [LightGBM] [Warning] min_data_in_leaf is set=93, min_child_samples=39 will be ignored. Current value: min_data_in_leaf=93
# [LightGBM] [Warning] min_gain_to_split is set=5.580631595515226, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.580631595515226
# [LightGBM] [Warning] lambda_l1 is set=0.008620574410137409, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.008620574410137409
# [LightGBM] [Warning] bagging_fraction is set=0.5551903987701197, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5551903987701197
# [LightGBM] [Warning] lambda_l2 is set=1.1512831872884565e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1512831872884565e-07
# [LightGBM] [Warning] bagging_freq is set=27, subsample_freq=0 will be ignored. Current value: bagging_freq=27
# MAE: 1332576.5343069881
#
# [LightGBM] [Warning] feature_fraction is set=0.22742250193534186, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.22742250193534186
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=7.259845562212915, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.259845562212915
# [LightGBM] [Warning] lambda_l1 is set=0.18367573458600212, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.18367573458600212
# [LightGBM] [Warning] bagging_fraction is set=0.5098576377043263, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5098576377043263
# [LightGBM] [Warning] lambda_l2 is set=1.1650576648696956e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1650576648696956e-06
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# [LightGBM] [Warning] feature_fraction is set=0.22742250193534186, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.22742250193534186
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] min_gain_to_split is set=7.259845562212915, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.259845562212915
# [LightGBM] [Warning] lambda_l1 is set=0.18367573458600212, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.18367573458600212
# [LightGBM] [Warning] bagging_fraction is set=0.5098576377043263, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5098576377043263
# [LightGBM] [Warning] lambda_l2 is set=1.1650576648696956e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.1650576648696956e-06
# [LightGBM] [Warning] bagging_freq is set=26, subsample_freq=0 will be ignored. Current value: bagging_freq=26
# MAE: 804944.8187279417

# %%
# {'learning_rate': 0.0055051378453408175,
#  'lambda_l1': 0.011274586080041064,
#  'lambda_l2': 2.9042256708707327e-06,
#  'min_gain_to_split': 8.208417529042908,
#  'num_leaves': 248,
#  'feature_fraction': 0.1365629651643199,
#  'bagging_fraction': 0.46310368612700326,
#  'bagging_freq': 28,
#  'min_child_samples': 50,
#  'min_data_in_leaf': 5}
study_LGB.best_params
# Out:
# {'learning_rate': 0.0055051378453408175,
#  'lambda_l1': 0.011274586080041064,
#  'lambda_l2': 2.9042256708707327e-06,
#  'min_gain_to_split': 8.208417529042908,
#  'num_leaves': 248,
#  'feature_fraction': 0.1365629651643199,
#  'bagging_fraction': 0.46310368612700326,
#  'bagging_freq': 28,
#  'min_child_samples': 50,
#  'min_data_in_leaf': 5}

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    )  
model1d.fit(series_1d_train, future_covariates=series_1d_future_covariates)
prediction1d = model1d.predict(n=90, future_covariates=series_1d_future_covariates)

df_prediction1d = prediction1d.pd_dataframe()
df_prediction1d[df_prediction1d["RUB"]>0] = 0
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.1365629651643199, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1365629651643199
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=50 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.208417529042908, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.208417529042908
# [LightGBM] [Warning] lambda_l1 is set=0.011274586080041064, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.011274586080041064
# [LightGBM] [Warning] bagging_fraction is set=0.46310368612700326, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46310368612700326
# [LightGBM] [Warning] lambda_l2 is set=2.9042256708707327e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.9042256708707327e-06
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28

# %%
df_prediction1d = prediction1d.pd_dataframe()

# %%
# Seems ok
series_1d_val.plot()
prediction1d.plot(label='forecast', low_quantile=0.05, high_quantile=0.95)
plt.legend()

# %%
# Настройка ARIMA модели на пиковые платежи.
# AUTOArima построена поверх библиотеки pmdarima для python
# Все шаги аналогичны

# %%
train_1_7d = train_1.reset_index().groupby(pd.Grouper(key='Date', freq='7D', how='sum', closed='left')).sum()
train_1_7d = train_1_7d.loc["2019-07-30":]

# %%
sns.lineplot(data=train_1_7d)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(
    train_1_7d.pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(get_month)
    .pipe(get_season)
)
# Out:
#                      RUB  Holidays  Number_of_week_in_year  \
# Date
# 2019-07-31 -5.138019e+06         0                      31
# 2019-08-07 -1.713401e+07         0                      32
# 2019-08-14 -1.715553e+07         0                      33
# 2019-08-21 -6.826534e+05         0                      34
# 2019-08-28 -1.680744e+07         0                      35
# ...                  ...       ...                     ...
# 2020-12-02 -1.528662e+03         0                      49
# 2020-12-09 -1.796149e+07         0                      50
# 2020-12-16 -1.805048e+07         0                      51
# 2020-12-23 -1.927071e+07         0                      52
# 2020-12-30 -8.601562e+06         0                      53
#
#             Number_of_week_in_month  Month  Season
# Date
# 2019-07-31                        5      7       3
# 2019-08-07                        1      8       3
# 2019-08-14                        2      8       3
# 2019-08-21                        3      8       3
# 2019-08-28                        4      8       3
# ...                             ...    ...     ...
# 2020-12-02                        0     12       1
# 2020-12-09                        1     12       1
# 2020-12-16                        2     12       1
# 2020-12-23                        3     12       1
# 2020-12-30                        4     12       1
#
# [75 rows x 6 columns]

# %%
val_1_7d = val_1_1d["2021-01-06":]["RUB"].reset_index().groupby(pd.Grouper(key='Date', freq='7D', how='sum', closed='left')).sum()

# %%
(
    val_1_7d.pipe(get_holidays)
    .pipe(number_of_week_in_year)
    .pipe(number_of_week_in_month)
    .pipe(get_month)
    .pipe(get_season)
)
# Out:
#                      RUB  Holidays  Number_of_week_in_year  \
# Date
# 2021-01-06  0.000000e+00         1                       1
# 2021-01-13 -1.938807e+07         0                       2
# 2021-01-20 -3.133081e+07         0                       3
# 2021-01-27 -2.054871e+07         0                       4
# 2021-02-03  0.000000e+00         0                       5
# 2021-02-10 -1.869003e+07         0                       6
# 2021-02-17 -3.238561e+07         0                       7
# 2021-02-24 -1.830584e+07         0                       8
# 2021-03-03  0.000000e+00         0                       9
# 2021-03-10 -1.750971e+07         0                      10
# 2021-03-17 -1.844832e+07         0                      11
# 2021-03-24 -1.981001e+07         0                      12
# 2021-03-31 -9.422805e+06         0                      13
# 2021-04-07  0.000000e+00         0                      14
# 2021-04-14  0.000000e+00         0                      15
# 2021-04-21  0.000000e+00         0                      16
# 2021-04-28  0.000000e+00         0                      17
# 2021-05-05  0.000000e+00         0                      18
# 2021-05-12  0.000000e+00         0                      19
# 2021-05-19  0.000000e+00         0                      20
# 2021-05-26  0.000000e+00         0                      21
# 2021-06-02  0.000000e+00         0                      22
# 2021-06-09  0.000000e+00         0                      23
# 2021-06-16  0.000000e+00         0                      24
# 2021-06-23  0.000000e+00         0                      25
# 2021-06-30  0.000000e+00         0                      26
# 2021-07-07  0.000000e+00         0                      27
# 2021-07-14  0.000000e+00         0                      28
# 2021-07-21  0.000000e+00         0                      29
# 2021-07-28  0.000000e+00         0                      30
# 2021-08-04  0.000000e+00         0                      31
# 2021-08-11  0.000000e+00         0                      32
# 2021-08-18  0.000000e+00         0                      33
# 2021-08-25  0.000000e+00         0                      34
#
#             Number_of_week_in_month  Month  Season
# Date
# 2021-01-06                        1      1       1
# 2021-01-13                        2      1       1
# 2021-01-20                        3      1       1
# 2021-01-27                        4      1       1
# 2021-02-03                        1      2       1
# 2021-02-10                        2      2       1
# 2021-02-17                        3      2       1
# 2021-02-24                        4      2       1
# 2021-03-03                        1      3       2
# 2021-03-10                        2      3       2
# 2021-03-17                        3      3       2
# 2021-03-24                        4      3       2
# 2021-03-31                        5      3       2
# 2021-04-07                        1      4       2
# 2021-04-14                        2      4       2
# 2021-04-21                        3      4       2
# 2021-04-28                        4      4       2
# 2021-05-05                        1      5       2
# 2021-05-12                        2      5       2
# 2021-05-19                        3      5       2
# 2021-05-26                        4      5       2
# 2021-06-02                        0      6       3
# 2021-06-09                        1      6       3
# 2021-06-16                        2      6       3
# 2021-06-23                        3      6       3
# 2021-06-30                        4      6       3
# 2021-07-07                        1      7       3
# 2021-07-14                        2      7       3
# 2021-07-21                        3      7       3
# 2021-07-28                        4      7       3
# 2021-08-04                        1      8       3
# 2021-08-11                        2      8       3
# 2021-08-18                        3      8       3
# 2021-08-25                        4      8       3

# %%
train_1_7d_reindex = train_1_7d["RUB"].reset_index(inplace=False)
train_1_7d_covariates = train_1_7d.drop("RUB", inplace=False, axis=1).reset_index()

val_1_7d_reindex = val_1_7d.loc["2021-01-01":"2021-03-31","RUB"].reset_index(inplace=False) #["RUB"]
val_1_7d_covariates = val_1_7d.drop("RUB", inplace=False, axis=1).reset_index()

# %%
total_1_7d = pd.concat([train_1_7d, val_1_7d.loc["2021-01-01":"2021-03-31"]])
total_1_7d_reindex = total_1_7d["RUB"].reset_index(inplace=False)

# %%
series_7d_total = TimeSeries.from_dataframe(total_1_7d_reindex, time_col='Date', value_cols='RUB', freq='7d') #, fill_missing_dates=False

# %%
covariates_7d = pd.concat([train_1_7d_covariates, val_1_7d_covariates])

# %%
series_7d_train = TimeSeries.from_dataframe(train_1_7d_reindex, time_col='Date', value_cols='RUB', freq='7d', fill_missing_dates=True)
series_7d_val = TimeSeries.from_dataframe(val_1_7d_reindex, time_col='Date', value_cols='RUB', freq='7d', fill_missing_dates=True)

# %%
list(train_1_7d_covariates.columns.values)
# Out:
# ['Date',
#  'Holidays',
#  'Number_of_week_in_year',
#  'Number_of_week_in_month',
#  'Month',
#  'Season']

# %%
series_7d_future_covariates = TimeSeries.from_dataframe(
    covariates_7d,
    time_col="Date",
    value_cols=[
        "Holidays",
        "Number_of_week_in_year",
        "Number_of_week_in_month",
        "Month",
        "Season",
    ],
    freq="7d",
    fill_missing_dates=True,
)

# %%
train_7d_split = series_7d_train
val_7d_split = series_7d_val

# %%
model7d = AutoARIMA()
model7d.fit(train_7d_split, future_covariates=series_7d_future_covariates) # future_covariates=series_7d_future_covariates
prediction7d = model7d.predict(n=13, future_covariates=series_7d_future_covariates) # future_covariates=series_7d_future_covariates

# %%
val_7d_split.plot()
prediction7d.plot(label='forecast', low_quantile=0.05, high_quantile=0.95)
plt.legend()

# %%
mean_absolute_error(val_7d_split.pd_dataframe(), prediction7d.pd_dataframe())
# Out:
# 6074063.367680637

# %%
df_prediction7d = prediction7d.pd_dataframe()

# %%
df_prediction1d
# Out:
# component            RUB
# Date
# 2021-01-01  9.362817e+04
# 2021-01-02 -1.833831e+05
# 2021-01-03 -6.628248e+04
# 2021-01-04  7.300706e+04
# 2021-01-05 -5.876695e+04
# ...                  ...
# 2021-03-27 -1.002320e+05
# 2021-03-28 -1.921583e+04
# 2021-03-29 -2.919233e+04
# 2021-03-30  6.253294e+03
# 2021-03-31 -4.171955e+06
#
# [90 rows x 1 columns]

# %%
df_prediction7d.resample("1D").sum()
# Out:
# component            RUB
# Date
# 2021-01-06 -3.670518e+06
# 2021-01-07  0.000000e+00
# 2021-01-08  0.000000e+00
# 2021-01-09  0.000000e+00
# 2021-01-10  0.000000e+00
# ...                  ...
# 2021-03-27  0.000000e+00
# 2021-03-28  0.000000e+00
# 2021-03-29  0.000000e+00
# 2021-03-30  0.000000e+00
# 2021-03-31 -2.235097e+07
#
# [85 rows x 1 columns]

# %%
df_prediction7d_resampled = pd.merge(df_prediction7d.resample("1D").sum(), first_quarter, how='outer', left_index=True, right_index=True).fillna(0).loc[:"2021-03-31"][["RUB_x"]]

# %%
mean_absolute_error(val_1_1d_reindex["RUB"], (df_prediction1d["RUB"] + df_prediction7d_resampled["RUB_x"])/2.0) #
# Out:
# 664820.0774906371

# %%
val_df = pd.DataFrame()
val_df.index = df_prediction1d["RUB"].index
val_df["y"] = val_1_1d_reindex["RUB"].values
val_df["yhat"] = ((df_prediction1d["RUB"] + df_prediction7d_resampled["RUB_x"])/2.0)

# %%
BU0_group_stage = pd.read_csv("train_1_ans_ts.csv", usecols=[1,2])
BU0_group_stage.set_index("Дата транзакции", inplace=True)
BU0_group_stage.index.name = "Date"

# %%
val_df["yhat_groupstage"] = BU0_group_stage.loc[:"2021-03-31", "Сумма в RUB"].values

# %%
BU0_group_stage.loc[:"2021-03-31", "Сумма в RUB"]
# Out:
# Date
# 2021-01-01   -1.224634e+05
# 2021-01-02   -1.373839e+06
# 2021-01-03   -7.049199e+04
# 2021-01-04   -1.370324e+06
# 2021-01-05   -1.263628e+05
#                   ...
# 2021-03-27   -1.390314e+06
# 2021-03-28   -8.007653e+04
# 2021-03-29   -1.374959e+06
# 2021-03-30   -1.258890e+05
# 2021-03-31   -5.188969e+06
# Name: Сумма в RUB, Length: 90, dtype: float64

# %%
val_df
# Out:
#                        y          yhat  yhat_groupstage
# Date
# 2021-01-01  0.000000e+00  4.681409e+04    -1.224634e+05
# 2021-01-02  0.000000e+00 -9.169153e+04    -1.373839e+06
# 2021-01-03  0.000000e+00 -3.314124e+04    -7.049199e+04
# 2021-01-04  0.000000e+00  3.650353e+04    -1.370324e+06
# 2021-01-05  0.000000e+00 -2.938347e+04    -1.263628e+05
# ...                  ...           ...              ...
# 2021-03-27  0.000000e+00 -5.011601e+04    -1.390314e+06
# 2021-03-28  0.000000e+00 -9.607915e+03    -8.007653e+04
# 2021-03-29  0.000000e+00 -1.459617e+04    -1.374959e+06
# 2021-03-30  0.000000e+00  3.126647e+03    -1.258890e+05
# 2021-03-31 -9.422805e+06 -1.326146e+07    -5.188969e+06
#
# [90 rows x 3 columns]

# %%
# y - истинное значение, yhat - значение новой модели, yhat_groupstage - значения старой модели. Качественно почти совпадают.
sns.lineplot(data=val_df)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# MAE от модели из отборов на первом квартале 2021 года. 1026000 => 2218810
mean_absolute_error(val_1_1d_reindex["RUB"], val_df["yhat_groupstage"])
# Out:
# 2218810.648317951

# %%
##############################################################################################################################################################################################

# %%
# Refit на total

# %%
model1d = LightGBMModel(
        lags=None,
        lags_future_covariates=(61, 31),
        output_chunk_length=1,
        verbose=-1,
        metric="mae",
        n_estimators=1000,
        learning_rate=study_LGB.best_params["learning_rate"],
        lambda_l1=study_LGB.best_params["lambda_l1"],
        lambda_l2=study_LGB.best_params["lambda_l2"],
        min_gain_to_split=study_LGB.best_params["min_gain_to_split"],
        num_leaves=study_LGB.best_params["num_leaves"],
        feature_fraction=study_LGB.best_params["feature_fraction"],
        bagging_fraction=study_LGB.best_params["bagging_fraction"],
        bagging_freq=study_LGB.best_params["bagging_freq"],
        min_child_samples=study_LGB.best_params["min_child_samples"],
        min_data_in_leaf=study_LGB.best_params["min_data_in_leaf"],
        feature_pre_filter=False
    ) 
model1d.fit(series_1d_total, future_covariates=series_1d_future_covariates)
prediction1d_total = model1d.predict(n=91, future_covariates=series_1d_future_covariates)
df_prediction1d_total = prediction1d_total.pd_dataframe()
df_prediction1d_total[df_prediction1d_total["RUB"]>0] = 0
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.1365629651643199, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1365629651643199
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=50 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_gain_to_split is set=8.208417529042908, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.208417529042908
# [LightGBM] [Warning] lambda_l1 is set=0.011274586080041064, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.011274586080041064
# [LightGBM] [Warning] bagging_fraction is set=0.46310368612700326, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46310368612700326
# [LightGBM] [Warning] lambda_l2 is set=2.9042256708707327e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.9042256708707327e-06
# [LightGBM] [Warning] bagging_freq is set=28, subsample_freq=0 will be ignored. Current value: bagging_freq=28

# %%
model7d = AutoARIMA()
model7d.fit(series_7d_total, future_covariates=series_7d_future_covariates) # future_covariates=series_7d_future_covariates
prediction7d_total = model7d.predict(n=13, future_covariates=series_7d_future_covariates) # future_covariates=series_7d_future_covariates
df_prediction7d_total = prediction7d_total.pd_dataframe()
df_prediction7d_total[df_prediction7d_total["RUB"]>0] = 0

# %%
df_prediction7d_total_resampled = pd.merge(df_prediction7d_total.resample("1D").sum(), first_quarter, how='outer', left_index=True, right_index=True).fillna(0).loc["2021-04-01":"2021-06-30"][["RUB_x"]]

# %%
train_1_ans_play_off = pd.DataFrame()
train_1_ans_play_off["Дата транзакции"] = pd.date_range(start="2021-04-01", end="2021-06-30", freq="1D")
train_1_ans_play_off["Сумма в RUB"] = ((df_prediction1d_total["RUB"] + df_prediction7d_total_resampled["RUB_x"])/2.0).values
train_1_ans_play_off["Сумма в RUB"] = train_1_ans_play_off["Сумма в RUB"].groupby(train_1_ans_play_off["Дата транзакции"].dt.month).cumsum().values

train_1_ans_play_off["Месяц"] = train_1_ans_play_off["Дата транзакции"].dt.month
train_1_ans_play_off["БЕ"] = 1

# %%
train_1_ans_play_off
# Out:
#    Дата транзакции   Сумма в RUB  Месяц  БЕ
# 0       2021-04-01  0.000000e+00      4   1
# 1       2021-04-02 -5.881170e+03      4   1
# 2       2021-04-03 -3.132099e+04      4   1
# 3       2021-04-04 -6.327782e+04      4   1
# 4       2021-04-05 -7.889123e+04      4   1
# ..             ...           ...    ...  ..
# 86      2021-06-26 -4.620150e+07      6   1
# 87      2021-06-27 -4.621872e+07      6   1
# 88      2021-06-28 -4.622768e+07      6   1
# 89      2021-06-29 -4.622768e+07      6   1
# 90      2021-06-30 -5.519730e+07      6   1
#
# [91 rows x 4 columns]

# %%
train_1_ans_play_off.to_csv("train_1_ans_play_off.csv")
